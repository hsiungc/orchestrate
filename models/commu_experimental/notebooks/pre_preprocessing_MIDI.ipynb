# %% [markdown]
# # Download and Prepare MusicMIDI for COMMU Processing

# %%
# !pip install boto3
# !pip install python-dotenv
# !pip install gensim==4.1.2
# !pip install seaborn
# !pip install openpyxl
# Out:
# Requirement already satisfied: boto3 in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (1.28.63)
# Requirement already satisfied: botocore<1.32.0,>=1.31.63 in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (from boto3) (1.31.63)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.8.0,>=0.7.0 in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (from boto3) (0.7.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (from botocore<1.32.0,>=1.31.63->boto3) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (from botocore<1.32.0,>=1.31.63->boto3) (1.26.17)
# Requirement already satisfied: six>=1.5 in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.32.0,>=1.31.63->boto3) (1.16.0)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages)
# Requirement already satisfied: python-dotenv in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (0.19.2)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages)
# Requirement already satisfied: gensim==4.1.2 in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (4.1.2)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (from gensim==4.1.2) (1.20.3)
# Requirement already satisfied: scipy>=0.18.1 in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (from gensim==4.1.2) (1.4.1)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (from gensim==4.1.2) (6.4.0)
# Requirement already satisfied: Cython==0.29.23 in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (from gensim==4.1.2) (0.29.23)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages)
# Requirement already satisfied: seaborn in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (0.13.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (from seaborn) (1.20.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (from seaborn) (3.7.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (6.1.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.3->seaborn) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages)
# Requirement already satisfied: openpyxl in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages (from openpyxl) (1.1.0)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\ktrin\miniconda3\envs\commu-env\lib\site-packages)

# %%
import os
import boto3
import joblib
import shutil
import mido
import miditoolkit
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ast import literal_eval
from pathlib import Path
from tqdm.notebook import tqdm

import dotenv
dotenv.load_dotenv()

sns.set()

# %%
# set some parameter
DATA_DIR = '../dataset'

# %%
# read in MIDI Metafiles
# parse chord progressions
# remove numbers from instruments
commu_meta = pd.read_csv(f"{DATA_DIR}/commu_meta.csv", index_col=0)
commu_meta['chord_progressions'] = commu_meta['chord_progressions'].apply(lambda x: literal_eval(x))
commu_meta['inst'] = commu_meta['inst'].apply(lambda x: re.sub(r'\d+', '', x))
commu_meta['inst'] = commu_meta['inst'].apply(lambda x: x.replace("__","").replace("-", ""))
commu_meta.head()
# Out:
#   audio_key                                 chord_progressions pitch_range  \
# 0    aminor  [[Am, Am, Am, Am, Am, Am, Am, Am, C, C, C, C, ...         mid
# 1    cmajor  [[C, C, C, C, C, C, C, C, Dm, Dm, Dm, Dm, Dm, ...     mid_low
# 2    aminor  [[Am, Am, Am, Am, Am, Am, Am, Am, Am, Am, Am, ...    mid_high
# 3    cmajor  [[C, C, C, C, C, C, C, C, Gm, Gm, Gm, Gm, Gm, ...         mid
# 4    aminor  [[Am, Am, Am, Am, Em, Em, Em, Em, F, F, F, F, ...     mid_low
#
#    num_measures  bpm      genre     track_role             inst sample_rhythm  \
# 0             8  120  cinematic    main_melody  string_ensemble      standard
# 1             8   80     newage  accompaniment   acoustic_piano      standard
# 2             8  150  cinematic           riff    string_violin      standard
# 3             8  110  cinematic            pad            choir      standard
# 4             4   60  cinematic            pad   acoustic_piano      standard
#
#   time_signature  min_velocity  max_velocity split_data          id
# 0            4/4           101           102      train  commu00001
# 1            4/4            23            30      train  commu00002
# 2            4/4           123           127      train  commu00003
# 3            4/4            45            46      train  commu00004
# 4            4/4            21            22      train  commu00005

# %%
# clean some columns
# remove mid suffix
# list the chord progression
musicMIDI_meta = pd.read_csv(f"{DATA_DIR}/midi_metadata_file.csv")
musicMIDI_meta['id'] = musicMIDI_meta['file_name']
musicMIDI_meta['id'] = musicMIDI_meta['id'].apply(lambda x: x[:-4])
musicMIDI_meta['chord_progressions'] = musicMIDI_meta['chord_progression'].apply(lambda x: literal_eval(x))
musicMIDI_meta['audio_key'] = musicMIDI_meta['audio_key'].apply(lambda x: x.replace('-', ''))
musicMIDI_meta.drop(columns=['file_name', 'chord_progression'], inplace=True)
musicMIDI_meta.head()
# Out:
#   audio_key pitch_range  num_measures  bpm       genre track_roll  \
# 0      Cmaj     unknown            10  192  electronic    unknown
# 1      Fmaj     unknown             7  112  electronic    unknown
# 2      Fmaj     unknown            12  163  electronic    unknown
# 3        Dm     unknown            19  109  electronic    unknown
# 4        Am     unknown            11  179  electronic    unknown
#
#                inst sample_rhythm time_signature  min_velocity  max_velocity  \
# 0          Dulcimer       unknown            2/4            64            87
# 1     Brass Section       unknown            2/4           127           127
# 2  Percussive Organ       unknown            2/4            31            85
# 3    SynthStrings 1       unknown            2/4            85            96
# 4   Lead 1 (square)       unknown            2/4            27           113
#
#    split_data                                   id  \
# 0         NaN  0004806f96307e317d116040af5b7861_11
# 1         NaN  0004806f96307e317d116040af5b7861_12
# 2         NaN  0004806f96307e317d116040af5b7861_13
# 3         NaN   0004806f96307e317d116040af5b7861_2
# 4         NaN   0004806f96307e317d116040af5b7861_3
#
#                                   chord_progressions
# 0  [Am, Am, Cmaj, Cmaj, Fmaj, Fmaj, Am, Am, Bmaj,...
# 1  [F, F, F, F, A, A, A, A, C, C, G, G, F, F, F, ...
# 2  [Dm, Dm, Dm, Dm, Fmaj, Fmaj, Fmaj, Fmaj, B, B,...
# 3  [Dm, Dm, Dm, Dm, Fmaj, Fmaj, Am, Am, Am, Am, G...
# 4  [C, C, G, G, A, A, C, C, A, A, Gmaj, Gmaj, G, ...

# %%
# fix chord progression label
def fix_chord_progression_label(chords):
    import re
    try:
        new_chord = []
        for c in chords:
            # replace number with empty string
            # c = re.sub(r'\d+', '', c)
            c = c.replace('-', '')
            c = c.replace('maj', '')
            new_chord.append(c)
        return [new_chord]
    except Exception as e:
        print(x)
        raise e

musicMIDI_meta['chord_progressions'] = musicMIDI_meta['chord_progressions'].apply(lambda x: fix_chord_progression_label(x))
musicMIDI_meta
# Out:
#       audio_key pitch_range  num_measures  bpm       genre track_roll  \
# 0          Cmaj     unknown            10  192  electronic    unknown
# 1          Fmaj     unknown             7  112  electronic    unknown
# 2          Fmaj     unknown            12  163  electronic    unknown
# 3            Dm     unknown            19  109  electronic    unknown
# 4            Am     unknown            11  179  electronic    unknown
# ...         ...         ...           ...  ...         ...        ...
# 62057        Cm     unknown            22  104        folk    unknown
# 62058        Cm     unknown            15  130        folk    unknown
# 62059      Fmaj     unknown             9  231   classical    unknown
# 62060      Fmaj     unknown            10  193   classical    unknown
# 62061      Fmaj     unknown             9  227   classical    unknown
#
#                    inst sample_rhythm time_signature  min_velocity  \
# 0              Dulcimer       unknown            2/4            64
# 1         Brass Section       unknown            2/4           127
# 2      Percussive Organ       unknown            2/4            31
# 3        SynthStrings 1       unknown            2/4            85
# 4       Lead 1 (square)       unknown            2/4            27
# ...                 ...           ...            ...           ...
# 62057   Tango Accordion       unknown            4/4            70
# 62058   Tango Accordion       unknown            4/4            70
# 62059             Flute       unknown            4/4            79
# 62060           Piccolo       unknown            4/4            55
# 62061              Oboe       unknown            4/4            64
#
#        max_velocity  split_data                                   id  \
# 0                87         NaN  0004806f96307e317d116040af5b7861_11
# 1               127         NaN  0004806f96307e317d116040af5b7861_12
# 2                85         NaN  0004806f96307e317d116040af5b7861_13
# 3                96         NaN   0004806f96307e317d116040af5b7861_2
# 4               113         NaN   0004806f96307e317d116040af5b7861_3
# ...             ...         ...                                  ...
# 62057            95         NaN   fff824db4e363d902648ca4869a2b682_2
# 62058            95         NaN   fff824db4e363d902648ca4869a2b682_3
# 62059            90         NaN   fffdf64e3d6ff25c5b1a38b485f336c3_1
# 62060            85         NaN   fffdf64e3d6ff25c5b1a38b485f336c3_2
# 62061            64         NaN   fffdf64e3d6ff25c5b1a38b485f336c3_3
#
#                                       chord_progressions
# 0      [[Am, Am, C, C, F, F, Am, Am, B, B, G, G, B, B...
# 1      [[F, F, F, F, A, A, A, A, C, C, G, G, F, F, F,...
# 2      [[Dm, Dm, Dm, Dm, F, F, F, F, B, B, G, G, Dm, ...
# 3      [[Dm, Dm, Dm, Dm, F, F, Am, Am, Am, Am, G, G, ...
# 4      [[C, C, G, G, A, A, C, C, A, A, G, G, G, G, C,...
# ...                                                  ...
# 62057  [[C, C, C, C, E, E, E, E, C, C, C, C, C, C, C,...
# 62058  [[C, C, C, C, E, E, E, E, G, G, G, G, C, C, C,...
# 62059  [[C, C, C, C, F, F, F, F, C, C, C, C, F, F, F,...
# 62060  [[F, F, F, F, B, B, B, B, C, C, C, C, B, B, B,...
# 62061  [[F, F, F, F, B, B, B, B, F, F, F, F, B, B, B,...
#
# [62062 rows x 14 columns]

# %%
# add key signature to MIDI files at the beginning of the file
def append_key_signature(input_path, output_path, midi_file_name, key):
    """
        Function to extract the minimum and maximum velocity from a given MIDI file
        Input: MIDI file path
        Output: Minimum velocity, Maximum velocity
    """
    from miditoolkit import MidiFile, KeySignature

    try:
        midi_file_path = input_path + '/' + midi_file_name + '.mid'
        # Load MIDI file and set up the key signature event
        midi_file = mido.MidiFile(midi_file_path)

        # Insert key signature event into the track
        position_ticks = 0 
        midi_file.tracks[0].append(mido.MetaMessage('key_signature', key=key, time=position_ticks))
        midi_file.tracks[0][-1], midi_file.tracks[0][-2] = midi_file.tracks[0][-2], midi_file.tracks[0][-1]
        # Save the MIDI file to the output path
        midi_file.save(f"{output_path}/{midi_file_name}.mid")

    except Exception as e:
        print(f"Error: {e}")
        return 
    return

# %%
# input_path = f"{DATA_DIR}/processed_musicMIDI/raw"
# output_path = f"{DATA_DIR}/processed_musicMIDI/raw_updated"
# midi_file_name = '0004806f96307e317d116040af5b7861_11'
# append_key_signature(input_path, output_path, midi_file_name, 'F')

# %%
# # inser the key signature into all MIDI files
# input_path = f"{DATA_DIR}/processed_musicMIDI/raw"
# output_path = f"{DATA_DIR}/processed_musicMIDI/raw_updated"


# # create the folder if not exist
# Path(output_path).mkdir(parents=True, exist_ok=True)

# for i, row in tqdm(musicMIDI_meta.iterrows()):
#     midi_file_name = row["id"]
#     key_signature = row["audio_key"]

#     # remove hypens
#     # remove maj if maj exists in key signature
#     key_signature = key_signature.replace('-', '')
#     if 'maj' in key_signature:
#         key_signature = key_signature[:-3]
#     append_key_signature(input_path, output_path, midi_file_name, key_signature)

# %% [markdown]
# # Rename Columns to Match comMU

# %%
# musicMIDI_meta = musicMIDI_meta.rename(columns = {'key_signature': 'audio_key',
                                                #   'chord_progression': 'chord_progressions',
                                                #   'Max_Genre': 'genre',
                                                #   'instrument': 'inst',
                                                #   'mid': 'id'})

# %%
# # test for key signature changes
# midi_file_path = f'{DATA_DIR}/processed_musicMIDI/raw_updated/0004806f96307e317d116040af5b7861_11.mid'
# midi = miditoolkit.MidiFile(midi_file_path)
# midi_id = Path(midi_file_path).stem
# pitch_track_notes = [midi.instruments[0].notes]

# print(midi)

# %%
# # test for key signature changes
# midi_file_path = f'{DATA_DIR}/commu_midi/train/raw/commu00001.mid'
# midi = miditoolkit.MidiFile(midi_file_path)
# midi_id = Path(midi_file_path).stem
# pitch_track_notes = [midi.instruments[0].notes]

# print(midi)

# %% [markdown]
# # Extract min/max velocity

# %%
def extract_min_max_velocity(midi_file_path):
    """
        Function to extract the minimum and maximum velocity from a given MIDI file
        Input: MIDI file path
        Output: Minimum velocity, Maximum velocity
    """
    try:
        mid = mido.MidiFile(midi_file_path)

        velocity_data = []

        for track in mid.tracks:
            for msg in track:
                if msg.type == 'note_on':
                    velocity = msg.velocity
                    velocity_data.append(velocity)


        velocity_data = sorted(list(set(velocity_data)))
        velocity_data = velocity_data[1:]
        min_velocity = velocity_data[0]
        max_velocity = velocity_data[-1]

    except Exception as e:
        print(f"Error: {e}")
        return None, None

    return min_velocity, max_velocity

# %%
# determine when minor velocity is negative
musicMIDI_meta['neg_min_velocity'] = musicMIDI_meta.apply(lambda x: x['min_velocity'] < 0, axis=1)

# determine when max velocity is negative
musicMIDI_meta['neg_max_velocity'] = musicMIDI_meta.apply(lambda x: x['max_velocity'] < 0, axis=1)
musicMIDI_meta['neg_min_velocity'].value_counts(), musicMIDI_meta['neg_max_velocity'].value_counts()
# Out:
# (neg_min_velocity
#  False    62062
#  Name: count, dtype: int64,
#  neg_max_velocity
#  False    62062
#  Name: count, dtype: int64)

# %%
# determine instances where the min/max velocidy is the same
musicMIDI_meta['min_max_velocity_same'] = musicMIDI_meta.apply(lambda x: x['min_velocity'] == x['max_velocity'], axis=1)
musicMIDI_meta['min_max_velocity_same'].value_counts()
# Out:
# min_max_velocity_same
# False    40582
# True     21480
# Name: count, dtype: int64

# %%
# determine instances when min velocity is > max velocity
musicMIDI_meta['min_velocity_greater_than_max_velocity'] = musicMIDI_meta.apply(lambda x: x['min_velocity'] > x['max_velocity'], axis=1)
musicMIDI_meta['min_velocity_greater_than_max_velocity'].value_counts()
# Out:
# min_velocity_greater_than_max_velocity
# False    62062
# Name: count, dtype: int64

# %%
# drop all the min/max velocity columns
musicMIDI_meta.drop(columns=['neg_min_velocity', 'neg_max_velocity', 'min_max_velocity_same', 'min_velocity_greater_than_max_velocity'], inplace=True)

# %%
# # for MIDI files that have same min/max velocity, re-extract the min/max velocity 
# # check if the min/max velocity is the same
# # if it is, ignore the file
# # if it is not, update the min/max velocity record
# temp_data = []
# for i, row in tqdm(musicMIDI_meta.iterrows()):
#     if row['min_max_velocity_same']:
#         midi_file_path = f'{DATA_DIR}/processed_musicMIDI/raw/{row["id"]}.mid'
#         min_velocity, max_velocity = extract_min_max_velocity(midi_file_path)
        
#         if min_velocity != max_velocity:
#             temp_data.append([row['id'], min_velocity, max_velocity])


# temp_data[:5]

# %%
# # test print minmax velocity
# midi_file_path = f'{DATA_DIR}/musicMIDI/raw/014d0f3da9195dc1c9c23c2ad0e438f9_12.mid'
# # midi_file_path = f'{DATA_DIR}/commu_midi/train/raw/commu00003.mid'
# min_velocity, max_velocity = extract_min_max_velocity(midi_file_path)

# if min_velocity is not None and max_velocity is not None:
#     print(f"Minimum velocity: {min_velocity}")
#     print(f"Maximum velocity: {max_velocity}")
# else:
#     print("Failed to extract velocity information from the MIDI file.")

# %%
# # extract min/max velocity from all MIDI files
# velocity_data = []
# for i, row in tqdm(musicMIDI_meta.iterrows()):
#     print(row['id'])
#     midi_file_path = f'{DATA_DIR}/musicMIDI/raw/{row["id"]}.mid'
#     min_velocity, max_velocity = extract_min_max_velocity(midi_file_path)
#     velocity_data.append([row['id'], min_velocity, max_velocity])

# # get the missing data
# velocity_data = pd.DataFrame(velocity_data, columns=['id', 'min_velocity', 'max_velocity'])
# missing_midi = velocity_data[velocity_data['min_velocity'] != velocity_data['min_velocity']]
# missing_midi.to_csv(f'{DATA_DIR}/missing_metaMIDI.csv', index=False)

# # merge velocity data with musicMIDI_meta
# musicMIDI_meta = musicMIDI_meta.drop(columns=['file_name', 'min_velocity', 'max_velocity']).merge(velocity_data, on='id', how='left')
# musicMIDI_meta.head()

# %% [markdown]
# # Cleanup MetaMIDI dataset

# %%
# get all commu columns headers
# get all musicMIDI columns headers
commu_headers = commu_meta.columns.tolist()
musicMIDI_headers = musicMIDI_meta.columns.tolist()
commu_headers, musicMIDI_headers
# Out:
# (['audio_key',
#   'chord_progressions',
#   'pitch_range',
#   'num_measures',
#   'bpm',
#   'genre',
#   'track_role',
#   'inst',
#   'sample_rhythm',
#   'time_signature',
#   'min_velocity',
#   'max_velocity',
#   'split_data',
#   'id'],
#  ['audio_key',
#   'pitch_range',
#   'num_measures',
#   'bpm',
#   'genre',
#   'track_roll',
#   'inst',
#   'sample_rhythm',
#   'time_signature',
#   'min_velocity',
#   'max_velocity',
#   'split_data',
#   'id',
#   'chord_progressions'])

# %%
# cleanup audio keys
musicMIDI_meta['audio_key'].unique()

# for key signature if ends with 'm' then it is minor
# else it is major
# replace "-" with empty string
# lower case the entire string
musicMIDI_meta['audio_key'] = musicMIDI_meta['audio_key'].apply(lambda x: x+'inor' if x.endswith('m') else x+'or')
musicMIDI_meta['audio_key'] = musicMIDI_meta['audio_key'].apply(lambda x: x.replace('-', ''))
musicMIDI_meta['audio_key'] = musicMIDI_meta['audio_key'].apply(lambda x: x.lower())
musicMIDI_meta['audio_key'].unique()
# Out:
# array(['cmajor', 'fmajor', 'dminor', 'aminor', 'eminor', 'dmajor',
#        'gmajor', 'amajor', 'f#minor', 'bminor', 'bmajor', 'emajor',
#        'gminor', 'fminor', 'c#major', 'f#major', 'c#minor', 'cminor',
#        'g#minor'], dtype=object)

# %%
# get top 10 time signature
top_10 = musicMIDI_meta.groupby('time_signature').count().sort_values(by='id', ascending=False).head(10).index
musicMIDI_meta['time_signature'].unique(), top_10
# Out:
# (array(['2/4', '4/4', '3/4', '3/2', '1/4', '6/8', '2/2', '6/4', '9/8',
#         '4/2', '12/8', '1/16', '8/4', '3/8', '5/4', '1/8', '5/8', '7/8',
#         '3/16', '1/1', '7/4', '12/16', '31/1', '4/8', '10/8', '3/1',
#         '13/8', '9/16', '32/8', '32/4', '8/8', '6/16', '5/16', '4/16',
#         '11/16', '11/8', '16/4', '1/2', '4/1', '2/16'], dtype=object),
#  Index(['4/4', '3/4', '2/4', '6/8', '1/4', '2/2', '6/4', '12/8', '3/8', '5/4'], dtype='object', name='time_signature'))

# %%
# get only top 10 time signatures
musicMIDI_meta = musicMIDI_meta[musicMIDI_meta['time_signature'].isin(top_10)]
musicMIDI_meta.head()
# Out:
#   audio_key pitch_range  num_measures  bpm       genre track_roll  \
# 0    cmajor     unknown            10  192  electronic    unknown
# 1    fmajor     unknown             7  112  electronic    unknown
# 2    fmajor     unknown            12  163  electronic    unknown
# 3    dminor     unknown            19  109  electronic    unknown
# 4    aminor     unknown            11  179  electronic    unknown
#
#                inst sample_rhythm time_signature  min_velocity  max_velocity  \
# 0          Dulcimer       unknown            2/4            64            87
# 1     Brass Section       unknown            2/4           127           127
# 2  Percussive Organ       unknown            2/4            31            85
# 3    SynthStrings 1       unknown            2/4            85            96
# 4   Lead 1 (square)       unknown            2/4            27           113
#
#    split_data                                   id  \
# 0         NaN  0004806f96307e317d116040af5b7861_11
# 1         NaN  0004806f96307e317d116040af5b7861_12
# 2         NaN  0004806f96307e317d116040af5b7861_13
# 3         NaN   0004806f96307e317d116040af5b7861_2
# 4         NaN   0004806f96307e317d116040af5b7861_3
#
#                                   chord_progressions
# 0  [[Am, Am, C, C, F, F, Am, Am, B, B, G, G, B, B...
# 1  [[F, F, F, F, A, A, A, A, C, C, G, G, F, F, F,...
# 2  [[Dm, Dm, Dm, Dm, F, F, F, F, B, B, G, G, Dm, ...
# 3  [[Dm, Dm, Dm, Dm, F, F, Am, Am, Am, Am, G, G, ...
# 4  [[C, C, G, G, A, A, C, C, A, A, G, G, G, G, C,...

# %%
# add missing headers to musicMIDI_meta
for header in commu_headers:
    if header not in musicMIDI_headers:
        musicMIDI_meta[header] = 'unknown'


# fill the rese with unknown
musicMIDI_meta.fillna('unknown', inplace=True)
# Out:
# C:\Users\ktrin\AppData\Local\Temp\ipykernel_20424\757961987.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   musicMIDI_meta[header] = 'unknown'
# C:\Users\ktrin\AppData\Local\Temp\ipykernel_20424\757961987.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   musicMIDI_meta.fillna('unknown', inplace=True)

# %%
def parse_inst(inst):
    """
        Function to cleanup the instrument column
    """
    try:
        # remove the number from the instrument
        # replace extra characters with empty string
        # replace last underscore with empty string
        inst = re.sub(r'\d+', '', inst)
        inst = inst.lower().replace('(', '').replace(')', '').replace('-', '').replace(' ', '_').replace("__", "_")
        if inst.endswith('_'):
            inst = inst[:-1]
        return inst
    except:
        return 'unknown'

# %%
# parse instrument
musicMIDI_meta['inst'] = musicMIDI_meta['inst'].apply(lambda x: parse_inst(x))

# fill unknown instrument with ensemble
musicMIDI_meta['inst'] = musicMIDI_meta['inst'].apply(lambda x: 'ensemble' if x == 'unknown' else x)
musicMIDI_meta
# Out:
# C:\Users\ktrin\AppData\Local\Temp\ipykernel_20424\95340619.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   musicMIDI_meta['inst'] = musicMIDI_meta['inst'].apply(lambda x: parse_inst(x))
# C:\Users\ktrin\AppData\Local\Temp\ipykernel_20424\95340619.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   musicMIDI_meta['inst'] = musicMIDI_meta['inst'].apply(lambda x: 'ensemble' if x == 'unknown' else x)
#       audio_key pitch_range  num_measures  bpm       genre track_roll  \
# 0        cmajor     unknown            10  192  electronic    unknown
# 1        fmajor     unknown             7  112  electronic    unknown
# 2        fmajor     unknown            12  163  electronic    unknown
# 3        dminor     unknown            19  109  electronic    unknown
# 4        aminor     unknown            11  179  electronic    unknown
# ...         ...         ...           ...  ...         ...        ...
# 62057    cminor     unknown            22  104        folk    unknown
# 62058    cminor     unknown            15  130        folk    unknown
# 62059    fmajor     unknown             9  231   classical    unknown
# 62060    fmajor     unknown            10  193   classical    unknown
# 62061    fmajor     unknown             9  227   classical    unknown
#
#                    inst sample_rhythm time_signature  min_velocity  \
# 0              dulcimer       unknown            2/4            64
# 1         brass_section       unknown            2/4           127
# 2      percussive_organ       unknown            2/4            31
# 3          synthstrings       unknown            2/4            85
# 4           lead_square       unknown            2/4            27
# ...                 ...           ...            ...           ...
# 62057   tango_accordion       unknown            4/4            70
# 62058   tango_accordion       unknown            4/4            70
# 62059             flute       unknown            4/4            79
# 62060           piccolo       unknown            4/4            55
# 62061              oboe       unknown            4/4            64
#
#        max_velocity split_data                                   id  \
# 0                87    unknown  0004806f96307e317d116040af5b7861_11
# 1               127    unknown  0004806f96307e317d116040af5b7861_12
# 2                85    unknown  0004806f96307e317d116040af5b7861_13
# 3                96    unknown   0004806f96307e317d116040af5b7861_2
# 4               113    unknown   0004806f96307e317d116040af5b7861_3
# ...             ...        ...                                  ...
# 62057            95    unknown   fff824db4e363d902648ca4869a2b682_2
# 62058            95    unknown   fff824db4e363d902648ca4869a2b682_3
# 62059            90    unknown   fffdf64e3d6ff25c5b1a38b485f336c3_1
# 62060            85    unknown   fffdf64e3d6ff25c5b1a38b485f336c3_2
# 62061            64    unknown   fffdf64e3d6ff25c5b1a38b485f336c3_3
#
#                                       chord_progressions track_role
# 0      [[Am, Am, C, C, F, F, Am, Am, B, B, G, G, B, B...    unknown
# 1      [[F, F, F, F, A, A, A, A, C, C, G, G, F, F, F,...    unknown
# 2      [[Dm, Dm, Dm, Dm, F, F, F, F, B, B, G, G, Dm, ...    unknown
# 3      [[Dm, Dm, Dm, Dm, F, F, Am, Am, Am, Am, G, G, ...    unknown
# 4      [[C, C, G, G, A, A, C, C, A, A, G, G, G, G, C,...    unknown
# ...                                                  ...        ...
# 62057  [[C, C, C, C, E, E, E, E, C, C, C, C, C, C, C,...    unknown
# 62058  [[C, C, C, C, E, E, E, E, G, G, G, G, C, C, C,...    unknown
# 62059  [[C, C, C, C, F, F, F, F, C, C, C, C, F, F, F,...    unknown
# 62060  [[F, F, F, F, B, B, B, B, C, C, C, C, B, B, B,...    unknown
# 62061  [[F, F, F, F, B, B, B, B, F, F, F, F, B, B, B,...    unknown
#
# [61336 rows x 15 columns]

# %%
def parse_genre(genre):
    """
        Function to cleanup the instrument column
    """
    try:
        return genre.lower().replace(' ', '').replace(',', ' ').replace('/', ' ').replace('&', ' ').replace('-', ' ').replace(' ', '_').replace("__", "_")
    
    except:
        return 'unknown'

# parse genre
# treat special case of folk_world__country
musicMIDI_meta['genre'] = musicMIDI_meta['genre'].apply(lambda x: parse_genre(x))
musicMIDI_meta.head()
# Out:
# C:\Users\ktrin\AppData\Local\Temp\ipykernel_20424\147891459.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   musicMIDI_meta['genre'] = musicMIDI_meta['genre'].apply(lambda x: parse_genre(x))
#   audio_key pitch_range  num_measures  bpm       genre track_roll  \
# 0    cmajor     unknown            10  192  electronic    unknown
# 1    fmajor     unknown             7  112  electronic    unknown
# 2    fmajor     unknown            12  163  electronic    unknown
# 3    dminor     unknown            19  109  electronic    unknown
# 4    aminor     unknown            11  179  electronic    unknown
#
#                inst sample_rhythm time_signature  min_velocity  max_velocity  \
# 0          dulcimer       unknown            2/4            64            87
# 1     brass_section       unknown            2/4           127           127
# 2  percussive_organ       unknown            2/4            31            85
# 3      synthstrings       unknown            2/4            85            96
# 4       lead_square       unknown            2/4            27           113
#
#   split_data                                   id  \
# 0    unknown  0004806f96307e317d116040af5b7861_11
# 1    unknown  0004806f96307e317d116040af5b7861_12
# 2    unknown  0004806f96307e317d116040af5b7861_13
# 3    unknown   0004806f96307e317d116040af5b7861_2
# 4    unknown   0004806f96307e317d116040af5b7861_3
#
#                                   chord_progressions track_role
# 0  [[Am, Am, C, C, F, F, Am, Am, B, B, G, G, B, B...    unknown
# 1  [[F, F, F, F, A, A, A, A, C, C, G, G, F, F, F,...    unknown
# 2  [[Dm, Dm, Dm, Dm, F, F, F, F, B, B, G, G, Dm, ...    unknown
# 3  [[Dm, Dm, Dm, Dm, F, F, Am, Am, Am, Am, G, G, ...    unknown
# 4  [[C, C, G, G, A, A, C, C, A, A, G, G, G, G, C,...    unknown

# %%
# randomize 10% of the dataset for validation
musicMIDI_meta_val = musicMIDI_meta.sample(frac=.10, random_state=3463)

# remove validation data from training data
musicMIDI_meta = musicMIDI_meta.drop(musicMIDI_meta_val.index)

# label the split data column with train and val
musicMIDI_meta['split_data'] = 'train'
musicMIDI_meta_val['split_data'] = 'val'

# combine the data
musicMIDI_meta = pd.concat([musicMIDI_meta, musicMIDI_meta_val])
musicMIDI_meta = musicMIDI_meta.reset_index(drop=True)
musicMIDI_meta.head()
# Out:
#   audio_key pitch_range  num_measures  bpm       genre track_roll  \
# 0    cmajor     unknown            10  192  electronic    unknown
# 1    fmajor     unknown             7  112  electronic    unknown
# 2    fmajor     unknown            12  163  electronic    unknown
# 3    aminor     unknown            11  179  electronic    unknown
# 4    dminor     unknown             7  112  electronic    unknown
#
#                inst sample_rhythm time_signature  min_velocity  max_velocity  \
# 0          dulcimer       unknown            2/4            64            87
# 1     brass_section       unknown            2/4           127           127
# 2  percussive_organ       unknown            2/4            31            85
# 3       lead_square       unknown            2/4            27           113
# 4       lead_square       unknown            2/4           126           126
#
#   split_data                                   id  \
# 0      train  0004806f96307e317d116040af5b7861_11
# 1      train  0004806f96307e317d116040af5b7861_12
# 2      train  0004806f96307e317d116040af5b7861_13
# 3      train   0004806f96307e317d116040af5b7861_3
# 4      train   0004806f96307e317d116040af5b7861_5
#
#                                   chord_progressions track_role
# 0  [[Am, Am, C, C, F, F, Am, Am, B, B, G, G, B, B...    unknown
# 1  [[F, F, F, F, A, A, A, A, C, C, G, G, F, F, F,...    unknown
# 2  [[Dm, Dm, Dm, Dm, F, F, F, F, B, B, G, G, Dm, ...    unknown
# 3  [[C, C, G, G, A, A, C, C, A, A, G, G, G, G, C,...    unknown
# 4  [[D, D, D, D, F, F, A, A, A, A, G, G, D, D, D,...    unknown

# %%
# move the files to the correct folder
# move the data to the respective folder
full_data_dir = f"{DATA_DIR}/processed_musicMIDI/raw_updated"
train_dir = f"{DATA_DIR}/meta_midi/train/raw"
val_dir = f"{DATA_DIR}/meta_midi/val/raw"

# create the folder if not exist
# check if the folder exist:
# if not create the folder
# else do nothing
if not os.path.exists(train_dir):
    os.makedirs(train_dir)
if not os.path.exists(val_dir):
    os.makedirs(val_dir)


# copy the data using the split_data column
for i, row in tqdm(musicMIDI_meta.iterrows()):
    try:
        # copy the file and replace underscore with hyphen
        # also replace the id with same structure
        if row['split_data'] == 'train':
            shutil.copy(f"{full_data_dir}/{row['id']}.mid", f"{train_dir}/{row['id'].replace('_', '-')}.mid")
            musicMIDI_meta.loc[i, 'id'] = row['id'].replace('_', '-')
        elif row['split_data'] == 'val':
            shutil.copy(f"{full_data_dir}/{row['id']}.mid", f"{val_dir}/{row['id'].replace('_', '-')}.mid")
            musicMIDI_meta.loc[i, 'id'] = row['id'].replace('_', '-')
    except Exception as e:
        print(e)
        pass
# Out:
# 0it [00:00, ?it/s]

# %%
musicMIDI_meta.to_csv(f"{DATA_DIR}/midi_metadata_file_cleaned.csv", index=False)

# %%
# append the commu dataframe and 
master_midi = pd.concat([commu_meta, musicMIDI_meta], axis=0)
# create a new feature with unique chord/note
master_midi['unique_chord_n_note'] = master_midi['chord_progressions'].apply(lambda x: list(set(x[0])))
master_midi.head()
# Out:
#   audio_key                                 chord_progressions pitch_range  \
# 0    aminor  [[Am, Am, Am, Am, Am, Am, Am, Am, C, C, C, C, ...         mid
# 1    cmajor  [[C, C, C, C, C, C, C, C, Dm, Dm, Dm, Dm, Dm, ...     mid_low
# 2    aminor  [[Am, Am, Am, Am, Am, Am, Am, Am, Am, Am, Am, ...    mid_high
# 3    cmajor  [[C, C, C, C, C, C, C, C, Gm, Gm, Gm, Gm, Gm, ...         mid
# 4    aminor  [[Am, Am, Am, Am, Em, Em, Em, Em, F, F, F, F, ...     mid_low
#
#    num_measures  bpm      genre     track_role             inst sample_rhythm  \
# 0             8  120  cinematic    main_melody  string_ensemble      standard
# 1             8   80     newage  accompaniment   acoustic_piano      standard
# 2             8  150  cinematic           riff    string_violin      standard
# 3             8  110  cinematic            pad            choir      standard
# 4             4   60  cinematic            pad   acoustic_piano      standard
#
#   time_signature  min_velocity  max_velocity split_data          id  \
# 0            4/4           101           102      train  commu00001
# 1            4/4            23            30      train  commu00002
# 2            4/4           123           127      train  commu00003
# 3            4/4            45            46      train  commu00004
# 4            4/4            21            22      train  commu00005
#
#   track_roll    unique_chord_n_note
# 0        NaN      [Am, G, Dm, C, D]
# 1        NaN  [Am, Dm, G, C, G7, F]
# 2        NaN         [F, E+, E, Am]
# 3        NaN  [A#, Dm, G, C, F, Gm]
# 4        NaN            [Em, F, Am]

# %%
master_midi.to_csv(f"{DATA_DIR}/master_midi_meta.csv", index=False)

# %%
isnt_df = musicMIDI_meta.groupby('inst').count().sort_values(by='id', ascending=False)
genre_df = musicMIDI_meta.groupby('genre').count().sort_values(by='id', ascending=False)

# %%
isnt_df
# Out:
#                        audio_key  pitch_range  num_measures   bpm  genre  \
# inst
# ensemble                    4697         4697          4697  4697   4697
# overdriven_guitar           3982         3982          3982  3982   3982
# acoustic_bass               3393         3393          3393  3393   3393
# acoustic_guitar_nylon       3230         3230          3230  3230   3230
# electric_guitar_muted       3124         3124          3124  3124   3124
# ...                          ...          ...           ...   ...    ...
# helicopter                    20           20            20    20     20
# telephone_ring                16           16            16    16     16
# tinkle_bell                   15           15            15    15     15
# fiddle                        14           14            14    14     14
# seashore                      14           14            14    14     14
#
#                        track_roll  sample_rhythm  time_signature  \
# inst
# ensemble                     4697           4697            4697
# overdriven_guitar            3982           3982            3982
# acoustic_bass                3393           3393            3393
# acoustic_guitar_nylon        3230           3230            3230
# electric_guitar_muted        3124           3124            3124
# ...                           ...            ...             ...
# helicopter                     20             20              20
# telephone_ring                 16             16              16
# tinkle_bell                    15             15              15
# fiddle                         14             14              14
# seashore                       14             14              14
#
#                        min_velocity  max_velocity  split_data    id  \
# inst
# ensemble                       4697          4697        4697  4697
# overdriven_guitar              3982          3982        3982  3982
# acoustic_bass                  3393          3393        3393  3393
# acoustic_guitar_nylon          3230          3230        3230  3230
# electric_guitar_muted          3124          3124        3124  3124
# ...                             ...           ...         ...   ...
# helicopter                       20            20          20    20
# telephone_ring                   16            16          16    16
# tinkle_bell                      15            15          15    15
# fiddle                           14            14          14    14
# seashore                         14            14          14    14
#
#                        chord_progressions  track_role
# inst
# ensemble                             4697        4697
# overdriven_guitar                    3982        3982
# acoustic_bass                        3393        3393
# acoustic_guitar_nylon                3230        3230
# electric_guitar_muted                3124        3124
# ...                                   ...         ...
# helicopter                             20          20
# telephone_ring                         16          16
# tinkle_bell                            15          15
# fiddle                                 14          14
# seashore                               14          14
#
# [122 rows x 14 columns]

# %%
genre_df
# Out:
#                     audio_key  pitch_range  num_measures    bpm  track_roll  \
# genre
# rock                    19972        19972         19972  19972       19972
# pop                     12929        12929         12929  12929       12929
# metal                    3908         3908          3908   3908        3908
# classical                3416         3416          3416   3416        3416
# electronic               3345         3345          3345   3345        3345
# dance                    2656         2656          2656   2656        2656
# country                  2602         2602          2602   2602        2602
# soul                     1955         1955          1955   1955        1955
# oldie                    1620         1620          1620   1620        1620
# jazz                     1417         1417          1417   1417        1417
# folk                      888          888           888    888         888
# folk_world_country        786          786           786    786         786
# instrumental              779          779           779    779         779
# reggae                    680          680           680    680         680
# blues                     659          659           659    659         659
# rock_pop                  650          650           650    650         650
# latin                     603          603           603    603         603
# soundtrack                522          522           522    522         522
# hiphop                    403          403           403    403         403
# funk_soul                 359          359           359    359         359
# christmas_holiday         255          255           255    255         255
# chillout                  166          166           166    166         166
# brazilian                 145          145           145    145         145
# newage                     95           95            95     95          95
# gothic                     90           90            90     90          90
# christian                  86           86            86     86          86
# childrens                  72           72            72     72          72
# jpop_jrock                 68           68            68     68          68
# rnb                        57           57            57     57          57
# posthardcore               38           38            38     38          38
# stage_screen               28           28            28     28          28
# non_music                  27           27            27     27          27
# experimental               21           21            21     21          21
# celtic                     16           16            16     16          16
# brass_military             10           10            10     10          10
# gospel                      8            8             8      8           8
# easylistening               5            5             5      5           5
#
#                      inst  sample_rhythm  time_signature  min_velocity  \
# genre
# rock                19972          19972           19972         19972
# pop                 12929          12929           12929         12929
# metal                3908           3908            3908          3908
# classical            3416           3416            3416          3416
# electronic           3345           3345            3345          3345
# dance                2656           2656            2656          2656
# country              2602           2602            2602          2602
# soul                 1955           1955            1955          1955
# oldie                1620           1620            1620          1620
# jazz                 1417           1417            1417          1417
# folk                  888            888             888           888
# folk_world_country    786            786             786           786
# instrumental          779            779             779           779
# reggae                680            680             680           680
# blues                 659            659             659           659
# rock_pop              650            650             650           650
# latin                 603            603             603           603
# soundtrack            522            522             522           522
# hiphop                403            403             403           403
# funk_soul             359            359             359           359
# christmas_holiday     255            255             255           255
# chillout              166            166             166           166
# brazilian             145            145             145           145
# newage                 95             95              95            95
# gothic                 90             90              90            90
# christian              86             86              86            86
# childrens              72             72              72            72
# jpop_jrock             68             68              68            68
# rnb                    57             57              57            57
# posthardcore           38             38              38            38
# stage_screen           28             28              28            28
# non_music              27             27              27            27
# experimental           21             21              21            21
# celtic                 16             16              16            16
# brass_military         10             10              10            10
# gospel                  8              8               8             8
# easylistening           5              5               5             5
#
#                     max_velocity  split_data     id  chord_progressions  \
# genre
# rock                       19972       19972  19972               19972
# pop                        12929       12929  12929               12929
# metal                       3908        3908   3908                3908
# classical                   3416        3416   3416                3416
# electronic                  3345        3345   3345                3345
# dance                       2656        2656   2656                2656
# country                     2602        2602   2602                2602
# soul                        1955        1955   1955                1955
# oldie                       1620        1620   1620                1620
# jazz                        1417        1417   1417                1417
# folk                         888         888    888                 888
# folk_world_country           786         786    786                 786
# instrumental                 779         779    779                 779
# reggae                       680         680    680                 680
# blues                        659         659    659                 659
# rock_pop                     650         650    650                 650
# latin                        603         603    603                 603
# soundtrack                   522         522    522                 522
# hiphop                       403         403    403                 403
# funk_soul                    359         359    359                 359
# christmas_holiday            255         255    255                 255
# chillout                     166         166    166                 166
# brazilian                    145         145    145                 145
# newage                        95          95     95                  95
# gothic                        90          90     90                  90
# christian                     86          86     86                  86
# childrens                     72          72     72                  72
# jpop_jrock                    68          68     68                  68
# rnb                           57          57     57                  57
# posthardcore                  38          38     38                  38
# stage_screen                  28          28     28                  28
# non_music                     27          27     27                  27
# experimental                  21          21     21                  21
# celtic                        16          16     16                  16
# brass_military                10          10     10                  10
# gospel                         8           8      8                   8
# easylistening                  5           5      5                   5
#
#                     track_role
# genre
# rock                     19972
# pop                      12929
# metal                     3908
# classical                 3416
# electronic                3345
# dance                     2656
# country                   2602
# soul                      1955
# oldie                     1620
# jazz                      1417
# folk                       888
# folk_world_country         786
# instrumental               779
# reggae                     680
# blues                      659
# rock_pop                   650
# latin                      603
# soundtrack                 522
# hiphop                     403
# funk_soul                  359
# christmas_holiday          255
# chillout                   166
# brazilian                  145
# newage                      95
# gothic                      90
# christian                   86
# childrens                   72
# jpop_jrock                  68
# rnb                         57
# posthardcore                38
# stage_screen                28
# non_music                   27
# experimental                21
# celtic                      16
# brass_military              10
# gospel                       8
# easylistening                5

# %%
# plot inverted bar chart
plt.clf()
plt.figure(figsize=(14,6))
sns.barplot(x=genre_df.index, y=genre_df['id'])
plt.title('Genre Distribution')
plt.xlabel('Genre')
plt.ylabel('Number of Songs')
plt.xticks(rotation=90)
#plt.savefig(f"{DATA_DIR}/genre_dist.png", bbox_inches='tight')
plt.show()

# %%
# plot inverted bar chart
plt.clf()
plt.figure(figsize=(14,6))
sns.barplot(x=isnt_df.index, y=isnt_df['id'])
plt.title('Instrument Distribution')
plt.xlabel('Instrument')
plt.ylabel('Number of Songs')
plt.xticks(rotation=90)
#plt.savefig(f"{DATA_DIR}/genre_dist.png", bbox_inches='tight')
plt.show()

# %%
# number of unique instruments
len(musicMIDI_meta.groupby('inst').count().index)
# Out:
# 122

# %% [markdown]
# # Applying Cosine Similarity to Group Instruments

# %%
import gensim.downloader

# Show all available models in gensim-data
print(list(gensim.downloader.info()['models'].keys()))
# Out:
# ['fasttext-wiki-news-subwords-300', 'conceptnet-numberbatch-17-06-300', 'word2vec-ruscorpora-300', 'word2vec-google-news-300', 'glove-wiki-gigaword-50', 'glove-wiki-gigaword-100', 'glove-wiki-gigaword-200', 'glove-wiki-gigaword-300', 'glove-twitter-25', 'glove-twitter-50', 'glove-twitter-100', 'glove-twitter-200', '__testing_word2vec-matrix-synopsis']

# %%
# get the word2vec model
embed_vectors = gensim.downloader.load('glove-wiki-gigaword-300')

# %%
#Current Instrument Map
INST_MAP = {
    "accordion": 1,
    "acoustic_bass": 3,
    "acoustic_guitar": 3,
    "acoustic_piano": 0,
    "banjo": 3,
    "bassoon": 5,
    "bell": 2,
    "brass_ensemble": 5,
    "celesta": 2,
    "choir": 7,
    "clarinet": 5,
    "drums_full": 6,
    "drums_tops": 6,
    "electric_bass": 3,
    "electric_guitar_clean": 3,
    "electric_guitar_distortion": 3,
    "electric_piano": 0,
    "fiddle": 4,
    "flute": 5,
    "glockenspiel": 2,
    "harp": 3,
    "harpsichord": 0,
    "horn": 5,
    "keyboard": 0,
    "mandolin": 3,
    "marimba": 2,
    "nylon_guitar": 3,
    "oboe": 5,
    "organ": 0,
    "oud": 3,
    "pad_synth": 4,
    "percussion": 6,
    "recorder": 5,
    "sitar": 3,
    "string_cello": 4,
    "string_double_bass": 4,
    "string_ensemble": 4,
    "string_viola": 4,
    "string_violin": 4,
    "synth_bass": 3,
    "synth_bass_808": 3,
    "synth_bass_wobble": 3,
    "synth_bell": 2,
    "synth_lead": 1,
    "synth_pad": 4,
    "synth_pluck": 7,
    "synth_voice": 7,
    "timpani": 6,
    "trombone": 5,
    "trumpet": 5,
    "tuba": 5,
    "ukulele": 3,
    "vibraphone": 2,
    "whistle": 7,
    "xylophone": 2,
    "zither": 3,
    "orgel": 2,
    "synth_brass": 5,
    "sax": 5,
    "bamboo_flute": 5,
    "yanggeum": 3,
    "vocal": 8,
}
len(INST_MAP.keys())
# Out:
# 62

# %%
# inverted index of the instrument map
# make the value the list of all instrument with the same numerical value
INV_INST_MAP = {}
for k, v in INST_MAP.items():
    if v not in INV_INST_MAP:
        INV_INST_MAP[v] = [k]
    else:
        INV_INST_MAP[v].append(k)

# get all keys 
current_inst = list(INST_MAP.keys())
current_inst.sort()
current_inst[:5]
# Out:
# ['accordion',
#  'acoustic_bass',
#  'acoustic_guitar',
#  'acoustic_piano',
#  'bamboo_flute']

# %%
# for each key in the current instrument map, split by underscore
splitted_inst = [inst.split('_') for inst in current_inst]

# for each splitted instrument, get the word2vec embedding
# if more than 1 word, get the sum of the embedding
# else get the embedding of the word
# store the embedding in a dictionary
inst_embedding = {}
for inst in splitted_inst:
    try:

        if len(inst) > 1:
            inst_embedding['_'.join(inst)] = np.sum([embed_vectors[word] for word in inst], axis=0)
        else:
            inst_embedding[inst[0]] = embed_vectors[inst[0]]
    except Exception as e:
        print(inst, e)
        pass

inst_embedding
# Out:
# ['yanggeum'] "Key 'yanggeum' not present"
# {'accordion': array([ 5.4066e-02,  6.4252e-01, -1.6742e-01, -3.0200e-01,  4.1525e-02,
#         -3.8896e-01, -1.8712e-01, -6.2862e-01,  2.1323e-01,  5.4814e-01,
#         -3.2976e-01,  3.3419e-01,  1.3399e-01, -6.3567e-01, -3.3802e-01,
#          1.0567e-01, -9.8030e-01,  2.6125e-02,  5.1448e-01,  4.4460e-02,
#          5.4924e-02,  8.4102e-02, -2.9315e-01,  9.1574e-01,  4.8669e-01,
#          2.8756e-01, -2.9339e-01,  7.1730e-02,  3.8698e-01, -2.9433e-01,
#          7.4752e-01,  3.7514e-01, -6.3231e-01,  4.0620e-01,  2.0115e-01,
#          2.3367e-01, -1.8274e-01,  9.9160e-01,  2.0653e-01,  1.5296e-01,
#          5.5438e-01,  4.3394e-01,  9.3854e-01, -1.3379e-01, -1.2988e-01,
#          3.9755e-01,  5.5568e-02,  4.2654e-01,  9.6011e-01, -2.2333e-01,
#         -4.6336e-01, -3.5479e-01,  7.2872e-01, -3.0096e-01,  3.2694e-01,
#         -1.9725e-01,  6.4341e-01, -1.5139e-01,  6.9737e-01,  1.4645e-01,
#         -1.2764e-01, -2.9745e-01,  2.2052e-01,  2.7520e-01,  9.2819e-01,
#         -6.5232e-01,  1.1204e-01, -4.7974e-01, -2.2538e-01, -5.0053e-01,
#          6.9048e-03,  3.8796e-01, -5.7697e-01, -2.7360e-01,  3.4913e-01,
#         -1.8976e-01, -3.0362e-01, -5.3832e-01,  2.2821e-01,  1.6175e-01,
#          8.6587e-01,  4.5296e-01, -2.2505e-01, -6.1512e-02, -3.4890e-01,
#         -2.5290e-01,  9.4623e-01, -4.4209e-01,  1.1138e-01,  5.3565e-02],
#        dtype=float32)}

# %%
# get all available instruments in musicMIDI
# lower case all the instruments
# drop illegal instruments
musicMIDI_meta = musicMIDI_meta[~(musicMIDI_meta['inst'] != musicMIDI_meta['inst'])]
new_instuments = musicMIDI_meta['inst'].unique().tolist()

# remove parenthesis and hyphen
# replace space with underscore
new_instuments.sort()

# for each key in the current instrument map, split by underscore
new_splitted_inst = [inst.split('_') for inst in new_instuments]
new_splitted_inst[:5]
# Out:
# [['accordion'],
#  ['acoustic', 'bass'],
#  ['acoustic', 'grand', 'piano'],
#  ['acoustic', 'guitar', 'nylon'],
#  ['acoustic', 'guitar', 'steel']]

# %%
# for each splitted instrument, get the word2vec embedding
# if more than 1 word, get the sum of the embedding
# else get the embedding of the word
# store the embedding in a dictionary
new_inst_embedding = {}
for inst in new_splitted_inst:
    try:
        if len(inst) > 1:
            new_inst_embedding['_'.join(inst)] = np.sum([embed_vectors[word] for word in inst], axis=0)
        else:
            new_inst_embedding[inst[0]] = embed_vectors[inst[0]]
    except Exception as e:
        print(inst, e)
        pass

new_inst_embedding
# Out:
# ['clavi'] "Key 'clavi' not present"
# ['lead', 'charang'] "Key 'charang' not present"
# ['lead', 'chiff'] "Key 'chiff' not present"
# ['pad', 'polysynth'] "Key 'polysynth' not present"
# ['shanai'] "Key 'shanai' not present"
# ['synthbrass'] "Key 'synthbrass' not present"
# ['synthstrings'] "Key 'synthstrings' not present"
#          0.098803 ,  0.9492   , -0.93831  ,  0.067655 ,  0.57324  ,
#         -0.059799 , -0.41556  ,  0.4      , -0.36435  , -0.28532  ,
#          0.32902  ,  0.069345 ,  0.16215  , -0.15349  , -0.37339  ,
#          0.098611 ,  0.25996  ,  0.24959  , -0.19028  , -0.45637  ,
#         -0.15375  ,  0.011768 ,  0.72536  ,  0.028268 , -0.31127  ,
#         -0.23432  ,  0.14253  ,  0.50685  , -0.51795  ,  0.10215  ,
#          0.27097  , -0.095127 ,  0.18312  ,  0.13134  ,  0.32827  ,
#         -0.28561  , -0.094822 , -0.23221  , -0.92804  , -0.42768  ,
#          0.39035  , -0.15496  , -0.78805  , -0.10057  ,  0.46683  ,
#         -0.031749 , -0.32448  ,  0.0449   , -0.085787 , -0.43964  ,
#          0.52202  ,  0.25963  ,  0.028026 ,  0.098617 , -0.57027  ,
#         -0.22518  ,  0.29414  , -0.20877  ,  0.46012  ,  0.036229 ],
#        dtype=float32)}

# %%
# compute a list of all possible permutations
import itertools

# for each instrument between the new and old instrument map
# compute the cosine similarity
pair_wise_similarity = []
for inst_1, inst_2 in itertools.product(inst_embedding.keys(), new_inst_embedding.keys()):
    # if inst_1 == inst_2:
        # continue
    cosine = np.dot(inst_embedding[inst_1], new_inst_embedding[inst_2])/(np.linalg.norm(inst_embedding[inst_1])*np.linalg.norm(new_inst_embedding[inst_2]))
    pair_wise_similarity.append([inst_2, inst_1, cosine])

# aggregate the cosine similarity into a dataframe
pair_wise_similarity_df = pd.DataFrame(pair_wise_similarity, columns=['new_isnt', 'current_inst', 'cosine_similarity'])

best_similarity = []
# for each new instrument, get the instrument with the highest cosine similarity
for new_inst, similarity_df in pair_wise_similarity_df.groupby('new_isnt'):
    best_similarity.append(similarity_df.sort_values('cosine_similarity', ascending=False).iloc[0].tolist())

best_similarity_df = pd.DataFrame(best_similarity, columns=['new_isnt', 'current_inst', 'cosine_similarity'])
best_similarity_df['inst_map'] = best_similarity_df['current_inst'].apply(lambda x: INST_MAP[x])
best_similarity_df
# Out:
#                   new_isnt     current_inst  cosine_similarity  inst_map
# 0                accordion        accordion           1.000000         1
# 1            acoustic_bass    acoustic_bass           1.000000         3
# 2     acoustic_grand_piano   acoustic_piano           0.875669         0
# 3    acoustic_guitar_nylon     nylon_guitar           0.929281         3
# 4    acoustic_guitar_steel  acoustic_guitar           0.898544         3
# ..                     ...              ...                ...       ...
# 110                 violin    string_violin           0.852045         4
# 111             voice_oohs      synth_voice           0.581818         7
# 112                whistle          whistle           1.000000         7
# 113              woodblock      harpsichord           0.264353         0
# 114              xylophone        xylophone           1.000000         2
#
# [115 rows x 4 columns]

# %%
# for instrument that are not in the current instrument map,
# manually assesst the similarity and fill the instrument map accordingly 
inst_not_available = []
for inst in musicMIDI_meta['inst'].unique():
    if inst not in best_similarity_df['new_isnt'].unique():
        inst_not_available.append(inst)
inst_not_available
# Out:
# ['pad_polysynth',
#  'synthstrings',
#  'synthbrass',
#  'clavi',
#  'lead_chiff',
#  'lead_charang',
#  'shanai']

# %%
non_similarity_mapping = { 
    "synthbrass": 5,
    "synthstrings": 4,
    "shanai": 5,
    "clavi": 1,
    "pad_polysynth": 1,
    "lead_charang": 3,
    "lead_chiff": 0
}

NEW_INST_MAP = best_similarity_df[['new_isnt', 'inst_map']].set_index('new_isnt').to_dict()
NEW_INST_MAP=NEW_INST_MAP['inst_map']
NEW_INST_MAP.update(non_similarity_mapping)
NEW_INST_MAP
# Out:
# {'accordion': 1,
#  'acoustic_bass': 3,
#  'acoustic_grand_piano': 0,
#  'acoustic_guitar_nylon': 3,
#  'acoustic_guitar_steel': 3,
#  'agogo': 2,
#  'alto_sax': 5,
#  'applause': 8,
#  'bagpipe': 1,
#  'banjo': 3,
#  'baritone_sax': 5,
#  'bassoon': 5,
#  'bird_tweet': 2,
#  'blown_bottle': 7,
#  'brass_section': 5,
#  'breath_noise': 3,
#  'bright_acoustic_piano': 0,
#  'celesta': 2,
#  'cello': 4,
#  'choir_aahs': 7,
#  'church_organ': 0,
#  'clarinet': 5,
#  'contrabass': 5,
#  'distortion_guitar': 3,
#  'drawbar_organ': 0,
#  'dulcimer': 3,
#  'electric_bass_finger': 3,
#  'electric_bass_pick': 3,
#  'electric_grand_piano': 0,
#  'electric_guitar_clean': 3,
#  'electric_guitar_jazz': 0,
#  'electric_guitar_muted': 3,
#  'electric_piano': 0,
#  'english_horn': 5,
#  'ensemble': 5,
#  'fiddle': 4,
#  'flute': 5,
#  'french_horn': 5,
#  'fretless_bass': 3,
#  'fx_atmosphere': 3,
#  'fx_brightness': 7,
#  'fx_crystal': 5,
#  'fx_echoes': 7,
#  'fx_goblins': 7,
#  'fx_rain': 1,
#  'fx_scifi': 7,
#  'fx_soundtrack': 3,
#  'glockenspiel': 2,
#  'guitar_fret_noise': 3,
#  'guitar_harmonics': 3,
#  'harmonica': 3,
#  'harpsichord': 0,
#  'helicopter': 2,
#  'honkytonk_piano': 0,
#  'kalimba': 2,
#  'koto': 3,
#  'lead_bass_+_lead': 1,
#  'lead_calliope': 1,
#  'lead_fifths': 1,
#  'lead_sawtooth': 1,
#  'lead_square': 1,
#  'lead_voice': 1,
#  'marimba': 2,
#  'melodic_tom': 3,
#  'music_box': 0,
#  'muted_trumpet': 5,
#  'oboe': 5,
#  'ocarina': 2,
#  'orchestra_hit': 4,
#  'orchestral_harp': 3,
#  'overdriven_guitar': 3,
#  'pad_bowed': 4,
#  'pad_choir': 7,
#  'pad_halo': 4,
#  'pad_metallic': 4,
#  'pad_new_age': 4,
#  'pad_sweep': 4,
#  'pad_warm': 4,
#  'pan_flute': 5,
#  'percussive_organ': 0,
#  'piccolo': 5,
#  'pizzicato_strings': 4,
#  'recorder': 5,
#  'reed_organ': 0,
#  'reverse_cymbal': 4,
#  'rock_organ': 0,
#  'seashore': 3,
#  'shakuhachi': 5,
#  'shamisen': 3,
#  'sitar': 3,
#  'slap_bass': 3,
#  'soprano_sax': 5,
#  'steel_drums': 6,
#  'string_ensemble': 4,
#  'synth_bass': 3,
#  'synth_drum': 3,
#  'synth_voice': 7,
#  'taiko_drum': 6,
#  'tango_accordion': 1,
#  'telephone_ring': 2,
#  'tenor_sax': 5,
#  'timpani': 6,
#  'tinkle_bell': 2,
#  'tremolo_strings': 3,
#  'trombone': 5,
#  'trumpet': 5,
#  'tuba': 5,
#  'tubular_bells': 2,
#  'vibraphone': 2,
#  'viola': 4,
#  'violin': 4,
#  'voice_oohs': 7,
#  'whistle': 7,
#  'woodblock': 0,
#  'xylophone': 2,
#  'synthbrass': 5,
#  'synthstrings': 4,
#  'shanai': 5,
#  'clavi': 1,
#  'pad_polysynth': 1,
#  'lead_charang': 3,
#  'lead_chiff': 0}

# %%
# # MAP all keys with synth to synnthetic group 1 using regex
# synth_group = {k: v for k, v in NEW_INST_MAP.items() if not k.find('synth')}
# synth_group

# %%
# define updated instrument grouping
INST_GROUP = {
    0: 'keyboard',
    1: 'accordian',
    2: 'bell',
    3: 'guitar',
    4: 'string',
    5: 'brass',
    6: 'percussion',
    7: 'choir',
    8: 'vocal',
    9: 'ensemble'
}

# %%
# replace ensemble with a new category
# update the original inst map
NEW_INST_MAP['ensemble'] = 9
INST_MAP.update(NEW_INST_MAP)
print(len(INST_MAP.keys()))
# Out:
# 158

# %%
# check to see if all instruments are mapped
# inverted index of the instrument map
# make the value the list of all instrument with the same numerical value
INV_INST_MAP = {}
for k, v in INST_MAP.items():
    if v not in INV_INST_MAP:
        INV_INST_MAP[v] = [k]
    else:
        INV_INST_MAP[v].append(k)

# get all keys 
INV_INST_MAP[8]
# Out:
# ['vocal', 'applause']

# %%
# map the new dictionary to the musicMIDI_meta dataframe
master_midi['inst_mapping'] = master_midi['inst'].map(INST_MAP)
master_midi['updated_inst'] = master_midi['inst_mapping'].map(INST_GROUP)
master_midi[(master_midi['inst_mapping'] != master_midi['inst_mapping'])]


musicMIDI_meta['inst_mapping'] = musicMIDI_meta['inst'].map(INST_MAP)
musicMIDI_meta['updated_inst'] = musicMIDI_meta['inst_mapping'].map(INST_GROUP)
musicMIDI_meta[(musicMIDI_meta['inst_mapping'] != musicMIDI_meta['inst_mapping'])]
# Out:
# Empty DataFrame
# Columns: [audio_key, pitch_range, num_measures, bpm, genre, track_roll, inst, sample_rhythm, time_signature, min_velocity, max_velocity, split_data, id, chord_progressions, track_role, inst_mapping, updated_inst]
# Index: []

# %%
# map the new dictionary to the musicMIDI_meta dataframe
master_midi['inst_mapping'] = master_midi['inst'].map(INST_MAP)
master_midi['updated_inst'] = master_midi['inst_mapping'].map(INST_GROUP)
master_midi = master_midi[~(master_midi['inst_mapping'] != master_midi['inst_mapping'])]


musicMIDI_meta['inst_mapping'] = musicMIDI_meta['inst'].map(INST_MAP)
musicMIDI_meta['updated_inst'] = musicMIDI_meta['inst_mapping'].map(INST_GROUP)
musicMIDI_meta = musicMIDI_meta[~(musicMIDI_meta['inst_mapping'] != musicMIDI_meta['inst_mapping'])]

# master_midi.groupby(['inst_mapping', 'updated_inst']).count().sort_values(by='id', ascending=False)

# %% [markdown]
# # Instrument Mapping

# %%
import json

# save the instrument map
with open(f"{DATA_DIR}/instrument_map.json", 'w') as f:
    f.write(json.dumps(INST_MAP, indent=4))

# %% [markdown]
# # Genre Mapping
# Map the current genre list to the list of top suggest genre. Goal is to overall decreases the musical instrument

# %%
# Read In the Genre Changes
genre_changes = pd.read_excel(f"{DATA_DIR}/Instrument and Genre Changes.xlsx", sheet_name='Recommendations')
genre_mapping = genre_changes[['Original', 'Recommended']].set_index('Original').to_dict()['Recommended']
genre_mapping
# Out:
# {'blues': 'jazz',
#  'brass_military': 'country',
#  'brazilian': 'country',
#  'celtic': 'folk',
#  'childrens': 'filter out',
#  'chillout': 'jazz',
#  'christian': 'country',
#  'christmas_holiday': 'country',
#  'cinematic': 'classical',
#  'classical': 'classical',
#  'country': 'country',
#  'dance': 'dance',
#  'easylistening': 'country',
#  'electronic': 'electronic',
#  'experimental': 'electronic',
#  'folk': 'folk',
#  'folk_world country': 'folk',
#  'folk_world_country': 'folk',
#  'funk_soul': 'jazz',
#  'gospel': 'soul',
#  'gothic': 'classical',
#  'hiphop': 'oldie',
#  'instrumental': 'instrumental',
#  'jazz': 'jazz',
#  'jpop_jrock': 'pop',
#  'latin': 'classical',
#  'metal': 'metal',
#  'neofolk': 'folk',
#  'new age': 'classical',
#  'newage': 'classical',
#  'non_music': 'filter out',
#  'oldie': 'oldie',
#  'pop': 'pop',
#  'post hardcore': 'rock',
#  'posthardcore': 'rock',
#  'reggae': 'pop',
#  'rnb': 'pop',
#  'rock': 'rock',
#  'rock_pop': 'rock',
#  'soul': 'soul',
#  'soundtrack': 'instrumental',
#  'stage_screen': 'instrumental'}

# %%
# map the old genre to the new genre
master_midi['updated_genre'] = master_midi['genre'].map(genre_mapping)
musicMIDI_meta['updated_genre'] = musicMIDI_meta['genre'].map(genre_mapping)

# %%
# filtered out some unwanted genre
master_midi = master_midi[~(master_midi['updated_genre'] != master_midi['updated_genre'])]
master_midi = master_midi[master_midi['updated_genre'] != 'filter out']

# filtered out some unwanted genre
musicMIDI_meta = musicMIDI_meta[~(musicMIDI_meta['updated_genre'] != musicMIDI_meta['updated_genre'])]
musicMIDI_meta = musicMIDI_meta[musicMIDI_meta['updated_genre'] != 'filter out']

# %%
master_midi.groupby(['updated_genre']).count().sort_values(by='id', ascending=False)
# Out:
#                audio_key  chord_progressions  pitch_range  num_measures  \
# updated_genre
# rock               20660               20660        20660         20660
# classical          15348               15348        15348         15348
# pop                13734               13734        13734         13734
# metal               3908                3908         3908          3908
# electronic          3366                3366         3366          3366
# country             3103                3103         3103          3103
# dance               2656                2656         2656          2656
# jazz                2601                2601         2601          2601
# oldie               2023                2023         2023          2023
# soul                1963                1963         1963          1963
# folk                1690                1690         1690          1690
# instrumental        1329                1329         1329          1329
#
#                  bpm  genre  track_role   inst  sample_rhythm  time_signature  \
# updated_genre
# rock           20660  20660       20660  20660          20660           20660
# classical      15348  15348       15348  15348          15348           15348
# pop            13734  13734       13734  13734          13734           13734
# metal           3908   3908        3908   3908           3908            3908
# electronic      3366   3366        3366   3366           3366            3366
# country         3103   3103        3103   3103           3103            3103
# dance           2656   2656        2656   2656           2656            2656
# jazz            2601   2601        2601   2601           2601            2601
# oldie           2023   2023        2023   2023           2023            2023
# soul            1963   1963        1963   1963           1963            1963
# folk            1690   1690        1690   1690           1690            1690
# instrumental    1329   1329        1329   1329           1329            1329
#
#                min_velocity  max_velocity  split_data     id  track_roll  \
# updated_genre
# rock                  20660         20660       20660  20660       20660
# classical             15348         15348       15348  15348        4204
# pop                   13734         13734       13734  13734       13734
# metal                  3908          3908        3908   3908        3908
# electronic             3366          3366        3366   3366        3366
# country                3103          3103        3103   3103        3103
# dance                  2656          2656        2656   2656        2656
# jazz                   2601          2601        2601   2601        2601
# oldie                  2023          2023        2023   2023        2023
# soul                   1963          1963        1963   1963        1963
# folk                   1690          1690        1690   1690        1690
# instrumental           1329          1329        1329   1329        1329
#
#                unique_chord_n_note  inst_mapping  updated_inst
# updated_genre
# rock                         20660         20660         20660
# classical                    15348         15348         15348
# pop                          13734         13734         13734
# metal                         3908          3908          3908
# electronic                    3366          3366          3366
# country                       3103          3103          3103
# dance                         2656          2656          2656
# jazz                          2601          2601          2601
# oldie                         2023          2023          2023
# soul                          1963          1963          1963
# folk                          1690          1690          1690
# instrumental                  1329          1329          1329

# %%
# process genre map
genre_list = list(master_midi['updated_genre'].unique())
genre_list.sort()

# create a dictionary per genre and map it with a number starting with 2
# 0 is reserved for unknown
# 1 is reserved for other
GENRE_MAP = {}
for i, genre in enumerate(genre_list):
    GENRE_MAP[genre] = i

master_midi['genre_mapping'] = master_midi['updated_genre'].map(GENRE_MAP)
musicMIDI_meta['genre_mapping'] = musicMIDI_meta['updated_genre'].map(GENRE_MAP)

# %%
GENRE_MAP = master_midi[['genre', 'genre_mapping']].set_index('genre').to_dict()['genre_mapping']
GENRE_MAP
# Out:
# {'cinematic': 0,
#  'newage': 0,
#  'electronic': 3,
#  'pop': 9,
#  'chillout': 6,
#  'rock': 10,
#  'classical': 0,
#  'country': 1,
#  'latin': 0,
#  'metal': 7,
#  'christmas_holiday': 1,
#  'folk_world_country': 4,
#  'dance': 2,
#  'instrumental': 5,
#  'soul': 11,
#  'rock_pop': 10,
#  'soundtrack': 5,
#  'reggae': 9,
#  'jazz': 6,
#  'brazilian': 1,
#  'folk': 4,
#  'blues': 6,
#  'funk_soul': 6,
#  'oldie': 8,
#  'hiphop': 8,
#  'gothic': 0,
#  'jpop_jrock': 9,
#  'posthardcore': 10,
#  'experimental': 3,
#  'rnb': 9,
#  'stage_screen': 5,
#  'christian': 1,
#  'easylistening': 1,
#  'brass_military': 1,
#  'gospel': 11,
#  'celtic': 4}

# %%
with open(f"{DATA_DIR}/genre_map.json", 'w') as f:
    f.write(json.dumps(GENRE_MAP, indent=4))

# %%
# output the master_midi
master_midi.to_csv(f"{DATA_DIR}/master_midi_meta_parse.csv", index=False)
master_midi.head()
# Out:
#   audio_key                                 chord_progressions pitch_range  \
# 0    aminor  [[Am, Am, Am, Am, Am, Am, Am, Am, C, C, C, C, ...         mid
# 1    cmajor  [[C, C, C, C, C, C, C, C, Dm, Dm, Dm, Dm, Dm, ...     mid_low
# 2    aminor  [[Am, Am, Am, Am, Am, Am, Am, Am, Am, Am, Am, ...    mid_high
# 3    cmajor  [[C, C, C, C, C, C, C, C, Gm, Gm, Gm, Gm, Gm, ...         mid
# 4    aminor  [[Am, Am, Am, Am, Em, Em, Em, Em, F, F, F, F, ...     mid_low
#
#    num_measures  bpm      genre     track_role             inst sample_rhythm  \
# 0             8  120  cinematic    main_melody  string_ensemble      standard
# 1             8   80     newage  accompaniment   acoustic_piano      standard
# 2             8  150  cinematic           riff    string_violin      standard
# 3             8  110  cinematic            pad            choir      standard
# 4             4   60  cinematic            pad   acoustic_piano      standard
#
#   time_signature  min_velocity  max_velocity split_data          id  \
# 0            4/4           101           102      train  commu00001
# 1            4/4            23            30      train  commu00002
# 2            4/4           123           127      train  commu00003
# 3            4/4            45            46      train  commu00004
# 4            4/4            21            22      train  commu00005
#
#   track_roll    unique_chord_n_note  inst_mapping updated_inst updated_genre  \
# 0        NaN      [Am, G, Dm, C, D]             4       string     classical
# 1        NaN  [Am, Dm, G, C, G7, F]             0     keyboard     classical
# 2        NaN         [F, E+, E, Am]             4       string     classical
# 3        NaN  [A#, Dm, G, C, F, Gm]             7        choir     classical
# 4        NaN            [Em, F, Am]             0     keyboard     classical
#
#    genre_mapping
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
# output the master_midi
musicMIDI_meta.to_csv(f"{DATA_DIR}/midi_metadata_file_cleaned.csv", index=False)
musicMIDI_meta.head()
# Out:
#   audio_key pitch_range  num_measures  bpm       genre track_roll  \
# 0    cmajor     unknown            10  192  electronic    unknown
# 1    fmajor     unknown             7  112  electronic    unknown
# 2    fmajor     unknown            12  163  electronic    unknown
# 3    aminor     unknown            11  179  electronic    unknown
# 4    dminor     unknown             7  112  electronic    unknown
#
#                inst sample_rhythm time_signature  min_velocity  max_velocity  \
# 0          dulcimer       unknown            2/4            64            87
# 1     brass_section       unknown            2/4           127           127
# 2  percussive_organ       unknown            2/4            31            85
# 3       lead_square       unknown            2/4            27           113
# 4       lead_square       unknown            2/4           126           126
#
#   split_data                                   id  \
# 0      train  0004806f96307e317d116040af5b7861-11
# 1      train  0004806f96307e317d116040af5b7861-12
# 2      train  0004806f96307e317d116040af5b7861-13
# 3      train   0004806f96307e317d116040af5b7861-3
# 4      train   0004806f96307e317d116040af5b7861-5
#
#                                   chord_progressions track_role  inst_mapping  \
# 0  [[Am, Am, C, C, F, F, Am, Am, B, B, G, G, B, B...    unknown             3
# 1  [[F, F, F, F, A, A, A, A, C, C, G, G, F, F, F,...    unknown             5
# 2  [[Dm, Dm, Dm, Dm, F, F, F, F, B, B, G, G, Dm, ...    unknown             0
# 3  [[C, C, G, G, A, A, C, C, A, A, G, G, G, G, C,...    unknown             1
# 4  [[D, D, D, D, F, F, A, A, A, A, G, G, D, D, D,...    unknown             1
#
#   updated_inst updated_genre  genre_mapping
# 0       guitar    electronic              3
# 1        brass    electronic              3
# 2     keyboard    electronic              3
# 3    accordian    electronic              3
# 4    accordian    electronic              3
