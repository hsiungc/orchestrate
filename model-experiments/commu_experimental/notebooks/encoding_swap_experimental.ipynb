# %%
import os
import boto3
import joblib
import mido
from miditoolkit import MidiFile
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ast import literal_eval
from pathlib import Path
from tqdm.notebook import tqdm

import dotenv
dotenv.load_dotenv()

sns.set()

# %% [markdown]
# # Helper Functions

# %%
def get_pitch_range(midi):
    min_pitch = float('inf')
    max_pitch = float('-inf')

    for track in midi.instruments:
        for note in track.notes:
            min_pitch = min(min_pitch, note.pitch)
            max_pitch = max(max_pitch, note.pitch)

    return min_pitch, max_pitch

# %% [markdown]
# # Get MetaData

# %%
# read in the full metadataset
meta_df = pd.read_csv(f"../dataset/master_midi_meta_parse.csv")
meta_df
# Out:
#       audio_key                                 chord_progressions  \
# 0        aminor  [['Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'A...
# 1        cmajor  [['C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'Dm'...
# 2        aminor  [['Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'A...
# 3        cmajor  [['C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'Gm'...
# 4        aminor  [['Am', 'Am', 'Am', 'Am', 'Em', 'Em', 'Em', 'E...
# ...         ...                                                ...
# 72376    amajor  [['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A',...
# 72377    gminor  [['Gm', 'Gm', 'Gm', 'Gm', 'B', 'B', 'B', 'B', ...
# 72378    emajor  [['B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',...
# 72379   c#major  [['G#', 'G#', 'G#', 'G#', 'C#', 'C#', 'C#', 'C...
# 72380    cmajor  [['C', 'C', 'C', 'C', 'G', 'G', 'G', 'G', 'G',...
#
#       pitch_range  num_measures  bpm               genre     track_role  \
# 0             mid             8  120           cinematic    main_melody
# 1         mid_low             8   80              newage  accompaniment
# 2        mid_high             8  150           cinematic           riff
# 3             mid             8  110           cinematic            pad
# 4         mid_low             4   60           cinematic            pad
# ...           ...           ...  ...                 ...            ...
# 72376     unknown            12  169                soul        unknown
# 72377     unknown             3  100               oldie        unknown
# 72378     unknown            11  180                rock        unknown
# 72379     unknown            11  240               metal        unknown
# 72380     unknown            13  161  folk_world_country        unknown
#
#                         inst sample_rhythm time_signature  min_velocity  \
# 0            string_ensemble      standard            4/4           101
# 1             acoustic_piano      standard            4/4            23
# 2              string_violin      standard            4/4           123
# 3                      choir      standard            4/4            45
# 4             acoustic_piano      standard            4/4            21
# ...                      ...           ...            ...           ...
# 72376   electric_guitar_jazz       unknown            4/4            70
# 72377            soprano_sax       unknown            4/4           116
# 72378  bright_acoustic_piano       unknown            2/4            95
# 72379   acoustic_grand_piano       unknown            4/4            95
# 72380  acoustic_guitar_nylon       unknown            4/4            41
#
#        max_velocity split_data                                  id track_roll  \
# 0               102      train                          commu00001        NaN
# 1                30      train                          commu00002        NaN
# 2               127      train                          commu00003        NaN
# 3                46      train                          commu00004        NaN
# 4                22      train                          commu00005        NaN
# ...             ...        ...                                 ...        ...
# 72376            79        val  e34a552e87b6bb8939bc35660d2d116c-5    unknown
# 72377           116        val  d0531034be492842b6d9bb32486f6a95-1    unknown
# 72378            95        val  72b9d074542398fc021f636eb17da32b-5    unknown
# 72379            95        val  0bc159de1686720e1c0282b57a3af7e5-4    unknown
# 72380            50        val  c49cd9f3aedfdc864244330c3e1bc942-3    unknown
#
#                      unique_chord_n_note  inst_mapping updated_inst  \
# 0            ['Am', 'G', 'Dm', 'C', 'D']             4       string
# 1      ['Am', 'Dm', 'G', 'C', 'G7', 'F']             0     keyboard
# 2                 ['F', 'E+', 'E', 'Am']             4       string
# 3      ['A#', 'Dm', 'G', 'C', 'F', 'Gm']             7        choir
# 4                      ['Em', 'F', 'Am']             0     keyboard
# ...                                  ...           ...          ...
# 72376                   ['G', 'A', 'Gm']             0     keyboard
# 72377                        ['B', 'Gm']             5        brass
# 72378                              ['B']             0     keyboard
# 72379                  ['C#', 'G#', 'E']             0     keyboard
# 72380               ['F', 'D', 'G', 'C']             3       guitar
#
#       updated_genre  genre_mapping
# 0         classical              0
# 1         classical              0
# 2         classical              0
# 3         classical              0
# 4         classical              0
# ...             ...            ...
# 72376          soul             11
# 72377         oldie              8
# 72378          rock             10
# 72379         metal              7
# 72380          folk              4
#
# [72381 rows x 20 columns]

# %%
# isolate commu only code
commu_meta = meta_df[meta_df["id"].str.startswith("commu")].reset_index(drop=True)
meta_midi = meta_df.drop(commu_meta.index).reset_index(drop=True)
commu_meta, meta_midi
# Out:
# (      audio_key                                 chord_progressions  \
#  0        aminor  [['Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'A...
#  1        cmajor  [['C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'Dm'...
#  2        aminor  [['Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'A...
#  3        cmajor  [['C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'Gm'...
#  4        aminor  [['Am', 'Am', 'Am', 'Am', 'Em', 'Em', 'Em', 'E...
#  ...         ...                                                ...
#  11139    cmajor  [['Fmaj7', 'Fmaj7', 'Fmaj7', 'Fmaj7', 'Fmaj7',...
#  11140    cmajor  [['Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'A...
#  11141    aminor  [['Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'A...
#  11142    aminor  [['Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'A...
#  11143    aminor  [['Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'A...
#
#        pitch_range  num_measures  bpm      genre     track_role  \
#  0             mid             8  120  cinematic    main_melody
#  1         mid_low             8   80     newage  accompaniment
#  2        mid_high             8  150  cinematic           riff
#  3             mid             8  110  cinematic            pad
#  4         mid_low             4   60  cinematic            pad
#  ...           ...           ...  ...        ...            ...
#  11139    mid_high             8  110  cinematic            pad
#  11140     mid_low             8  110  cinematic           riff
#  11141    very_low             8  145  cinematic           bass
#  11142         low             8  140  cinematic  accompaniment
#  11143    very_low             8  140  cinematic           bass
#
#                    inst sample_rhythm time_signature  min_velocity  \
#  0      string_ensemble      standard            4/4           101
#  1       acoustic_piano      standard            4/4            23
#  2        string_violin      standard            4/4           123
#  3                choir      standard            4/4            45
#  4       acoustic_piano      standard            4/4            21
#  ...                ...           ...            ...           ...
#  11139        synth_pad      standard            4/4            83
#  11140  acoustic_guitar      standard            4/4            51
#  11141  string_ensemble      standard            4/4           109
#  11142     string_cello      standard            4/4            55
#  11143  string_ensemble      standard            4/4           110
#
#         max_velocity split_data          id track_roll  \
#  0               102      train  commu00001        NaN
#  1                30      train  commu00002        NaN
#  2               127      train  commu00003        NaN
#  3                46      train  commu00004        NaN
#  4                22      train  commu00005        NaN
#  ...             ...        ...         ...        ...
#  11139            84        val  commu11140        NaN
#  11140            55        val  commu11141        NaN
#  11141           112        val  commu11142        NaN
#  11142           115        val  commu11143        NaN
#  11143           111        val  commu11144        NaN
#
#                                       unique_chord_n_note  inst_mapping  \
#  0                            ['Am', 'G', 'Dm', 'C', 'D']             4
#  1                      ['Am', 'Dm', 'G', 'C', 'G7', 'F']             0
#  2                                 ['F', 'E+', 'E', 'Am']             4
#  3                      ['A#', 'Dm', 'G', 'C', 'F', 'Gm']             7
#  4                                      ['Em', 'F', 'Am']             0
#  ...                                                  ...           ...
#  11139  ['Gsus4', 'G', 'Am7', 'C', 'Em7', 'G7', 'Fmaj7...             4
#  11140                      ['G', 'Cmaj7', 'Fmaj7', 'Am']             3
#  11141                                 ['Am7', 'F', 'Am']             4
#  11142                                      ['Am7', 'Am']             4
#  11143                               ['Dm', 'Bdim', 'Am']             4
#
#        updated_inst updated_genre  genre_mapping
#  0           string     classical              0
#  1         keyboard     classical              0
#  2           string     classical              0
#  3            choir     classical              0
#  4         keyboard     classical              0
#  ...            ...           ...            ...
#  11139       string     classical              0
#  11140       guitar     classical              0
#  11141       string     classical              0
#  11142       string     classical              0
#  11143       string     classical              0
#
#  [11144 rows x 20 columns],
#        audio_key                                 chord_progressions  \
#  0        cmajor  [['Am', 'Am', 'C', 'C', 'F', 'F', 'Am', 'Am', ...
#  1        fmajor  [['F', 'F', 'F', 'F', 'A', 'A', 'A', 'A', 'C',...
#  2        fmajor  [['Dm', 'Dm', 'Dm', 'Dm', 'F', 'F', 'F', 'F', ...
#  3        aminor  [['C', 'C', 'G', 'G', 'A', 'A', 'C', 'C', 'A',...
#  4        dminor  [['D', 'D', 'D', 'D', 'F', 'F', 'A', 'A', 'A',...
#  ...         ...                                                ...
#  61232    amajor  [['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A',...
#  61233    gminor  [['Gm', 'Gm', 'Gm', 'Gm', 'B', 'B', 'B', 'B', ...
#  61234    emajor  [['B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',...
#  61235   c#major  [['G#', 'G#', 'G#', 'G#', 'C#', 'C#', 'C#', 'C...
#  61236    cmajor  [['C', 'C', 'C', 'C', 'G', 'G', 'G', 'G', 'G',...
#
#        pitch_range  num_measures  bpm               genre track_role  \
#  0         unknown            10  192          electronic    unknown
#  1         unknown             7  112          electronic    unknown
#  2         unknown            12  163          electronic    unknown
#  3         unknown            11  179          electronic    unknown
#  4         unknown             7  112          electronic    unknown
#  ...           ...           ...  ...                 ...        ...
#  61232     unknown            12  169                soul    unknown
#  61233     unknown             3  100               oldie    unknown
#  61234     unknown            11  180                rock    unknown
#  61235     unknown            11  240               metal    unknown
#  61236     unknown            13  161  folk_world_country    unknown
#
#                          inst sample_rhythm time_signature  min_velocity  \
#  0                   dulcimer       unknown            2/4            64
#  1              brass_section       unknown            2/4           127
#  2           percussive_organ       unknown            2/4            31
#  3                lead_square       unknown            2/4            27
#  4                lead_square       unknown            2/4           126
#  ...                      ...           ...            ...           ...
#  61232   electric_guitar_jazz       unknown            4/4            70
#  61233            soprano_sax       unknown            4/4           116
#  61234  bright_acoustic_piano       unknown            2/4            95
#  61235   acoustic_grand_piano       unknown            4/4            95
#  61236  acoustic_guitar_nylon       unknown            4/4            41
#
#         max_velocity split_data                                   id  \
#  0                87      train  0004806f96307e317d116040af5b7861-11
#  1               127      train  0004806f96307e317d116040af5b7861-12
#  2                85      train  0004806f96307e317d116040af5b7861-13
#  3               113      train   0004806f96307e317d116040af5b7861-3
#  4               126      train   0004806f96307e317d116040af5b7861-5
#  ...             ...        ...                                  ...
#  61232            79        val   e34a552e87b6bb8939bc35660d2d116c-5
#  61233           116        val   d0531034be492842b6d9bb32486f6a95-1
#  61234            95        val   72b9d074542398fc021f636eb17da32b-5
#  61235            95        val   0bc159de1686720e1c0282b57a3af7e5-4
#  61236            50        val   c49cd9f3aedfdc864244330c3e1bc942-3
#
#        track_roll                                unique_chord_n_note  \
#  0        unknown  ['B', 'Am', 'G', 'Dm', 'C', 'F', 'D', 'Em', 'C...
#  1        unknown                          ['G', 'C', 'F', 'D', 'A']
#  2        unknown                         ['B', 'Dm', 'G', 'C', 'F']
#  3        unknown                     ['B', 'G', 'C', 'D', 'A', 'E']
#  4        unknown                          ['B', 'G', 'F', 'D', 'A']
#  ...          ...                                                ...
#  61232    unknown                                   ['G', 'A', 'Gm']
#  61233    unknown                                        ['B', 'Gm']
#  61234    unknown                                              ['B']
#  61235    unknown                                  ['C#', 'G#', 'E']
#  61236    unknown                               ['F', 'D', 'G', 'C']
#
#         inst_mapping updated_inst updated_genre  genre_mapping
#  0                 3       guitar    electronic              3
#  1                 5        brass    electronic              3
#  2                 0     keyboard    electronic              3
#  3                 1    accordian    electronic              3
#  4                 1    accordian    electronic              3
#  ...             ...          ...           ...            ...
#  61232             0     keyboard          soul             11
#  61233             5        brass         oldie              8
#  61234             0     keyboard          rock             10
#  61235             0     keyboard         metal              7
#  61236             3       guitar          folk              4
#
#  [61237 rows x 20 columns])

# %%
commu_meta
# Out:
#       audio_key                                 chord_progressions  \
# 0        aminor  [['Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'A...
# 1        cmajor  [['C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'Dm'...
# 2        aminor  [['Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'A...
# 3        cmajor  [['C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'Gm'...
# 4        aminor  [['Am', 'Am', 'Am', 'Am', 'Em', 'Em', 'Em', 'E...
# ...         ...                                                ...
# 11139    cmajor  [['Fmaj7', 'Fmaj7', 'Fmaj7', 'Fmaj7', 'Fmaj7',...
# 11140    cmajor  [['Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'A...
# 11141    aminor  [['Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'A...
# 11142    aminor  [['Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'A...
# 11143    aminor  [['Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'A...
#
#       pitch_range  num_measures  bpm      genre     track_role  \
# 0             mid             8  120  cinematic    main_melody
# 1         mid_low             8   80     newage  accompaniment
# 2        mid_high             8  150  cinematic           riff
# 3             mid             8  110  cinematic            pad
# 4         mid_low             4   60  cinematic            pad
# ...           ...           ...  ...        ...            ...
# 11139    mid_high             8  110  cinematic            pad
# 11140     mid_low             8  110  cinematic           riff
# 11141    very_low             8  145  cinematic           bass
# 11142         low             8  140  cinematic  accompaniment
# 11143    very_low             8  140  cinematic           bass
#
#                   inst sample_rhythm time_signature  min_velocity  \
# 0      string_ensemble      standard            4/4           101
# 1       acoustic_piano      standard            4/4            23
# 2        string_violin      standard            4/4           123
# 3                choir      standard            4/4            45
# 4       acoustic_piano      standard            4/4            21
# ...                ...           ...            ...           ...
# 11139        synth_pad      standard            4/4            83
# 11140  acoustic_guitar      standard            4/4            51
# 11141  string_ensemble      standard            4/4           109
# 11142     string_cello      standard            4/4            55
# 11143  string_ensemble      standard            4/4           110
#
#        max_velocity split_data          id track_roll  \
# 0               102      train  commu00001        NaN
# 1                30      train  commu00002        NaN
# 2               127      train  commu00003        NaN
# 3                46      train  commu00004        NaN
# 4                22      train  commu00005        NaN
# ...             ...        ...         ...        ...
# 11139            84        val  commu11140        NaN
# 11140            55        val  commu11141        NaN
# 11141           112        val  commu11142        NaN
# 11142           115        val  commu11143        NaN
# 11143           111        val  commu11144        NaN
#
#                                      unique_chord_n_note  inst_mapping  \
# 0                            ['Am', 'G', 'Dm', 'C', 'D']             4
# 1                      ['Am', 'Dm', 'G', 'C', 'G7', 'F']             0
# 2                                 ['F', 'E+', 'E', 'Am']             4
# 3                      ['A#', 'Dm', 'G', 'C', 'F', 'Gm']             7
# 4                                      ['Em', 'F', 'Am']             0
# ...                                                  ...           ...
# 11139  ['Gsus4', 'G', 'Am7', 'C', 'Em7', 'G7', 'Fmaj7...             4
# 11140                      ['G', 'Cmaj7', 'Fmaj7', 'Am']             3
# 11141                                 ['Am7', 'F', 'Am']             4
# 11142                                      ['Am7', 'Am']             4
# 11143                               ['Dm', 'Bdim', 'Am']             4
#
#       updated_inst updated_genre  genre_mapping
# 0           string     classical              0
# 1         keyboard     classical              0
# 2           string     classical              0
# 3            choir     classical              0
# 4         keyboard     classical              0
# ...            ...           ...            ...
# 11139       string     classical              0
# 11140       guitar     classical              0
# 11141       string     classical              0
# 11142       string     classical              0
# 11143       string     classical              0
#
# [11144 rows x 20 columns]

# %%
## TODO: could make everything in metamidi standard for sample rhythm
commu_meta.groupby(['track_role']).count()#.count().sort_values(['id'])
# Out:
#                audio_key  chord_progressions  pitch_range  num_measures   bpm  \
# track_role
# accompaniment       2510                2510         2510          2510  2510
# bass                 503                 503          503           503   503
# main_melody         3048                3048         3048          3048  3048
# pad                 1720                1720         1720          1720  1720
# riff                1051                1051         1051          1051  1051
# sub_melody          2312                2312         2312          2312  2312
#
#                genre  inst  sample_rhythm  time_signature  min_velocity  \
# track_role
# accompaniment   2510  2510           2510            2510          2510
# bass             503   503            503             503           503
# main_melody     3048  3048           3048            3048          3048
# pad             1720  1720           1720            1720          1720
# riff            1051  1051           1051            1051          1051
# sub_melody      2312  2312           2312            2312          2312
#
#                max_velocity  split_data    id  track_roll  \
# track_role
# accompaniment          2510        2510  2510           0
# bass                    503         503   503           0
# main_melody            3048        3048  3048           0
# pad                    1720        1720  1720           0
# riff                   1051        1051  1051           0
# sub_melody             2312        2312  2312           0
#
#                unique_chord_n_note  inst_mapping  updated_inst  updated_genre  \
# track_role
# accompaniment                 2510          2510          2510           2510
# bass                           503           503           503            503
# main_melody                   3048          3048          3048           3048
# pad                           1720          1720          1720           1720
# riff                          1051          1051          1051           1051
# sub_melody                    2312          2312          2312           2312
#
#                genre_mapping
# track_role
# accompaniment           2510
# bass                     503
# main_melody             3048
# pad                     1720
# riff                    1051
# sub_melody              2312

# %%
# for meta_midi filter out all instances where min_velocity == max_velocity
meta_midi = meta_midi[meta_midi["min_velocity"] != meta_midi["max_velocity"]].reset_index(drop=True)

# %%
# determine min and max BPM for commu
# TODO: set max BPM to 200
min_bpm = commu_meta["bpm"].min()
max_bpm = commu_meta["bpm"].max()
min_bpm, max_bpm, meta_midi['bpm'].min(), meta_midi['bpm'].max()
# Out:
# (35, 155, 30, 300)

# %%
# determine min and max BPM for commu
min_vel = commu_meta["min_velocity"].min()
max_vel = commu_meta["max_velocity"].max()
min_vel, max_vel, meta_midi['min_velocity'].min(), meta_midi['max_velocity'].max()
# Out:
# (2, 127, 1, 127)

# %%
# determine commu min/max number of measures
min_measures = commu_meta["num_measures"].min()
max_measures = commu_meta["num_measures"].max()
min_measures, max_measures, meta_midi['num_measures'].min(), meta_midi['num_measures'].max()
# Out:
# (4, 17, 1, 191)

# %%
# filter meta midi files such that it consistent with commu
## 1. filtering out bpm
meta_midi = meta_midi[meta_midi['bpm'].between(30, 200)].reset_index(drop=True)

## 2. filtering out velocity
meta_midi = meta_midi[meta_midi['min_velocity'].between(min_vel, max_vel)].reset_index(drop=True)

## 3. filtering out time signature
commu_time_sig = ["4/4", "3/4", "6/8", "12/8"]
meta_midi = meta_midi[meta_midi['time_signature'].isin(commu_time_sig)].reset_index(drop=True)

## 4. filtering out commu num_measures ranges
meta_midi = meta_midi[meta_midi['num_measures'].between(min_measures, 23)].reset_index(drop=True)

# %%
meta_midi
# Out:
#       audio_key                                 chord_progressions  \
# 0        dmajor  [['E', 'E', 'E', 'E', 'D', 'D', 'D', 'D', 'G',...
# 1        eminor  [['F#', 'F#', 'F#', 'F#', 'E', 'E', 'E', 'E', ...
# 2        gmajor  [['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'E',...
# 3        gmajor  [['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'E',...
# 4        aminor  [['C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'F',...
# ...         ...                                                ...
# 22575    emajor  [['C#m', 'C#m', 'C#m', 'C#m', 'C#m', 'C#m', 'C...
# 22576    gmajor  [['B', 'B', 'B', 'B', 'A', 'A', 'A', 'A', 'G',...
# 22577    gmajor  [['G', 'G', 'G', 'G', 'C', 'C', 'C', 'C', 'Am'...
# 22578    amajor  [['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A',...
# 22579    cmajor  [['C', 'C', 'C', 'C', 'G', 'G', 'G', 'G', 'G',...
#
#       pitch_range  num_measures  bpm               genre track_role  \
# 0         unknown            11  166                 pop    unknown
# 1         unknown            16  122                 pop    unknown
# 2         unknown            12  161                 pop    unknown
# 3         unknown            12  155                 pop    unknown
# 4         unknown            11  145                 pop    unknown
# ...           ...           ...  ...                 ...        ...
# 22575     unknown             9  174                rock    unknown
# 22576     unknown            10  188          electronic    unknown
# 22577     unknown            16  140             country    unknown
# 22578     unknown            12  169                soul    unknown
# 22579     unknown            13  161  folk_world_country    unknown
#
#                         inst sample_rhythm time_signature  min_velocity  \
# 0              lead_sawtooth       unknown            4/4            72
# 1              lead_sawtooth       unknown            4/4            55
# 2          overdriven_guitar       unknown            4/4            53
# 3      electric_guitar_muted       unknown            4/4            28
# 4                melodic_tom       unknown            4/4            89
# ...                      ...           ...            ...           ...
# 22575               fx_scifi       unknown            4/4            59
# 22576   acoustic_grand_piano       unknown            4/4            40
# 22577        string_ensemble       unknown            4/4            48
# 22578   electric_guitar_jazz       unknown            4/4            70
# 22579  acoustic_guitar_nylon       unknown            4/4            41
#
#        max_velocity split_data                                   id  \
# 0               127      train  001344339e5b6a6bf1bc16d70b7f91a2-11
# 1               127      train  001344339e5b6a6bf1bc16d70b7f91a2-12
# 2               127      train  001344339e5b6a6bf1bc16d70b7f91a2-14
# 3               127      train  001344339e5b6a6bf1bc16d70b7f91a2-15
# 4               127      train  001344339e5b6a6bf1bc16d70b7f91a2-16
# ...             ...        ...                                  ...
# 22575            68        val   47c1439cd723b457c9009516ac737279-2
# 22576           110        val   ac86c10bac321f338638cc5d49b72a43-1
# 22577            66        val  9290b0d249e42d455ad6ecda4fe0783a-15
# 22578            79        val   e34a552e87b6bb8939bc35660d2d116c-5
# 22579            50        val   c49cd9f3aedfdc864244330c3e1bc942-3
#
#       track_roll                          unique_chord_n_note  inst_mapping  \
# 0        unknown                    ['B', 'G', 'D', 'A', 'E']             1
# 1        unknown  ['B', 'F#', 'G', 'C#', 'D', 'Gm', 'A', 'E']             1
# 2        unknown         ['B', 'F#', 'G', 'C', 'D', 'A', 'E']             3
# 3        unknown         ['B', 'G', 'C', 'C#', 'D', 'A', 'E']             3
# 4        unknown    ['B', 'Am', 'G', 'C', 'F', 'D', 'A', 'E']             3
# ...          ...                                          ...           ...
# 22575    unknown                          ['B', 'G#m', 'C#m']             7
# 22576    unknown        ['B', 'F#', 'G', 'C', 'D', 'Em', 'A']             0
# 22577    unknown                        ['D', 'G', 'C', 'Am']             4
# 22578    unknown                             ['G', 'A', 'Gm']             0
# 22579    unknown                         ['F', 'D', 'G', 'C']             3
#
#       updated_inst updated_genre  genre_mapping
# 0        accordian           pop              9
# 1        accordian           pop              9
# 2           guitar           pop              9
# 3           guitar           pop              9
# 4           guitar           pop              9
# ...            ...           ...            ...
# 22575        choir          rock             10
# 22576     keyboard    electronic              3
# 22577       string       country              1
# 22578     keyboard          soul             11
# 22579       guitar          folk              4
#
# [22580 rows x 20 columns]

# %%
## use FAD score to assign track roles
commu_meta.groupby(['track_role']).count()
# Out:
#                audio_key  chord_progressions  pitch_range  num_measures   bpm  \
# track_role
# accompaniment       2510                2510         2510          2510  2510
# bass                 503                 503          503           503   503
# main_melody         3048                3048         3048          3048  3048
# pad                 1720                1720         1720          1720  1720
# riff                1051                1051         1051          1051  1051
# sub_melody          2312                2312         2312          2312  2312
#
#                genre  inst  sample_rhythm  time_signature  min_velocity  \
# track_role
# accompaniment   2510  2510           2510            2510          2510
# bass             503   503            503             503           503
# main_melody     3048  3048           3048            3048          3048
# pad             1720  1720           1720            1720          1720
# riff            1051  1051           1051            1051          1051
# sub_melody      2312  2312           2312            2312          2312
#
#                max_velocity  split_data    id  track_roll  \
# track_role
# accompaniment          2510        2510  2510           0
# bass                    503         503   503           0
# main_melody            3048        3048  3048           0
# pad                    1720        1720  1720           0
# riff                   1051        1051  1051           0
# sub_melody             2312        2312  2312           0
#
#                unique_chord_n_note  inst_mapping  updated_inst  updated_genre  \
# track_role
# accompaniment                 2510          2510          2510           2510
# bass                           503           503           503            503
# main_melody                   3048          3048          3048           3048
# pad                           1720          1720          1720           1720
# riff                          1051          1051          1051           1051
# sub_melody                    2312          2312          2312           2312
#
#                genre_mapping
# track_role
# accompaniment           2510
# bass                     503
# main_melody             3048
# pad                     1720
# riff                    1051
# sub_melody              2312

# %%
## TODO: filtered on commu NUM Measures
commu_meta.groupby(['num_measures']).count()
# Out:
#               audio_key  chord_progressions  pitch_range   bpm  genre  \
# num_measures
# 4                  2710                2710         2710  2710   2710
# 5                     2                   2            2     2      2
# 8                  7233                7233         7233  7233   7233
# 9                    80                  80           80    80     80
# 16                 1042                1042         1042  1042   1042
# 17                   77                  77           77    77     77
#
#               track_role  inst  sample_rhythm  time_signature  min_velocity  \
# num_measures
# 4                   2710  2710           2710            2710          2710
# 5                      2     2              2               2             2
# 8                   7233  7233           7233            7233          7233
# 9                     80    80             80              80            80
# 16                  1042  1042           1042            1042          1042
# 17                    77    77             77              77            77
#
#               max_velocity  split_data    id  track_roll  unique_chord_n_note  \
# num_measures
# 4                     2710        2710  2710           0                 2710
# 5                        2           2     2           0                    2
# 8                     7233        7233  7233           0                 7233
# 9                       80          80    80           0                   80
# 16                    1042        1042  1042           0                 1042
# 17                      77          77    77           0                   77
#
#               inst_mapping  updated_inst  updated_genre  genre_mapping
# num_measures
# 4                     2710          2710           2710           2710
# 5                        2             2              2              2
# 8                     7233          7233           7233           7233
# 9                       80            80             80             80
# 16                    1042          1042           1042           1042
# 17                      77            77             77             77

# %%
meta_midi.groupby(['num_measures']).count()
# Out:
#               audio_key  chord_progressions  pitch_range   bpm  genre  \
# num_measures
# 4                   596                 596          596   596    596
# 5                   445                 445          445   445    445
# 6                   598                 598          598   598    598
# 7                   863                 863          863   863    863
# 8                  1075                1075         1075  1075   1075
# 9                  1203                1203         1203  1203   1203
# 10                 2276                2276         2276  2276   2276
# 11                 2764                2764         2764  2764   2764
# 12                 2368                2368         2368  2368   2368
# 13                 2022                2022         2022  2022   2022
# 14                 1439                1439         1439  1439   1439
# 15                 1129                1129         1129  1129   1129
# 16                 1316                1316         1316  1316   1316
# 17                 1013                1013         1013  1013   1013
# 18                  860                 860          860   860    860
# 19                  613                 613          613   613    613
# 20                  629                 629          629   629    629
# 21                  554                 554          554   554    554
# 22                  447                 447          447   447    447
# 23                  370                 370          370   370    370
#
#               track_role  inst  sample_rhythm  time_signature  min_velocity  \
# num_measures
# 4                    596   596            596             596           596
# 5                    445   445            445             445           445
# 6                    598   598            598             598           598
# 7                    863   863            863             863           863
# 8                   1075  1075           1075            1075          1075
# 9                   1203  1203           1203            1203          1203
# 10                  2276  2276           2276            2276          2276
# 11                  2764  2764           2764            2764          2764
# 12                  2368  2368           2368            2368          2368
# 13                  2022  2022           2022            2022          2022
# 14                  1439  1439           1439            1439          1439
# 15                  1129  1129           1129            1129          1129
# 16                  1316  1316           1316            1316          1316
# 17                  1013  1013           1013            1013          1013
# 18                   860   860            860             860           860
# 19                   613   613            613             613           613
# 20                   629   629            629             629           629
# 21                   554   554            554             554           554
# 22                   447   447            447             447           447
# 23                   370   370            370             370           370
#
#               max_velocity  split_data    id  track_roll  unique_chord_n_note  \
# num_measures
# 4                      596         596   596         596                  596
# 5                      445         445   445         445                  445
# 6                      598         598   598         598                  598
# 7                      863         863   863         863                  863
# 8                     1075        1075  1075        1075                 1075
# 9                     1203        1203  1203        1203                 1203
# 10                    2276        2276  2276        2276                 2276
# 11                    2764        2764  2764        2764                 2764
# 12                    2368        2368  2368        2368                 2368
# 13                    2022        2022  2022        2022                 2022
# 14                    1439        1439  1439        1439                 1439
# 15                    1129        1129  1129        1129                 1129
# 16                    1316        1316  1316        1316                 1316
# 17                    1013        1013  1013        1013                 1013
# 18                     860         860   860         860                  860
# 19                     613         613   613         613                  613
# 20                     629         629   629         629                  629
# 21                     554         554   554         554                  554
# 22                     447         447   447         447                  447
# 23                     370         370   370         370                  370
#
#               inst_mapping  updated_inst  updated_genre  genre_mapping
# num_measures
# 4                      596           596            596            596
# 5                      445           445            445            445
# 6                      598           598            598            598
# 7                      863           863            863            863
# 8                     1075          1075           1075           1075
# 9                     1203          1203           1203           1203
# 10                    2276          2276           2276           2276
# 11                    2764          2764           2764           2764
# 12                    2368          2368           2368           2368
# 13                    2022          2022           2022           2022
# 14                    1439          1439           1439           1439
# 15                    1129          1129           1129           1129
# 16                    1316          1316           1316           1316
# 17                    1013          1013           1013           1013
# 18                     860           860            860            860
# 19                     613           613            613            613
# 20                     629           629            629            629
# 21                     554           554            554            554
# 22                     447           447            447            447
# 23                     370           370            370            370

# %%
measures = meta_midi.groupby(['num_measures']).count()
measures[measures.index > 17]['id'].sum() / measures['id'].sum()
# Out:
# 0.1538086802480071

# %%
meta_midi.to_csv("../dataset/filtered_meta_midi_to_be_in_commu_range.csv", index=False)

# %%
meta_midi[meta_midi['genre'] == 'rock'].groupby(['split_data']).count()
# Out:
#             audio_key  chord_progressions  pitch_range  num_measures   bpm  \
# split_data
# train            5803                5803         5803          5803  5803
# val               614                 614          614           614   614
#
#             genre  track_role  inst  sample_rhythm  time_signature  \
# split_data
# train        5803        5803  5803           5803            5803
# val           614         614   614            614             614
#
#             min_velocity  max_velocity    id  track_roll  unique_chord_n_note  \
# split_data
# train               5803          5803  5803        5803                 5803
# val                  614           614   614         614                  614
#
#             inst_mapping  updated_inst  updated_genre  genre_mapping
# split_data
# train               5803          5803           5803           5803
# val                  614           614            614            614

# %%
commu_meta[commu_meta['genre'] == 'newage'].groupby(['split_data']).count()
# Out:
#             audio_key  chord_progressions  pitch_range  num_measures   bpm  \
# split_data
# train            2928                2928         2928          2928  2928
# val               192                 192          192           192   192
#
#             genre  track_role  inst  sample_rhythm  time_signature  \
# split_data
# train        2928        2928  2928           2928            2928
# val           192         192   192            192             192
#
#             min_velocity  max_velocity    id  track_roll  unique_chord_n_note  \
# split_data
# train               2928          2928  2928           0                 2928
# val                  192           192   192           0                  192
#
#             inst_mapping  updated_inst  updated_genre  genre_mapping
# split_data
# train               2928          2928           2928           2928
# val                  192           192            192            192

# %%
# filter out data and append
# commu_meta = commu_meta[commu_meta['genre'] != 'newage']
# meta_midi = meta_midi[meta_midi['genre'] == 'rock']

final_df = pd.concat([commu_meta, meta_midi],axis=0).sample(frac=1).reset_index(drop=True)
final_df_train = final_df[final_df['split_data'] == 'train'].sample(frac=1).reset_index(drop=True)
final_df_test = final_df[final_df['split_data'] == 'val'].sample(frac=1).reset_index(drop=True)
final_df = pd.concat([final_df_train, final_df_test],axis=0).reset_index(drop=True)
final_df.to_csv("../dataset/meta_filtered_commu_full_inst_genre.csv", index=False)

# %%
final_df
# Out:
#       audio_key                                 chord_progressions  \
# 0        aminor  [['C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'B',...
# 1        cmajor  [['G', 'G', 'G', 'G', 'G', 'G', 'G', 'G', 'G',...
# 2       f#minor  [['C#', 'C#', 'C#', 'C#', 'C#', 'C#', 'C#', 'C...
# 3        cmajor  [['C', 'C', 'C', 'C', 'G', 'G', 'G', 'G', 'Am7...
# 4        emajor  [['B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',...
# ...         ...                                                ...
# 33719    dmajor  [['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'D',...
# 33720    amajor  [['Cm', 'Cm', 'Cm', 'Cm', 'G#', 'G#', 'G#', 'G...
# 33721    fminor  [['B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',...
# 33722    aminor  [['E', 'E', 'E', 'E', 'E', 'E', 'E', 'E', 'E',...
# 33723    gmajor  [['E', 'E', 'E', 'E', 'B', 'B', 'B', 'B', 'A',...
#
#       pitch_range  num_measures  bpm               genre     track_role  \
# 0         unknown             7   36                rock        unknown
# 1         unknown             8  180                 pop        unknown
# 2         unknown            16  160               metal        unknown
# 3         mid_low             4  100              newage  accompaniment
# 4         unknown             7  153               oldie        unknown
# ...           ...           ...  ...                 ...            ...
# 33719     unknown             4  141  folk_world_country        unknown
# 33720     unknown             7  191                 pop        unknown
# 33721     unknown            18   90              reggae        unknown
# 33722     unknown            18  120                rock        unknown
# 33723     unknown            22   87                 pop        unknown
#
#                         inst sample_rhythm time_signature  min_velocity  \
# 0                 synthbrass       unknown            4/4            97
# 1                    timpani       unknown            4/4            72
# 2          overdriven_guitar       unknown            4/4            70
# 3             acoustic_piano      standard            4/4            49
# 4           percussive_organ       unknown            4/4            82
# ...                      ...           ...            ...           ...
# 33719                 shanai       unknown            4/4           105
# 33720             fx_crystal       unknown            4/4            88
# 33721          acoustic_bass       unknown            4/4            63
# 33722  electric_guitar_muted       unknown            4/4            95
# 33723            lead_square       unknown            4/4            64
#
#        max_velocity split_data                                  id track_roll  \
# 0               101      train  ecbea432cc241d9ce6d538e0151de1b7-6    unknown
# 1               127      train  5daf3586f16c43682a80bcaa5c5a0da0-7    unknown
# 2                95      train  20edb760f18a93664d53dbfc66adc0e9-1    unknown
# 3                57      train                          commu02701        NaN
# 4               126      train  774575eebc32574da278f10b6f54acb2-5    unknown
# ...             ...        ...                                 ...        ...
# 33719           115        val  1da60045575d51727acd88155f663755-5    unknown
# 33720           122        val  f31c766ba03601e5f07eeeb4b0018825-8    unknown
# 33721           111        val  697c38add4bcb7c403a388033db3c450-1    unknown
# 33722           127        val  710bd2eb118ed2bd632a701f6cba6546-1    unknown
# 33723            90        val  e908e3cdd642681c54f469a0baf0c1a2-8    unknown
#
#                                     unique_chord_n_note  inst_mapping  \
# 0                 ['B', 'G', 'C', 'F', 'Bm', 'Em', 'A']             5
# 1                             ['G', 'C', 'D', 'A', 'E']             6
# 2                           ['B', 'G', 'G#', 'C#', 'A']             3
# 3      ['G', 'Am7', 'C', 'C7', 'Em7', 'F', 'Dm7', 'Gm']             0
# 4                                       ['B', 'F', 'E']             0
# ...                                                 ...           ...
# 33719                                        ['D', 'A']             5
# 33720                            ['D', 'Cm', 'G#', 'E']             5
# 33721                        ['B', 'G#', 'C', 'F', 'E']             3
# 33722                                   ['A', 'C', 'E']             3
# 33723                              ['B', 'D', 'A', 'E']             1
#
#       updated_inst updated_genre  genre_mapping
# 0            brass          rock             10
# 1       percussion           pop              9
# 2           guitar         metal              7
# 3         keyboard     classical              0
# 4         keyboard         oldie              8
# ...            ...           ...            ...
# 33719        brass          folk              4
# 33720        brass           pop              9
# 33721       guitar           pop              9
# 33722       guitar          rock             10
# 33723    accordian           pop              9
#
# [33724 rows x 20 columns]

# %%
final_df[final_df['genre_mapping'] == 0].groupby(['genre_mapping', 'genre']).count()
# Out:
#                          audio_key  chord_progressions  pitch_range  \
# genre_mapping genre
# 0             cinematic       8024                8024         8024
#               classical        976                 976          976
#               gothic            13                  13           13
#               latin            280                 280          280
#               newage          3155                3155         3155
#
#                          num_measures   bpm  track_role  inst  sample_rhythm  \
# genre_mapping genre
# 0             cinematic          8024  8024        8024  8024           8024
#               classical           976   976         976   976            976
#               gothic               13    13          13    13             13
#               latin               280   280         280   280            280
#               newage             3155  3155        3155  3155           3155
#
#                          time_signature  min_velocity  max_velocity  \
# genre_mapping genre
# 0             cinematic            8024          8024          8024
#               classical             976           976           976
#               gothic                 13            13            13
#               latin                 280           280           280
#               newage               3155          3155          3155
#
#                          split_data    id  track_roll  unique_chord_n_note  \
# genre_mapping genre
# 0             cinematic        8024  8024           0                 8024
#               classical         976   976         976                  976
#               gothic             13    13          13                   13
#               latin             280   280         280                  280
#               newage           3155  3155          35                 3155
#
#                          inst_mapping  updated_inst  updated_genre
# genre_mapping genre
# 0             cinematic          8024          8024           8024
#               classical           976           976            976
#               gothic               13            13             13
#               latin               280           280            280
#               newage             3155          3155           3155

# %%
# # Filtered out meta_midi only
# final_df_train = meta_midi[meta_midi['split_data'] == 'train'].sample(frac=1).reset_index(drop=True)
# final_df_test = meta_midi[meta_midi['split_data'] == 'val'].sample(frac=1).reset_index(drop=True)
# final_df = pd.concat([final_df_train, final_df_test],axis=0).reset_index(drop=True)

# %%
# import shutil
# # move the data to the respective folder
# train_raw = f"../dataset/complete_midi/train/raw"
# val_raw = f"../dataset/complete_midi/val/raw"

# train_dir = f"../dataset/meta_midi_only_filtered/train/raw"
# val_dir = f"../dataset/meta_midi_only_filtered/val/raw"

# # create the folder if not exist
# Path(train_dir).mkdir(parents=True, exist_ok=True)
# Path(val_dir).mkdir(parents=True, exist_ok=True)

# # copy the data using the split_data column
# for i, row in tqdm(final_df.iterrows()):
#     try:
#         # copy the file and replace underscore with hyphen
#         # also replace the id with same structure
#         if row['split_data'] == 'train':
#             shutil.copy(f"{train_raw}/{row['id']}.mid", f"{train_dir}/{row['id'].replace('_', '-')}.mid")
#         elif row['split_data'] == 'val':
#             shutil.copy(f"{val_raw}/{row['id']}.mid", f"{val_dir}/{row['id'].replace('_', '-')}.mid")
#     except Exception as e:
#         print(e)
#         pass

# %%
# final_df.to_csv("../dataset/meta_midi_only_filtered.csv", index=False)

# %%
# import json
# genre_map = final_df[['genre', 'genre_mapping']].groupby(['genre']).max().to_dict()['genre_mapping']
# with open(f"../dataset/genre_map_v2.json", 'w') as f:
#     f.write(json.dumps(genre_map, indent=4))

# %% [markdown]
# # Increase Batch Size
# # Filling Unknown
# ### 1. standard fill for sample rythm
# ### 2. model to classify pitch ranges
# ### 3. randomly assign to reach commu distribution

# %% [markdown]
# # Pitch Ranges Analysis

# %%
# determine the pitch range of the midi files
commu_pitch_ranges = []
for i, row in tqdm(commu_meta.iterrows()):
    midi_file_path = f"../dataset/complete_midi/{row['split_data']}/raw/{row['id']}.mid"

    try:
        # extract the pitch range
        midi = MidiFile(midi_file_path)
        min_pitch, max_pitch = get_pitch_range(midi)

        
        if min_pitch == float('inf') or max_pitch == float('-inf'):
            print("No pitch information found in the MIDI file.")
        else:
            # print(f"Pitch Range: {min_pitch} to {max_pitch}")
            commu_pitch_ranges.append([row['id'], row['pitch_range'], min_pitch, max_pitch])

    except Exception as e:
        print(e)
        pass
# Out:
# 0it [00:00, ?it/s]

# %%
# compute mean 
commu_pitch_ranges_df  = pd.DataFrame(commu_pitch_ranges, columns=["id", "pitch_range", "min_pitch", "max_pitch"])
commu_pitch_ranges_df
# Out:
#                id pitch_range  min_pitch  max_pitch
# 0      commu00001         mid         57         81
# 1      commu00002     mid_low         41         67
# 2      commu00003    mid_high         71         89
# 3      commu00004         mid         62         76
# 4      commu00005     mid_low         40         60
# ...           ...         ...        ...        ...
# 11139  commu11140    mid_high         60         91
# 11140  commu11141     mid_low         53         67
# 11141  commu11142    very_low         33         33
# 11142  commu11143         low         40         48
# 11143  commu11144    very_low         33         33
#
# [11144 rows x 4 columns]

# %%
quantiles = [0.25, 0.75]  # You can adjust these as needed

# Group by and aggregate other statistics
summary_stats = commu_pitch_ranges_df.groupby("pitch_range").agg({
    "min_pitch": ['min', 'max', 'mean', 'median', lambda x: x.quantile(quantiles).tolist()[0], lambda x: x.quantile(quantiles).tolist()[1]],
    "max_pitch": ['min', 'max', 'mean', 'median', lambda x: x.quantile(quantiles).tolist()[0], lambda x: x.quantile(quantiles).tolist()[1]]
})

# rename the columns by merging the multiindex columns together
summary_stats = summary_stats.rename(columns={'<lambda_0>': 'q25',
                                              '<lambda_1>': 'q75'})
summary_stats.columns = summary_stats.columns.map('_'.join)
summary_stats = summary_stats.reset_index()
summary_stats
# Out:
#   pitch_range  min_pitch_min  min_pitch_max  min_pitch_mean  min_pitch_median  \
# 0        high             62             93       79.256516              79.0
# 1         low             22             46       36.157895              36.0
# 2         mid             26             71       54.717620              55.0
# 3    mid_high             28             83       68.294976              69.0
# 4     mid_low              5             59       42.547331              41.0
# 5   very_high             86             95       90.500000              90.5
# 6    very_low             21             33       28.486486              29.0
#
#    min_pitch_q25  min_pitch_q75  max_pitch_min  max_pitch_max  max_pitch_mean  \
# 0          76.00          83.00             84            108       94.775034
# 1          33.00          40.00             33             69       47.969925
# 2          50.00          60.00             55            102       74.820012
# 3          65.00          72.00             64            103       86.059157
# 4          39.00          47.00             45            101       65.166904
# 5          88.25          92.75            100            108      104.000000
# 6          26.00          31.00             24             45       35.797297
#
#    max_pitch_median  max_pitch_q25  max_pitch_q75
# 0              95.0           91.0           98.0
# 1              48.0           45.0           52.0
# 2              76.0           72.0           79.0
# 3              86.0           83.0           90.0
# 4              65.0           62.0           69.0
# 5             104.0          102.0          106.0
# 6              36.0           33.0           37.0

# %%
commu_pitch_ranges_df = commu_pitch_ranges_df.merge(summary_stats, on="pitch_range")
commu_pitch_ranges_df
# Out:
#                id pitch_range  min_pitch  max_pitch  min_pitch_min  \
# 0      commu00001         mid         57         81             26
# 1      commu00004         mid         62         76             26
# 2      commu00008         mid         67         69             26
# 3      commu00013         mid         65         76             26
# 4      commu00017         mid         53         77             26
# ...           ...         ...        ...        ...            ...
# 11139  commu11134    very_low         26         36             21
# 11140  commu11142    very_low         33         33             21
# 11141  commu11144    very_low         33         33             21
# 11142  commu01427   very_high         86        108             86
# 11143  commu05244   very_high         95        100             86
#
#        min_pitch_max  min_pitch_mean  min_pitch_median  min_pitch_q25  \
# 0                 71       54.717620              55.0          50.00
# 1                 71       54.717620              55.0          50.00
# 2                 71       54.717620              55.0          50.00
# 3                 71       54.717620              55.0          50.00
# 4                 71       54.717620              55.0          50.00
# ...              ...             ...               ...            ...
# 11139             33       28.486486              29.0          26.00
# 11140             33       28.486486              29.0          26.00
# 11141             33       28.486486              29.0          26.00
# 11142             95       90.500000              90.5          88.25
# 11143             95       90.500000              90.5          88.25
#
#        min_pitch_q75  max_pitch_min  max_pitch_max  max_pitch_mean  \
# 0              60.00             55            102       74.820012
# 1              60.00             55            102       74.820012
# 2              60.00             55            102       74.820012
# 3              60.00             55            102       74.820012
# 4              60.00             55            102       74.820012
# ...              ...            ...            ...             ...
# 11139          31.00             24             45       35.797297
# 11140          31.00             24             45       35.797297
# 11141          31.00             24             45       35.797297
# 11142          92.75            100            108      104.000000
# 11143          92.75            100            108      104.000000
#
#        max_pitch_median  max_pitch_q25  max_pitch_q75
# 0                  76.0           72.0           79.0
# 1                  76.0           72.0           79.0
# 2                  76.0           72.0           79.0
# 3                  76.0           72.0           79.0
# 4                  76.0           72.0           79.0
# ...                 ...            ...            ...
# 11139              36.0           33.0           37.0
# 11140              36.0           33.0           37.0
# 11141              36.0           33.0           37.0
# 11142             104.0          102.0          106.0
# 11143             104.0          102.0          106.0
#
# [11144 rows x 16 columns]
