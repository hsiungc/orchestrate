# %%
# import some useful libraries
import glob
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras import metrics

from tqdm.notebook import tqdm
from music21 import converter, instrument, note, chord, stream

# %%
glob.glob("../data/piano/*.mid")
# Out:
# ['../data/piano\\0fithos.mid',
#  '../data/piano\\8.mid',
#  '../data/piano\\ahead_on_our_way_piano.mid',
#  '../data/piano\\AT.mid',
#  '../data/piano\\balamb.mid',
#  '../data/piano\\bcm.mid',
#  '../data/piano\\BlueStone_LastDungeon.mid',
#  '../data/piano\\braska.mid',
#  '../data/piano\\caitsith.mid',
#  '../data/piano\\Cids.mid',
#  '../data/piano\\cosmo.mid',
#  '../data/piano\\costadsol.mid',
#  '../data/piano\\dayafter.mid',
#  '../data/piano\\decisive.mid',
#  '../data/piano\\dontbeafraid.mid',
#  '../data/piano\\DOS.mid',
#  '../data/piano\\electric_de_chocobo.mid',
#  '../data/piano\\Eternal_Harvest.mid',
#  '../data/piano\\EyesOnMePiano.mid',
#  '../data/piano\\ff11_awakening_piano.mid',
#  '../data/piano\\ff1battp.mid',
#  '../data/piano\\FF3_Battle_(Piano).mid',
#  '../data/piano\\FF3_Third_Phase_Final_(Piano).mid',
#  '../data/piano\\ff4-airship.mid',
#  '../data/piano\\Ff4-BattleLust.mid',
#  '../data/piano\\ff4-fight1.mid',
#  '../data/piano\\ff4-town.mid',
#  '../data/piano\\FF4.mid',
#  '../data/piano\\ff4pclov.mid',
#  '../data/piano\\ff4_piano_collections-main_theme.mid',
#  '../data/piano\\FF6epitaph_piano.mid',
#  '../data/piano\\ff6shap.mid',
#  '../data/piano\\Ff7-Cinco.mid',
#  '../data/piano\\Ff7-Jenova_Absolute.mid',
#  '../data/piano\\ff7-mainmidi.mid',
#  '../data/piano\\Ff7-One_Winged.mid',
#  '../data/piano\\ff7themep.mid',
#  '../data/piano\\ff8-lfp.mid',
#  '../data/piano\\FF8_Shuffle_or_boogie_pc.mid',
#  '../data/piano\\FFIII_Edgar_And_Sabin_Piano.mid',
#  '../data/piano\\FFIXQuMarshP.mid',
#  '../data/piano\\FFIX_Piano.mid',
#  '../data/piano\\FFVII_BATTLE.mid',
#  '../data/piano\\FFX_-_Ending_Theme_(Piano_Version)_-_by_Angel_FF.mid',
#  '../data/piano\\Fiend_Battle_(Piano).mid',
#  '../data/piano\\Fierce_Battle_(Piano).mid',
#  '../data/piano\\figaro.mid',
#  '../data/piano\\Finalfantasy5gilgameshp.mid',
#  '../data/piano\\Finalfantasy6fanfarecomplete.mid',
#  '../data/piano\\Final_Fantasy_7_-_Judgement_Day_Piano.mid',
#  '../data/piano\\Final_Fantasy_Matouyas_Cave_Piano.mid',
#  '../data/piano\\fortresscondor.mid',
#  '../data/piano\\Fyw_piano.mid',
#  '../data/piano\\gerudo.mid',
#  '../data/piano\\goldsaucer.mid',
#  '../data/piano\\Gold_Silver_Rival_Battle.mid',
#  '../data/piano\\great_war.mid',
#  '../data/piano\\HighwindTakestotheSkies.mid',
#  '../data/piano\\In_Zanarkand.mid',
#  '../data/piano\\JENOVA.mid',
#  '../data/piano\\Kingdom_Hearts_Dearly_Beloved.mid',
#  '../data/piano\\Kingdom_Hearts_Traverse_Town.mid',
#  '../data/piano\\Life_Stream.mid',
#  '../data/piano\\lurk_in_dark.mid',
#  '../data/piano\\mining.mid',
#  '../data/piano\\Oppressed.mid',
#  '../data/piano\\OTD5YA.mid',
#  '../data/piano\\path_of_repentance.mid',
#  '../data/piano\\pkelite4.mid',
#  '../data/piano\\Rachel_Piano_tempofix.mid',
#  '../data/piano\\redwings.mid',
#  '../data/piano\\relmstheme-piano.mid',
#  '../data/piano\\roseofmay-piano.mid',
#  '../data/piano\\rufus.mid',
#  '../data/piano\\Rydia_pc.mid',
#  '../data/piano\\sandy.mid',
#  '../data/piano\\sera_.mid',
#  '../data/piano\\sobf.mid',
#  '../data/piano\\Still_Alive-1.mid',
#  '../data/piano\\Suteki_Da_Ne_(Piano_Version).mid',
#  '../data/piano\\thenightmarebegins.mid',
#  '../data/piano\\thoughts.mid',
#  '../data/piano\\tifap.mid',
#  '../data/piano\\tpirtsd-piano.mid',
#  '../data/piano\\traitor.mid',
#  '../data/piano\\ultimafro.mid',
#  '../data/piano\\ultros.mid',
#  '../data/piano\\VincentPiano.mid',
#  '../data/piano\\ViviinAlexandria.mid',
#  '../data/piano\\waltz_de_choco.mid',
#  '../data/piano\\Zelda_Overworld.mid',
#  '../data/piano\\z_aeristhemepiano.mid']
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# read in music and prepare it in a list of notes
notes = []
for file in tqdm(glob.glob("../data/piano/*.mid")):
    midi = converter.parse(file)
    notes_to_parse = None
    parts = instrument.partitionByInstrument(midi)
    
    # Two cases:
    # 1. music file has instrument parts
    # 2. music file has notes in a flat structure
    if parts: 
        notes_to_parse = parts.parts[0].recurse()
    else: 
        notes_to_parse = midi.flat.notes
        
    # each note elements exported and append to an array of notes
    for element in notes_to_parse:
        if isinstance(element, note.Note):
            notes.append(str(element.pitch))
        elif isinstance(element, chord.Chord):
            notes.append('.'.join(str(n) for n in element.normalOrder))
# Out:
#   0%|          | 0/92 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# e:\UNIXSpace\Git_Desktop\Berkeley-MIDS\Classes\W210 - Capstone\w210-capstone-fall2023\workspace\ai_tune_generator.ipynb Cell 2 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/e%3A/UNIXSpace/Git_Desktop/Berkeley-MIDS/Classes/W210%20-%20Capstone/w210-capstone-fall2023/workspace/ai_tune_generator.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> notes = []
#       <a href='vscode-notebook-cell:/e%3A/UNIXSpace/Git_Desktop/Berkeley-MIDS/Classes/W210%20-%20Capstone/w210-capstone-fall2023/workspace/ai_tune_generator.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> for file in tqdm(glob.glob("../data/piano/*.mid")):
# ----> <a href='vscode-notebook-cell:/e%3A/UNIXSpace/Git_Desktop/Berkeley-MIDS/Classes/W210%20-%20Capstone/w210-capstone-fall2023/workspace/ai_tune_generator.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a>     midi = converter.parse(file)
#       <a href='vscode-notebook-cell:/e%3A/UNIXSpace/Git_Desktop/Berkeley-MIDS/Classes/W210%20-%20Capstone/w210-capstone-fall2023/workspace/ai_tune_generator.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a>     notes_to_parse = None
#       <a href='vscode-notebook-cell:/e%3A/UNIXSpace/Git_Desktop/Berkeley-MIDS/Classes/W210%20-%20Capstone/w210-capstone-fall2023/workspace/ai_tune_generator.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a>     parts = instrument.partitionByInstrument(midi)
#
# File c:\Users\ktrin\miniconda3\envs\tf\lib\site-packages\music21\converter\__init__.py:1168, in parse(value, *args, **keywords)
#    1165     return parseData(value, number=number, format=m21Format, **keywords)
#    1166 elif (not isinstance(value, bytes)
#    1167       and _osCanLoad(valueStr)):
# -> 1168     return parseFile(valueStr, number=number, format=m21Format,
#    1169                      forceSource=forceSource, **keywords)
#    1170 elif (not isinstance(value, bytes)
#    1171       and _osCanLoad(common.cleanpath(valueStr))):
#    1172     return parseFile(common.cleanpath(valueStr), number=number, format=m21Format,
#    1173                      forceSource=forceSource, **keywords)
#
# File c:\Users\ktrin\miniconda3\envs\tf\lib\site-packages\music21\converter\__init__.py:1037, in parseFile(fp, number, format, forceSource, **keywords)
#    1035 v = Converter()
#    1036 fp = common.cleanpath(fp, returnPathlib=True)
# -> 1037 v.parseFile(fp, number=number, format=format, forceSource=forceSource, **keywords)
#    1038 return v.stream
#
# File c:\Users\ktrin\miniconda3\envs\tf\lib\site-packages\music21\converter\__init__.py:571, in Converter.parseFile(self, fp, number, format, forceSource, storePickle, **keywords)
#     569 else:
#     570     environLocal.printDebug('Loading original version')
# --> 571     self.parseFileNoPickle(fp, number, format, forceSource, **keywords)
#     572     if writePickle is True and fpPickle is not None and storePickle is True:
#     573         # save the stream to disk...
#     574         environLocal.printDebug('Freezing Pickle')
#
# File c:\Users\ktrin\miniconda3\envs\tf\lib\site-packages\music21\converter\__init__.py:504, in Converter.parseFileNoPickle(self, fp, number, format, forceSource, **keywords)
#     502 self.subConverter.keywords = keywords
#     503 try:
# --> 504     self.subConverter.parseFile(fp, number=number, **keywords)
#     505 except NotImplementedError:
#     506     raise ConverterFileException(f'File is not in a correct format: {fp}')
#
# File c:\Users\ktrin\miniconda3\envs\tf\lib\site-packages\music21\converter\subConverters.py:1153, in ConverterMidi.parseFile(self, fp, number, **keywords)
#    1142 '''
#    1143 Get MIDI data from a file path.
#    1144
#    (...)
#    1150 in defaults.quantizationQuarterLengthDivisors. (Default: (4, 3)).
#    1151 '''
#    1152 from music21.midi import translate as midiTranslate
# -> 1153 midiTranslate.midiFilePathToStream(fp, self.stream, **keywords)
#
# File c:\Users\ktrin\miniconda3\envs\tf\lib\site-packages\music21\midi\translate.py:2705, in midiFilePathToStream(filePath, inputM21, **keywords)
#    2703 mf.read()
#    2704 mf.close()
# -> 2705 return midiFileToStream(mf, inputM21, **keywords)
#
# File c:\Users\ktrin\miniconda3\envs\tf\lib\site-packages\music21\midi\translate.py:2876, in midiFileToStream(mf, inputM21, quantizePost, **keywords)
#    2872     quantizePost = keywords.pop('quantizePost')
#    2874 # create a stream for each tracks
#    2875 # may need to check if tracks actually have event data
# -> 2876 midiTracksToStreams(mf.tracks,
#    2877                     ticksPerQuarter=mf.ticksPerQuarterNote,
#    2878                     quantizePost=quantizePost,
#    2879                     inputM21=s,
#    2880                     **keywords)
#    2881 # s._setMidiTracks(mf.tracks, mf.ticksPerQuarterNote)
#    2883 return s
#
# File c:\Users\ktrin\miniconda3\envs\tf\lib\site-packages\music21\midi\translate.py:2616, in midiTracksToStreams(midiTracks, ticksPerQuarter, quantizePost, inputM21, **keywords)
#    2613     else:
#    2614         streamPart = conductorPart
# -> 2616     midiTrackToStream(mt,
#    2617                       ticksPerQuarter,
#    2618                       quantizePost,
#    2619                       inputM21=streamPart,
#    2620                       conductorPart=conductorPart,
#    2621                       isFirst=(mt is firstTrackWithNotes),
#    2622                       **keywords)
#    2624 return s
#
# File c:\Users\ktrin\miniconda3\envs\tf\lib\site-packages\music21\midi\translate.py:2073, in midiTrackToStream(mt, ticksPerQuarter, quantizePost, inputM21, conductorPart, isFirst, **keywords)
#    2071 # quantize to nearest 16th
#    2072 if quantizePost:
# -> 2073     s.quantize(quarterLengthDivisors=quarterLengthDivisors,
#    2074                processOffsets=True,
#    2075                processDurations=True,
#    2076                inPlace=True,
#    2077                recurse=False)  # shouldn't be any substreams yet
#    2079 if not notes:
#    2080     # Conductor track doesn't need measures made
#    2081     # It's an intermediate result only -- not provided to user
#    2082     return s
#
# File c:\Users\ktrin\miniconda3\envs\tf\lib\site-packages\music21\stream\base.py:9273, in Stream.quantize(self, quarterLengthDivisors, processOffsets, processDurations, inPlace, recurse)
#    9271     rests_lacking_durations.append(e)
#    9272 else:
# -> 9273     e.duration.quarterLength = d_matchTuple.match
#    9274     if hasattr(e, 'editorial') and d_matchTuple.signedError != 0:
#    9275         e.editorial.quarterLengthQuantizationError = d_matchTuple.signedError
#
# File c:\Users\ktrin\miniconda3\envs\tf\lib\site-packages\music21\duration.py:2826, in Duration._setQuarterLength(self, value)
#    2823 self._componentsNeedUpdating = True
#    2824 self._quarterLengthNeedsUpdating = False
# -> 2826 self.informClient()
#
# File c:\Users\ktrin\miniconda3\envs\tf\lib\site-packages\music21\duration.py:2243, in Duration.informClient(self)
#    2241 if cl is None:
#    2242     return False
# -> 2243 cl.informSites({'changedAttribute': 'duration',
#    2244                 'quarterLength': self._qtrLength})
#    2245 return True
#
# File c:\Users\ktrin\miniconda3\envs\tf\lib\site-packages\music21\base.py:2628, in Music21Object.informSites(self, changedInformation)
#    2625 for s in self.sites.get():
#    2626     if hasattr(s, 'coreElementsChanged'):
#    2627         # noinspection PyCallingNonCallable
# -> 2628         s.coreElementsChanged(updateIsFlat=False, keepIndex=True)
#
# File c:\Users\ktrin\miniconda3\envs\tf\lib\site-packages\music21\stream\core.py:266, in StreamCoreMixin.coreElementsChanged(self, updateIsFlat, clearIsSorted, memo, keepIndex)
#     262 # may not always need to clear cache of all living sites, but may
#     263 # always be a good idea since .flatten() has changed etc.
#     264 # should not need to do derivation.origin sites.
#     265 for livingSite in self.sites:
# --> 266     livingSite.coreElementsChanged(memo=memo)
#     268 # clear these attributes for setting later
#     269 if clearIsSorted:
#
# File c:\Users\ktrin\miniconda3\envs\tf\lib\site-packages\music21\stream\core.py:265, in StreamCoreMixin.coreElementsChanged(self, updateIsFlat, clearIsSorted, memo, keepIndex)
#     260         origin.clearCache()
#     262 # may not always need to clear cache of all living sites, but may
#     263 # always be a good idea since .flatten() has changed etc.
#     264 # should not need to do derivation.origin sites.
# --> 265 for livingSite in self.sites:
#     266     livingSite.coreElementsChanged(memo=memo)
#     268 # clear these attributes for setting later
#
# File c:\Users\ktrin\miniconda3\envs\tf\lib\site-packages\music21\sites.py:314, in Sites.__iter__(self)
#     300 def __iter__(self):
#     301     '''
#     302     Returns all non-None sites.  Order is oldest first.
#     303
#    (...)
#     312     <music21.stream.Stream thisStream> 20.0
#     313     '''
# --> 314     return self.yieldSites(excludeNone=True)
#
# KeyboardInterrupt:

# %%
# Data Pre-processing:
# 1. get all pitch name
pitchnames = sorted(set(item for item in notes))

# 2. create a dictionary to map pitches to integers (essentially OHE the pitches)
note_to_int = dict((note, number) for number, note in enumerate(pitchnames))


# 3. Creating a input/output sequences for the neural network
# The output for each sequence of length 100 is the first note or chord that come after the sequence of notes
sequence_length = 100
network_input = []
network_output = []

# create input sequences and the corresponding outputs
for i in range(0, len(notes) - sequence_length, 1):
    sequence_in = notes[i:i + sequence_length]
    sequence_out = notes[i + sequence_length]
    
    # map the input/output string(s) to a numerical value for training purposes
    network_input.append([note_to_int[char] for char in sequence_in])
    network_output.append(note_to_int[sequence_out])


# determine the number of different pattern generated
n_patterns = len(network_input)

# reshape the input into a format compatible with LSTM layers
# essentially, the array of array is to be reshape by(x_pattern, y_length, )
network_input = np.reshape(network_input, (n_patterns, sequence_length, 1))

# Post processing on input/outputs
# normalize input
# OHE the output -> so that softmax can be use to generate a probability
# network_input = network_input / len(pitchnames)
# network_output = tf.keras.utils.to_categorical(network_output)

# %%
# 4. Load the LSTM model to use in generating a piece of music
tf.keras.backend.clear_session()
np.random.seed(0)
tf.random.set_seed(0)

# Build a model using keras.Sequential.
model = keras.Sequential()

# Input a row of data into an LSTM layer
model.add(keras.layers.LSTM(
    512, 
    input_shape=(network_input.shape[1], network_input.shape[2]), 
    recurrent_dropout=0.3,
    return_sequences=True))


model.add(keras.layers.LSTM(512, return_sequences=True, recurrent_dropout=0.3,))
model.add(keras.layers.LSTM(512, return_sequences=True, recurrent_dropout=0.3,))
model.add(keras.layers.LSTM(512))
model.add(keras.layers.BatchNormalization())

# dropout ~30% of the first LSTM layer as a regularization technique
# Useful to prevent overfitting
model.add(keras.layers.Dropout(0.3))

# Add some hidden layers/ one more level of dropout layers
model.add(keras.layers.Dense(256, activation='relu'))
model.add(keras.layers.Dense(256, activation='relu'))
model.add(keras.layers.BatchNormalization())
model.add(keras.layers.Dropout(0.3))

# output layer with softmax activation on all the 
model.add(keras.layers.Dense(
    units = len(pitchnames),
    activation = "softmax"
))
          
# compile the model 
model.compile(loss="categorical_crossentropy", optimizer='adam', metrics=['accuracy'])

model.load_weights('../data/trainig_outputs/weights-improvement-30-0.3417-bigger.hdf5')
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
(network_input.shape[1], network_input.shape[2])
# Out:
# (100, 1)

# %%
# 5. initialize a random start sequence; generate a series of new notes using that sequence
np.random.seed(97)
start = np.random.randint(0, len(network_input)-1)
int_to_note = dict((number, note) for number, note in enumerate(pitchnames))
pattern = network_input[start]
prediction_output = []


# generate n new notes
for note_index in tqdm(range(500)):
    
    # data normalization
    prediction_input = np.reshape(pattern, (1, len(pattern), 1))
    prediction_input = prediction_input / float(len(pitchnames))
    
    # model prediction, add to list of pattern
    prediction = model.predict(prediction_input, verbose=0)
    index = np.argmax(prediction)
    result = int_to_note[index]
    prediction_output.append(result)
    
    # pop the first value from the input
    pattern = np.append(pattern, [index])
    pattern = pattern[1:len(pattern)]
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
prediction_output
# Out:
# ['A3',
#  'B-2',
#  'B-2',
#  'F3',
#  'B-3',
#  'F3',
#  'A2',
#  'A2',
#  'C3',
#  'F2',
#  'A3',
#  'G2',
#  'G2',
#  'D3',
#  'E-3',
#  'G3',
#  'D3',
#  'D3',
#  'A2',
#  'E3',
#  'A3',
#  'B-2',
#  'F3',
#  'A2',
#  'B-3',
#  'F3',
#  'B-2',
#  'C3',
#  'E3',
#  'F3',
#  'C4',
#  'E3',
#  'G2',
#  'D3',
#  'G3',
#  'D3',
#  'A2',
#  'E3',
#  'A3',
#  'B-2',
#  'F3',
#  'D3',
#  'B-3',
#  'E3',
#  'G3',
#  'A2',
#  'F3',
#  'E3',
#  'A3',
#  'D3',
#  'C3',
#  'E3',
#  'E-2',
#  'B-3',
#  'E-2',
#  'B-3',
#  'E-3',
#  'B-3',
#  'G3',
#  'A3',
#  'G3',
#  'F#3',
#  'E-3',
#  'D3',
#  'E-3',
#  'C3',
#  'G3',
#  'B-2',
#  'A2',
#  'G2',
#  'F#2',
#  'E2',
#  'D3',
#  'D2',
#  'F#3',
#  'F#2',
#  'D3',
#  'F#2',
#  'D3',
#  'A2',
#  'F#3',
#  'A2',
#  'F#3',
#  'D3',
#  'A3',
#  'D3',
#  'A3',
#  'D3',
#  'E-2',
#  'B-3',
#  'E-2',
#  'B-3',
#  'E-3',
#  'B-3',
#  'G3',
#  'A3',
#  'G3',
#  'F#3',
#  'E-3',
#  'D3',
#  'E-3',
#  'C3',
#  'G3',
#  'B-2',
#  'A2',
#  'G2',
#  'F#2',
#  'E2',
#  'D3',
#  'D2',
#  'F#3',
#  'D4',
#  'F#4',
#  'E-4',
#  'G4',
#  'D4',
#  'F#4',
#  'C4',
#  'E-4',
#  'B-3',
#  'D4',
#  'A3',
#  'C4',
#  'G3',
#  'B-3',
#  'F#3',
#  'A3',
#  'E-3',
#  'G3',
#  'D3',
#  'F#3',
#  'D3',
#  'G2',
#  'D3',
#  'G2',
#  'D3',
#  'D3',
#  'G3',
#  'B-3',
#  'G2',
#  'G3',
#  'G2',
#  'D3',
#  'E-3',
#  'G3',
#  'C4',
#  'G2',
#  'G3',
#  'G2',
#  'D3',
#  'F3',
#  'G3',
#  'D4',
#  'G2',
#  'B-3',
#  'G2',
#  'G3',
#  'E-3',
#  'G3',
#  'B-3',
#  'G2',
#  'G3',
#  'G2',
#  'D3',
#  'D3',
#  'G3',
#  'B-3',
#  'G2',
#  'D3',
#  'D3',
#  'D2',
#  'A3',
#  'D2',
#  'A3',
#  'A2',
#  'D3',
#  'F#3',
#  'D2',
#  'D3',
#  'D2',
#  'A3',
#  'B-2',
#  'D3',
#  'F#3',
#  'D2',
#  'D3',
#  'D2',
#  'B-3',
#  'C3',
#  'D3',
#  'A3',
#  'D2',
#  'F#3',
#  'D2',
#  'D3',
#  'B-2',
#  'D3',
#  'F#3',
#  'D2',
#  'D3',
#  'D2',
#  'A3',
#  'A2',
#  'D3',
#  'F#3',
#  'D2',
#  'A3',
#  'A2',
#  'G2',
#  'D3',
#  'G2',
#  'D3',
#  'D3',
#  'G3',
#  'B-3',
#  'G2',
#  'G3',
#  'G2',
#  'D3',
#  'E-3',
#  'G3',
#  'C4',
#  'G2',
#  'G3',
#  'G2',
#  'D3',
#  'F3',
#  'G3',
#  'D4',
#  'G2',
#  'B-3',
#  'G2',
#  'G3',
#  'E-3',
#  'G3',
#  'B-3',
#  'G2',
#  'G3',
#  'G2',
#  'D3',
#  'D3',
#  'G3',
#  'B-3',
#  'G2',
#  'D3',
#  'D3',
#  'D2',
#  'A3',
#  'D2',
#  'A3',
#  'A2',
#  'D3',
#  'F#3',
#  'D2',
#  'D3',
#  'D2',
#  'A3',
#  'B-2',
#  'D3',
#  'F#3',
#  'D2',
#  'D3',
#  'D2',
#  'B-3',
#  'C3',
#  'D3',
#  'A3',
#  'D2',
#  'F#3',
#  'D2',
#  'D3',
#  'B-2',
#  'D3',
#  'F#3',
#  'D2',
#  'D3',
#  'D2',
#  'A3',
#  'A2',
#  'D3',
#  'F#3',
#  'D2',
#  'A3',
#  'A2',
#  'G2',
#  'D3',
#  'G2',
#  'D3',
#  'D3',
#  'G3',
#  'B-3',
#  'G2',
#  'G3',
#  'G2',
#  'D3',
#  'E-3',
#  'G3',
#  'C4',
#  'G2',
#  'G3',
#  'G2',
#  'D3',
#  'F3',
#  'G3',
#  'D4',
#  'G2',
#  'B-3',
#  'G2',
#  'G3',
#  'E-3',
#  'G3',
#  'B-3',
#  'G2',
#  'G3',
#  'G2',
#  'D3',
#  'D3',
#  'G3',
#  'B-3',
#  'G2',
#  'D3',
#  'D3',
#  'D2',
#  'A3',
#  'D2',
#  'A3',
#  'A2',
#  'D3',
#  'F#3',
#  'D2',
#  'D3',
#  'D2',
#  'A3',
#  'B-2',
#  'D3',
#  'F#3',
#  'D2',
#  'D3',
#  'D2',
#  'B-3',
#  'C3',
#  'D3',
#  'A3',
#  'D2',
#  'F#3',
#  'D2',
#  'D3',
#  'B-2',
#  'D3',
#  'F#3',
#  'D2',
#  'D3',
#  'D2',
#  'A3',
#  'A2',
#  'D3',
#  'F#3',
#  'D2',
#  'A3',
#  'A2',
#  'G2',
#  'D3',
#  'G2',
#  'D3',
#  'D3',
#  'G3',
#  'B-3',
#  'G2',
#  'G3',
#  'G2',
#  'D3',
#  'E-3',
#  'G3',
#  'C4',
#  'G2',
#  'G3',
#  'G2',
#  'D3',
#  'F3',
#  'G3',
#  'D4',
#  'G2',
#  'B-3',
#  'G2',
#  'G3',
#  'E-3',
#  'G3',
#  'B-3',
#  'G2',
#  'G3',
#  'G2',
#  'D3',
#  'D3',
#  'G3',
#  'B-3',
#  'G2',
#  'D3',
#  'D3',
#  'D2',
#  'A3',
#  'D2',
#  'A3',
#  'A2',
#  'D3',
#  'F#3',
#  'D2',
#  'D3',
#  'D2',
#  'A3',
#  'B-2',
#  'D3',
#  'F#3',
#  'D2',
#  'D3',
#  'D2',
#  'B-3',
#  'C3',
#  'D3',
#  'A3',
#  'D2',
#  'F#3',
#  'D2',
#  'D3',
#  'B-2',
#  'D3',
#  'F#3',
#  'D2',
#  'D3',
#  'D2',
#  'A3',
#  'A2',
#  'D3',
#  'F#3',
#  'D2',
#  'A3',
#  'A2',
#  'G2',
#  'D3',
#  'G2',
#  'D3',
#  'D3',
#  'G3',
#  'B-3',
#  'G2',
#  'G3',
#  'G2',
#  'D3',
#  'E-3',
#  'G3',
#  'C4',
#  'G2',
#  'G3',
#  'G2',
#  'D3',
#  'F3',
#  'G3',
#  'D4',
#  'G2',
#  'B-3',
#  'G2',
#  'G3',
#  'E-3',
#  'G3',
#  'B-3',
#  'G2',
#  'G3',
#  'G2',
#  'D3',
#  'D3',
#  'G3',
#  'B-3',
#  'G2',
#  'D3',
#  'D3',
#  'D2',
#  'A3',
#  'D2',
#  'A3',
#  'A2',
#  'D3',
#  'F#3',
#  'D2',
#  'D3',
#  'D2',
#  'A3',
#  'B-2',
#  'D3',
#  'F#3',
#  'D2',
#  'D3',
#  'D2',
#  'B-3',
#  'C3',
#  'D3',
#  'A3',
#  'D2',
#  'F#3',
#  'D2',
#  'D3',
#  'B-2']

# %%
# 6. turning model encoedd output into music
# => decode the pattern into note/chord
# => if chord:
#       decode the cord into an array of notes
#       loop through the array of notes abd create a note object 
#       create chord object that encompasses all notes in the given chord
# => if note:
#       create note object and pitch contained in the pattern
# at each iteration, increase the offset by 0.5

offset = 0
output_notes = []

# create note and chord objects based on the values generated by the model
for pattern in prediction_output:
    # pattern is a chord
    if ('.' in pattern) or pattern.isdigit():
        notes_in_chord = pattern.split('.')
        notes = []
        for current_note in notes_in_chord:
            new_note = note.Note(int(current_note))
            new_note.storedInstrument = instrument.Piano()
            notes.append(new_note)
        new_chord = chord.Chord(notes)
        new_chord.offset = offset
        output_notes.append(new_chord)
    # pattern is a note
    else:
        new_note = note.Note(pattern)
        new_note.offset = offset
        new_note.storedInstrument = instrument.Piano()
        output_notes.append(new_note)
    # increase offset each iteration so that notes do not stack
    offset += 0.5

# %%
midi_stream = stream.Stream(output_notes)
midi_stream.write('midi', fp='../data/songs/test_output_06.mid')
# Out:
# '../data/songs/test_output_06.mid'

# %%
# 7. play the generated music
mf = midi.MidiFile()
mf.open('../data/songs/test_output_06.mid')
mf.read()
mf.close()
