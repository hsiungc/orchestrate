# %%
# import some useful libraries
import glob, nltk, joblib
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from keras import metrics

from PIL import Image
from tqdm.notebook import tqdm

from sklearn.feature_extraction.text import CountVectorizer

from music21 import midi
from plugins.midi2img import midi2img
from plugins.img2midi import img2midi
from IPython.display import clear_output

# %%
DATA_PATH = '../data/dataset'

# %%
# load in the metadata
# create a list of captions that concatenate the piece description and arousal
# lower case te caption list
midi_meta = pd.read_csv(f'{DATA_PATH}/commu_meta_desc.csv')
# midi_meta['caption_list'] = midi_meta['piece_description'].str.lower()+ ". " + midi_meta['piece_arousal'].str.lower()
midi_meta
# Out:
#      Unnamed: 0        audio_key  \
# 0           342  ['c', ' major']
# 1          7279  ['c', ' major']
# 2          2734  ['c', ' major']
# 3          6178  ['a', ' minor']
# 4          3041  ['a', ' minor']
# ..          ...              ...
# 191        5421  ['c', ' major']
# 192        3259  ['a', ' minor']
# 193        4716  ['c', ' major']
# 194        2651  ['a', ' minor']
# 195       10375  ['c', ' major']
#
#                                     chord_progressions   pitch_range  \
# 0    [['Dm7', 'Dm7', 'Dm7', 'Dm7', 'Gsus4', 'Gsus4'...  ['mid high']
# 1    [['C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'F',...  ['mid high']
# 2    [['C', 'C', 'C', 'C', 'G', 'G', 'G', 'G', 'Am7...       ['mid']
# 3    [['Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'A...       ['mid']
# 4    [['Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'A...       ['mid']
# ..                                                 ...           ...
# 191  [['C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'Dm7...   ['mid low']
# 192  [['Dm7', 'Dm7', 'Dm7', 'Dm7', 'Dm7', 'Dm7', 'D...  ['mid high']
# 193  [['Cmaj7', 'Cmaj7', 'Cmaj7', 'Cmaj7', 'G', 'G'...      ['high']
# 194  [['Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'Am', 'A...       ['mid']
# 195  [['Cmaj7', 'Cmaj7', 'Cmaj7', 'Cmaj7', 'Cmaj7',...       ['low']
#
#      num_measures  bpm      genre         track_role                 inst  \
# 0               8   65    new age    ['main melody']   ['acoustic piano']
# 1               8   90  cinematic    ['main melody']       ['vibraphone']
# 2               4  100    new age            ['pad']   ['acoustic piano']
# 3               8   70    new age            ['pad']        ['synth pad']
# 4               8   85  cinematic  ['accompaniment']  ['string ensemble']
# ..            ...  ...        ...                ...                  ...
# 191             8   50    new age            ['pad']  ['string ensemble']
# 192             8   80  cinematic     ['sub melody']   ['acoustic piano']
# 193             8   80  cinematic     ['sub melody']   ['acoustic piano']
# 194             8  120  cinematic  ['accompaniment']  ['string ensemble']
# 195             8   80  cinematic           ['bass']   ['acoustic piano']
#
#     sample_rhythm time_signature  min_velocity  max_velocity split_data  \
# 0        standard          4-Apr            33            40      train
# 1        standard          4-Apr            56            70      train
# 2        standard          4-Apr            33            42      train
# 3        standard          4-Apr            81            82      train
# 4        standard          4-Apr            63           124      train
# ..            ...            ...           ...           ...        ...
# 191      standard          4-Apr            81            82      train
# 192      standard          4-Apr            38            56      train
# 193      standard          4-Apr            31            58      train
# 194      standard          4-Apr            99           100      train
# 195      standard          4-Apr            41            49      train
#
#              id                                        description  \
# 0    commu00343  "Whispers of Lucid Skies"\nTraversing ethereal...
# 1    commu07280  "An enchanting symphony of soaring dreams, whe...
# 2    commu02735  "Uncharted Melody: A harmonious journey throug...
# 3    commu06179  "Whispers of Shadows: A Melody's Dance in the ...
# 4    commu03042  "Whispers of Shadows" - A haunting symphony, w...
# ..          ...                                                ...
# 191  commu05422  "Melodic whispers under a starlit sky, embraci...
# 192  commu03260  "Whispers in Shadows: An Enchanting Melody Awa...
# 193  commu04717  "Whispers of cinematic dreams unfold, as a you...
# 194  commu02652  "Lost in Shadows: The Enigmatic Serenade paint...
# 195  commu10376  "Enchanting Echoes of a Whimsical Journey: A L...
#
#                                       description_list  \
# 0    whispers of lucid skies traversing ethereal re...
# 1    an enchanting symphony of soaring dreams where...
# 2    uncharted melody a harmonious journey through ...
# 3    whispers of shadows a melodys dance in the twi...
# 4    whispers of shadows a haunting symphony where ...
# ..                                                 ...
# 191  melodic whispers under a starlit sky embracing...
# 192  whispers in shadows an enchanting melody awake...
# 193  whispers of cinematic dreams unfold as a young...
# 194  lost in shadows the enigmatic serenade paintin...
# 195  enchanting echoes of a whimsical journey a lus...
#
#                                           caption_list
# 0    c,  major, mid high, main melody, new age, aco...
# 1    c,  major, mid high, main melody, cinematic, v...
# 2         c,  major, mid, pad, new age, acoustic piano
# 3              a,  minor, mid, pad, new age, synth pad
# 4    a,  minor, mid, accompaniment, cinematic, stri...
# ..                                                 ...
# 191  c,  major, mid low, pad, new age, string ensemble
# 192  a,  minor, mid high, sub melody, cinematic, ac...
# 193  c,  major, high, sub melody, cinematic, acoust...
# 194  a,  minor, mid, accompaniment, cinematic, stri...
# 195    c,  major, low, bass, cinematic, acoustic piano
#
# [196 rows x 18 columns]

# %%
# read in music and prepare it in a list of notes
midis = []
for file in tqdm(glob.glob(f"{DATA_PATH}/commu_midi/train/raw/*.mid")):
    midis.append(file)

for file in tqdm(glob.glob(f"{DATA_PATH}/commu_midi/val/raw/*.mid")):
    midis.append(file)
# Out:
#   0%|          | 0/10381 [00:00<?, ?it/s]
#   0%|          | 0/763 [00:00<?, ?it/s]

# %%
# convert MIDI to image
# declare output path
output_path = f"{DATA_PATH}/commu_img/train_desc"

# instantiate a midi2img converter object
midi2img_obj = midi2img(output_path)

# for each midi file, convert it to image
for midi in tqdm(midis):
    data, metadata = midi2img_obj.convert_to_image(midi)
    for img_key in data.keys():
        try:
            # if img_key[-1:] != "0": continue
            img_path = output_path+"/"+midi.split("/")[-1].replace(".mid",f"_{img_key}.png")
            img = Image.open(img_path)
            basewidth = 106
            hsize = 106
            img = img.resize((basewidth,hsize), Image.ANTIALIAS)
            img.save(img_path)
        except Exception as e:
            print("Error in converting: ", e)
            pass
# Out:
#   0%|          | 0/11144 [00:00<?, ?it/s]
# C:\Users\ktrin\AppData\Local\Temp\ipykernel_17100\2840756171.py:18: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   img = img.resize((basewidth,hsize), Image.ANTIALIAS)
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00001_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00002_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00003_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00004_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00005_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00006_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00007_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00008_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00009_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00010_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00011_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00012_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00013_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00014_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00015_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00016_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00017_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00018_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00019_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00020_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00021_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00022_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00023_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00024_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00025_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00026_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00027_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00028_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00029_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00030_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00031_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00032_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00033_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00034_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00035_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00036_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00037_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00038_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00039_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00040_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00041_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00042_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00043_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00044_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00045_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00046_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00047_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00048_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00049_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00050_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00051_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00052_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00053_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00054_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00055_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00056_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00057_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00058_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00059_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00060_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00061_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00062_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00063_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00064_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00065_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00066_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00067_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00068_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00069_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00070_Piano_0.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00071_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00072_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00073_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00074_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00075_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00076_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00077_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00078_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00079_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00080_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00081_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00082_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00083_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00084_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00085_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00086_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00087_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00088_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00089_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00090_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00091_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00092_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00093_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00094_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00095_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00096_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00097_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00098_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00099_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00100_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00101_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00102_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00103_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00104_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00105_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00106_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00107_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00108_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00109_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00110_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00111_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00112_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00113_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00114_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00115_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00116_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00117_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00118_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00119_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00120_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00121_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00122_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00123_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00124_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00125_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00126_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00127_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00128_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00129_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00130_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00131_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00132_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00133_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00134_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00135_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00136_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00137_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00138_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00139_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00140_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00141_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00142_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00143_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00144_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00145_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00146_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00147_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00148_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00149_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00150_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00151_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00152_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00153_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00154_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00155_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00156_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00157_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00158_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00159_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00160_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00161_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00162_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00163_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00164_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00165_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00166_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00167_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00168_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00169_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00170_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00171_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00172_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00173_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00174_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00175_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00176_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00177_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00178_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00179_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00180_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00181_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00182_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00183_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00184_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00185_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00186_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00187_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00188_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00189_Piano_3.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00190_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00191_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00192_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00193_Piano_3.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00194_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00195_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00196_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00197_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00198_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00199_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00200_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00201_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00202_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00203_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00204_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00205_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00206_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00207_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00208_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00209_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00210_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00211_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00212_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00213_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00214_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00215_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00216_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00217_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00218_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00219_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00220_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00221_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00222_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00223_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00224_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00225_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00226_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00227_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00228_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00229_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00230_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00231_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00232_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00233_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00234_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00235_Piano_0.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00236_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00237_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00238_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00239_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00240_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00241_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00242_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00243_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00244_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00245_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00246_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00247_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00248_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00249_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00250_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00251_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00252_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00253_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00254_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00255_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00256_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00257_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00258_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00259_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00260_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00261_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00262_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00263_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00264_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00265_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00266_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00267_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00268_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00269_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00270_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00271_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00272_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00273_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00274_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00275_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00276_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00277_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00278_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00279_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00280_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00281_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00282_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00283_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00284_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00285_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00286_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00287_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00288_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00289_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00290_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00291_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00292_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00293_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00294_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00295_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00296_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00297_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00298_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00299_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00300_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00301_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00302_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00303_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00304_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00305_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00306_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00307_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00308_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00309_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00310_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00311_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00312_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00313_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00314_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00315_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00316_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00317_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00318_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00319_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00320_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00321_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00322_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00323_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00324_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00325_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00326_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00327_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00328_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00329_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00330_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00331_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00332_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00333_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00334_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00335_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00336_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00337_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00338_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00339_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00340_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00341_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00342_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00343_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00344_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00345_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00346_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00347_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00348_Piano_3.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00349_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00350_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00351_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00352_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00353_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00354_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00355_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00356_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00357_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00358_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00359_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00360_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00361_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00362_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00363_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00364_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00365_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00366_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00367_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00368_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00369_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00370_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00371_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00372_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00373_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00374_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00375_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00376_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00377_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu00378_Piano_2.png'
# ...
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11019_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11020_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11021_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11022_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11023_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11024_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11025_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11026_Piano_3.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11027_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11028_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11029_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11030_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11031_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11032_Piano_3.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11033_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11034_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11035_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11036_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11037_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11038_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11039_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11040_Piano_3.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11041_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11042_Piano_3.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11043_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11044_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11045_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11046_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11047_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11048_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11049_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11050_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11051_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11052_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11053_Piano_3.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11054_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11055_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11056_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11057_Piano_3.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11058_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11059_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11060_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11061_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11062_Piano_3.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11063_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11064_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11065_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11066_Piano_3.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11067_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11068_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11069_Piano_3.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11070_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11071_Piano_3.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11072_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11073_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11074_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11075_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11076_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11077_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11078_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11079_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11080_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11081_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11082_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11083_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11084_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11085_Piano_3.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11086_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11087_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11088_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11089_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11090_Piano_3.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11091_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11092_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11093_Piano_3.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11094_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11095_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11096_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11097_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11098_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11099_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11100_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11101_Piano_0.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11102_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11103_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11104_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11105_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11106_Piano_0.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11107_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11108_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11109_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11110_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11111_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11112_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11113_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11114_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11115_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11116_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11117_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11118_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11119_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11120_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11121_Piano_0.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11122_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11123_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11124_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11125_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11126_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11127_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11128_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11129_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11130_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11131_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11132_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11133_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11134_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11135_Piano_0.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11136_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11137_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11138_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11139_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11140_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11141_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11142_Piano_1.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11143_Piano_2.png'
# Error in converting:  [Errno 2] No such file or directory: '../data/dataset/commu_img/train_desc/raw\\commu11144_Piano_1.png'

# %%
# Dataset Construction
def access_images(path, metadata, piece_name='piece_name', num_images=float("inf")):
    """
        Fetch a defined number of images from a directory
        and return their normalized pixels arrays
        Inputs:
            path: path to the directory containing the images
            img_list: list of image names
            num_images: number of images to fetch
        Output:
            image_arr: pixel array of images
            img: the original image
    """
    pixels = {}

    # shuffle the metadata to get a random sample
    if num_images != float("inf"):
        metadata = metadata.sample(n=num_images).reset_index(drop=True)
    else:
        metadata = metadata.sample(frac=1).reset_index(drop=True)

    i = 0
    # construct a dictionary of empty lists with the song name
    for piece in tqdm(metadata[piece_name].unique()):
        if i >= num_images:
            break
        
        # construct the file path for the image
        file = f"{path}/{piece}_Piano_0.png"
        try:
            # Normalize the image
            img = Image.open(file, 'r')
            img = img.convert('1')
            pix = np.array(img.getdata())
            pix = pix.astype('float32')
            pix /= 255.0

            # pixels.append(pix.reshape(106,106,1))
            # once a valid image is found, break the loop
            if piece not in pixels.keys():

                pixels[piece] = [pix.reshape(106,106,1)]
            else:
                pixels[piece].append(pix.reshape(106,106,1))

        except Exception as e:
            # print("Error in fetching: ", e)
            pass
        i+=1
    return pixels

img_dir = f"{DATA_PATH}/commu_img/train_desc/raw"
# get train data only
# midi_meta = midi_meta[midi_meta['split_data'] == 'train']
pixels_arr = access_images(img_dir, midi_meta, piece_name='id')
len(pixels_arr.keys())
# Out:
#   0%|          | 0/196 [00:00<?, ?it/s]
# 195

# %%
# # Dataset Construction
# def access_images(path, metadata, piece_name='piece_name', num_images=float("inf")):
#     """
#         Fetch a defined number of images from a directory
#         and return their normalized pixels arrays
#         Inputs:
#             path: path to the directory containing the images
#             img_list: list of image names
#             num_images: number of images to fetch
#         Output:
#             image_arr: pixel array of images
#             img: the original image
#     """
#     pixels = {}

#     # shuffle the metadata to get a random sample
#     metadata = metadata.sample(n=num_images).reset_index(drop=True)

#     # fetch all images from the directory
#     i = 0
#     # construct a dictionary of empty lists with the song name
#     for piece in tqdm(metadata[piece_name].unique()):
#         # if row['piece_name'] not in pixels.keys():
#         #     pixels[row['piece_name']] = []
#         if i >= num_images:
#             break

#         for file in (glob.glob(f"{path}/*.png")):
#             try:
#                 img_path = file.split("/")[-1]
#                 # ignore the images that are not the first image
#                 if img_path[-5:-4] != '0':
#                     continue

#                 # Normalize the image
#                 img = Image.open(file, 'r')
#                 img = img.convert('1')
#                 pix = np.array(img.getdata())
#                 pix = pix.astype('float32')
#                 pix /= 255.0

#                 # pixels.append(pix.reshape(106,106,1))
#                 # once a valid image is found, break the loop
#                 if img_path.find(piece) != -1:
#                     if piece not in pixels.keys():
#                         pixels[piece] = [pix.reshape(106,106,1)]
#                     else:
#                         pixels[piece].append(pix.reshape(106,106,1))
#                     break

#             except Exception as e:
#                 print("Error in fetching: ", e)
#                 pass

#         i += 1
#     return pixels


# img_dir = f"{DATA_PATH}/commu_img/train/raw"
# # get train data only
# midi_meta = midi_meta[midi_meta['split_data'] == 'train']
# pixels_arr = access_images(img_dir, midi_meta, piece_name='id', num_images=2048)
# pixels_arr.keys()
# # np.unique(pixels_arr['commu00001'])

# %%
# create a dataframe of image arrays and piece names
join_col = 'id'
sound_image = pd.DataFrame(columns=[join_col, 'image_array'])#from_dict(pixels_arr, orient='index').reset_index()
sound_image[join_col] = pixels_arr.keys()
sound_image['image_array'] = pixels_arr.values()
sound_image

# merge with metadata
midi_meta = midi_meta.merge(sound_image, on=join_col, how='left').dropna(subset=[join_col])


# create image-caption pairs
training_set = []
for i, row in midi_meta.iterrows():
    caption = row['description_list']
    images = row['image_array']
    id = row['id']
    try:
        for image in images:
            training_set.append((id, image, caption))
    except:
        pass

# %%
# save data as joblib
joblib.dump(training_set, f'{DATA_PATH}/training_set_desc.joblib')
# Out:
# ['../data/dataset/training_set_desc.joblib']
