# %%
# !pip install mido
# !pip install pygame
# !pip install music21
# Out:
# Requirement already satisfied: mido in c:\users\ktrin\miniconda3\envs\w266\lib\site-packages (1.3.0)
# Requirement already satisfied: packaging~=23.1 in c:\users\ktrin\miniconda3\envs\w266\lib\site-packages (from mido) (23.1)
# Requirement already satisfied: pygame in c:\users\ktrin\miniconda3\envs\w266\lib\site-packages (2.5.1)
# Requirement already satisfied: music21 in c:\users\ktrin\miniconda3\envs\w266\lib\site-packages (7.3.3)
# Requirement already satisfied: more-itertools in c:\users\ktrin\miniconda3\envs\w266\lib\site-packages (from music21) (8.13.0)
# Requirement already satisfied: webcolors>=1.5 in c:\users\ktrin\miniconda3\envs\w266\lib\site-packages (from music21) (1.12)
# Requirement already satisfied: numpy in c:\users\ktrin\miniconda3\envs\w266\lib\site-packages (from music21) (1.23.1)
# Requirement already satisfied: joblib in c:\users\ktrin\miniconda3\envs\w266\lib\site-packages (from music21) (1.1.0)
# Requirement already satisfied: chardet in c:\users\ktrin\miniconda3\envs\w266\lib\site-packages (from music21) (5.0.0)
# Requirement already satisfied: matplotlib in c:\users\ktrin\miniconda3\envs\w266\lib\site-packages (from music21) (3.5.2)
# Requirement already satisfied: jsonpickle in c:\users\ktrin\miniconda3\envs\w266\lib\site-packages (from music21) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ktrin\miniconda3\envs\w266\lib\site-packages (from matplotlib->music21) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ktrin\miniconda3\envs\w266\lib\site-packages (from matplotlib->music21) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ktrin\miniconda3\envs\w266\lib\site-packages (from matplotlib->music21) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ktrin\miniconda3\envs\w266\lib\site-packages (from matplotlib->music21) (23.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ktrin\miniconda3\envs\w266\lib\site-packages (from matplotlib->music21) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ktrin\miniconda3\envs\w266\lib\site-packages (from matplotlib->music21) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ktrin\miniconda3\envs\w266\lib\site-packages (from matplotlib->music21) (4.34.4)
# Requirement already satisfied: six>=1.5 in c:\users\ktrin\miniconda3\envs\w266\lib\site-packages (from python-dateutil>=2.7->matplotlib->music21) (1.16.0)

# %%
# import some useful libraries
import glob
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras import metrics
from PIL import Image
from tqdm.notebook import tqdm

from music21 import midi
from plugins.midi2img import midi2img
from plugins.img2midi import img2midi
from IPython.display import clear_output
# Out:
# ---------------------------------------------------------------------------
# AlreadyExistsError                        Traceback (most recent call last)
# e:\UNIXSpace\Git_Desktop\Berkeley-MIDS\Classes\W210 - Capstone\w210-capstone-fall2023\workspace\museGAN_experiment.ipynb Cell 2 line <cell line: 8>()
#       <a href='vscode-notebook-cell:/e%3A/UNIXSpace/Git_Desktop/Berkeley-MIDS/Classes/W210%20-%20Capstone/w210-capstone-fall2023/workspace/museGAN_experiment.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> import tensorflow as tf
#       <a href='vscode-notebook-cell:/e%3A/UNIXSpace/Git_Desktop/Berkeley-MIDS/Classes/W210%20-%20Capstone/w210-capstone-fall2023/workspace/museGAN_experiment.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a> from tensorflow import keras
# ----> <a href='vscode-notebook-cell:/e%3A/UNIXSpace/Git_Desktop/Berkeley-MIDS/Classes/W210%20-%20Capstone/w210-capstone-fall2023/workspace/museGAN_experiment.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a> from keras import metrics
#       <a href='vscode-notebook-cell:/e%3A/UNIXSpace/Git_Desktop/Berkeley-MIDS/Classes/W210%20-%20Capstone/w210-capstone-fall2023/workspace/museGAN_experiment.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a> from PIL import Image
#      <a href='vscode-notebook-cell:/e%3A/UNIXSpace/Git_Desktop/Berkeley-MIDS/Classes/W210%20-%20Capstone/w210-capstone-fall2023/workspace/museGAN_experiment.ipynb#W1sZmlsZQ%3D%3D?line=9'>10</a> from tqdm.notebook import tqdm
#
# File c:\Users\ktrin\miniconda3\envs\W266\lib\site-packages\keras\__init__.py:25, in <module>
#      22 from keras import distribute
#      24 # See b/110718070#comment18 for more details about this import.
# ---> 25 from keras import models
#      27 from keras.engine.input_layer import Input
#      28 from keras.engine.sequential import Sequential
#
# File c:\Users\ktrin\miniconda3\envs\W266\lib\site-packages\keras\models.py:20, in <module>
#      18 import tensorflow.compat.v2 as tf
#      19 from keras import backend
# ---> 20 from keras import metrics as metrics_module
#      21 from keras import optimizer_v1
#      22 from keras.engine import functional
#
# File c:\Users\ktrin\miniconda3\envs\W266\lib\site-packages\keras\metrics.py:24, in <module>
#      21 from typing import List, Tuple, Union
#      22 import warnings
# ---> 24 from keras import activations
#      25 from keras import backend
#      26 from keras.engine import base_layer
#
# File c:\Users\ktrin\miniconda3\envs\W266\lib\site-packages\keras\activations.py:20, in <module>
#      17 import tensorflow.compat.v2 as tf
#      19 from keras import backend
# ---> 20 from keras.layers import advanced_activations
#      21 from keras.utils.generic_utils import deserialize_keras_object
#      22 from keras.utils.generic_utils import serialize_keras_object
#
# File c:\Users\ktrin\miniconda3\envs\W266\lib\site-packages\keras\layers\__init__.py:23, in <module>
#      20 from tensorflow.python import tf2
#      22 # Generic layers.
# ---> 23 from keras.engine.input_layer import Input
#      24 from keras.engine.input_layer import InputLayer
#      25 from keras.engine.input_spec import InputSpec
#
# File c:\Users\ktrin\miniconda3\envs\W266\lib\site-packages\keras\engine\input_layer.py:21, in <module>
#      19 from keras import backend
#      20 from keras.distribute import distributed_training_utils
# ---> 21 from keras.engine import base_layer
#      22 from keras.engine import keras_tensor
#      23 from keras.engine import node as node_module
#
# File c:\Users\ktrin\miniconda3\envs\W266\lib\site-packages\keras\engine\base_layer.py:43, in <module>
#      41 from keras.engine import node as node_module
#      42 from keras.mixed_precision import autocast_variable
# ---> 43 from keras.mixed_precision import loss_scale_optimizer
#      44 from keras.mixed_precision import policy
#      45 from keras.saving.saved_model import layer_serialization
#
# File c:\Users\ktrin\miniconda3\envs\W266\lib\site-packages\keras\mixed_precision\loss_scale_optimizer.py:18, in <module>
#      15 """Contains the loss scaling optimizer class."""
#      17 from keras import backend
# ---> 18 from keras import optimizers
#      19 from keras.mixed_precision import loss_scale as keras_loss_scale_module
#      20 from keras.optimizer_experimental import optimizer as optimizer_experimental
#
# File c:\Users\ktrin\miniconda3\envs\W266\lib\site-packages\keras\optimizers.py:31, in <module>
#      29 from keras.optimizer_v1 import Optimizer
#      30 from keras.optimizer_v1 import TFOptimizer
# ---> 31 from keras.optimizer_v2 import adadelta as adadelta_v2
#      32 from keras.optimizer_v2 import adagrad as adagrad_v2
#      33 from keras.optimizer_v2 import adam as adam_v2
#
# File c:\Users\ktrin\miniconda3\envs\W266\lib\site-packages\keras\optimizer_v2\adadelta.py:22, in <module>
#      20 import numpy as np
#      21 from keras import backend_config
# ---> 22 from keras.optimizer_v2 import optimizer_v2
#      23 from tensorflow.python.util.tf_export import keras_export
#      26 @keras_export('keras.optimizers.Adadelta')
#      27 class Adadelta(optimizer_v2.OptimizerV2):
#
# File c:\Users\ktrin\miniconda3\envs\W266\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:36, in <module>
#      32 import tensorflow.compat.v2 as tf
#      33 from tensorflow.python.util.tf_export import keras_export
# ---> 36 keras_optimizers_gauge = tf.__internal__.monitoring.BoolGauge(
#      37     "/tensorflow/api/keras/optimizers", "keras optimizer usage", "method")
#      39 _DEFAULT_VALID_DTYPES = frozenset([
#      40     tf.float16, tf.bfloat16, tf.float32, tf.float64,
#      41     tf.complex64, tf.complex128
#      42 ])
#      45 def _deduplicate_indexed_slices(values, indices):
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\monitoring.py:360, in BoolGauge.__init__(self, name, description, *labels)
#     352 def __init__(self, name, description, *labels):
#     353   """Creates a new BoolGauge.
#     354
#     355   Args:
#    (...)
#     358     *labels: The label list of the new metric.
#     359   """
# --> 360   super(BoolGauge, self).__init__('BoolGauge', _bool_gauge_methods,
#     361                                   len(labels), name, description, *labels)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\monitoring.py:135, in Metric.__init__(self, metric_name, metric_methods, label_length, *args)
#     131 if label_length >= len(self._metric_methods):
#     132   raise ValueError('Cannot create {} metric with label >= {}'.format(
#     133       self._metric_name, len(self._metric_methods)))
# --> 135 self._metric = self._metric_methods[self._label_length].create(*args)
#
# AlreadyExistsError: Another metric with the same name already exists.

# %% [markdown]
# # Load In museGAN dataset for visualization purposes
# It turned out that the people at museGAN is leveraging midi -> image conversion. The image consisted of bar of a multi track piano roll. From the below image, the horizontal represent time and the vericle represent the instrument used. In this dataset the instrument are layered from bottom to top as piano, strings, guitar, drums, bass.

# %%
# # load museGAN NPZ file
# data = np.load('../data/train_x_lpd_5_phr.npz')
# lst = data.files

# midi_images = data[lst[0]]

# print(f"Data Summary")
# print(data[lst[0]])
# print(f"Data Shape: {midi_images.shape}") 


# # plot the sound image
# plt.clf()
# plt.imshow(midi_images[:, :10])

# %% [markdown]
# # Construction of museGAN
# ## External Data Source
# For whatever reason, if we wanted to perform GAN modeling, we can leverage conversion of MIDI data to that of the piano roll. Download the data from piano repo in README and start performing the things below. [Convert-MIDI-TO-NP-ARRAY](https://medium.com/analytics-vidhya/convert-midi-file-to-numpy-array-in-python-7d00531890c)

# %%
# read in music and prepare it in a list of notes
midis = []
for file in tqdm(glob.glob("../data/piano/*.mid")):
    midis.append(file)
    
# test read MIDI file
mf = midi.MidiFile()
mf.open(midis[0]) 
mf.read()
mf.close()
s = midi.translate.midiFileToStream(mf)
s.show('midi')
# Out:
#   0%|          | 0/92 [00:00<?, ?it/s]
#                 <div id='midiPlayerDiv120039'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv120039');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
# Use MIDI2IMG to convert MIDI to image
midi_path = midis[0]
output_path = "../data/midi_img"
midi2img_obj = midi2img(output_path, resolution=0.25, maxSongLength=600)
data, metadata = midi2img_obj.convert_to_image(midi_path)
print(f"Numer of repetitions: {len(data.keys())}")
# Out:
# Numer of repetitions: 5

# %%
# Plot MIDI images
plt.figure(figsize=(12,12))
for i in range(len(data.keys())):
    data_key = list(data.keys())[i]
    img = data[data_key]
    plt.subplot(len(data.keys()), 1, i+1)
    plt.imshow(img, cmap='gray', vmin=img.min(), vmax=img.max())
    plt.axis('off')
    plt.title(data_key + str(i+1))
plt.show()

# %%
# reconvert MIDI images to MIDI files
image_path = "../data/midi_img/piano/0fithos_Created_0.png"
output_path = "../data/midi_reconstruction"

img2midi_obj = img2midi(image_path, output_path, resolution=0.25)
img2midi_obj.convert_to_midi()

# %%
# # run to cell to play
# # stop the cell and run sp.stop to stop the music
# mf = midi.MidiFile()
# mf.open(f"{output_path}/music.mid")
# mf.read()
# mf.close()
# s = midi.translate.midiFileToStream(mf)
# sp = midi.realtime.StreamPlayer(s)
# sp.play()

# %%
# sp.stop()

# %% [markdown]
# ## Dataset Construction

# %%
# declare output path
output_path = "../data/midi_img"

# instantiate a midi2img converter object
midi2img_obj = midi2img(output_path)

# for each midi file, convert it to image
for midi in tqdm(midis):
    data, metadata = midi2img_obj.convert_to_image(midi)
    for img_key in data.keys():
        try:
            img_path = output_path+"/"+midi.split("/")[-1].replace(".mid",f"_{img_key}.png")
            # print(img_path)
            img = Image.open(img_path)
            basewidth = 106
            hsize = 106
            img = img.resize((basewidth,hsize), Image.ANTIALIAS)
            img.save(img_path)
        except:
            print("Error in converting: "+img_path)
            pass
# Out:
#   0%|          | 0/92 [00:00<?, ?it/s]
# C:\Users\ktrin\AppData\Local\Temp\ipykernel_10292\3716288181.py:17: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   img = img.resize((basewidth,hsize), Image.ANTIALIAS)
# Error in converting: ../data/midi_img/piano\0fithos_Created_19.png
# Error in converting: ../data/midi_img/piano\8_Piano_4.png
# Error in converting: ../data/midi_img/piano\ahead_on_our_way_piano_Piano_15.png
# Error in converting: ../data/midi_img/piano\AT_Acoustic Guitar_17.png
# Error in converting: ../data/midi_img/piano\balamb_Right Hand_12.png
# Error in converting: ../data/midi_img/piano\bcm_Right Hand_10.png
# Error in converting: ../data/midi_img/piano\BlueStone_LastDungeon_Right Hand_13.png
# Error in converting: ../data/midi_img/piano\braska_Piano_6.png
# Error in converting: ../data/midi_img/piano\caitsith_Right Hand_73.png
# Error in converting: ../data/midi_img/piano\Cids_Piano_11.png
# Error in converting: ../data/midi_img/piano\cosmo_Right Hand_18.png
# Error in converting: ../data/midi_img/piano\costadsol_Right Hand_6.png
# Error in converting: ../data/midi_img/piano\dayafter_Right Hand_9.png
# Error in converting: ../data/midi_img/piano\decisive_Right Hand_8.png
# Error in converting: ../data/midi_img/piano\dontbeafraid_Piano_19.png
# Error in converting: ../data/midi_img/piano\DOS_Right Hand_11.png
# Error in converting: ../data/midi_img/piano\electric_de_chocobo_Right Hand_10.png
# Error in converting: ../data/midi_img/piano\Eternal_Harvest_Eternal Harvest_21.png
# Error in converting: ../data/midi_img/piano\EyesOnMePiano_Staff_12.png
# Error in converting: ../data/midi_img/piano\EyesOnMePiano_Staff-2_11.png
# Error in converting: ../data/midi_img/piano\ff11_awakening_piano_Piano_14.png
# Error in converting: ../data/midi_img/piano\ff1battp_Piano_9.png
# Error in converting: ../data/midi_img/piano\FF3_Battle_(Piano)_BD_7.png
# Error in converting: ../data/midi_img/piano\FF3_Third_Phase_Final_(Piano)_Piano_16.png
# Error in converting: ../data/midi_img/piano\ff4-airship_Right Hand_6.png
# Error in converting: ../data/midi_img/piano\Ff4-BattleLust_Right Hand_40.png
# Error in converting: ../data/midi_img/piano\ff4-fight1_Right Hand_11.png
# Error in converting: ../data/midi_img/piano\ff4-town_Right Hand_6.png
# Error in converting: ../data/midi_img/piano\FF4_Right Hand_15.png
# Error in converting: ../data/midi_img/piano\ff4pclov_Piano_11.png
# Error in converting: ../data/midi_img/piano\ff4_piano_collections-main_theme_Right Hand_16.png
# Error in converting: ../data/midi_img/piano\FF6epitaph_piano_Track 1_4.png
# Error in converting: ../data/midi_img/piano\ff6shap_Piano_9.png
# Error in converting: ../data/midi_img/piano\Ff7-Cinco_Piano_10.png
# Error in converting: ../data/midi_img/piano\Ff7-Jenova_Absolute_Right Hand_8.png
# Error in converting: ../data/midi_img/piano\ff7-mainmidi_Right Hand_4.png
# Error in converting: ../data/midi_img/piano\Ff7-One_Winged_Right Hand_21.png
# Error in converting: ../data/midi_img/piano\ff7themep_Main Theme of Final Fantasy VII_10.png
# Error in converting: ../data/midi_img/piano\ff8-lfp_Piano_19.png
# Error in converting: ../data/midi_img/piano\FF8_Shuffle_or_boogie_pc_Right Hand_18.png
# Error in converting: ../data/midi_img/piano\FFIII_Edgar_And_Sabin_Piano_Right Hand_9.png
# Error in converting: ../data/midi_img/piano\FFIXQuMarshP_Piano_9.png
# Error in converting: ../data/midi_img/piano\FFIX_Piano_Right Hand_6.png
# Error in converting: ../data/midi_img/piano\FFVII_BATTLE_Piano_5.png
# Error in converting: ../data/midi_img/piano\FFX_-_Ending_Theme_(Piano_Version)_-_by_Angel_FF_Piano_13.png
# Error in converting: ../data/midi_img/piano\Fiend_Battle_(Piano)_Right Hand_12.png
# Error in converting: ../data/midi_img/piano\Fierce_Battle_(Piano)_Right Hand_8.png
# Error in converting: ../data/midi_img/piano\figaro_Right Hand_6.png
# Error in converting: ../data/midi_img/piano\Finalfantasy5gilgameshp_Piano_11.png
# Error in converting: ../data/midi_img/piano\Finalfantasy6fanfarecomplete_G_8.png
# Error in converting: ../data/midi_img/piano\Final_Fantasy_7_-_Judgement_Day_Piano_Electric Piano_6.png
# Error in converting: ../data/midi_img/piano\Final_Fantasy_Matouyas_Cave_Piano_Right Hand_7.png
# Error in converting: ../data/midi_img/piano\fortresscondor_Right Hand_10.png
# Error in converting: ../data/midi_img/piano\Fyw_piano_Staff_187.png
# Error in converting: ../data/midi_img/piano\gerudo_Right Hand_13.png
# Error in converting: ../data/midi_img/piano\goldsaucer_Right Hand_15.png
# Error in converting: ../data/midi_img/piano\Gold_Silver_Rival_Battle_Piano_16.png
# Error in converting: ../data/midi_img/piano\great_war_Right Hand_25.png
# Error in converting: ../data/midi_img/piano\HighwindTakestotheSkies_Staff_14.png
# Error in converting: ../data/midi_img/piano\In_Zanarkand_Piano_10.png
# Error in converting: ../data/midi_img/piano\JENOVA_Right Hand_40.png
# Error in converting: ../data/midi_img/piano\Kingdom_Hearts_Dearly_Beloved_Right Hand_6.png
# Error in converting: ../data/midi_img/piano\Kingdom_Hearts_Traverse_Town_Staff_6.png
# Error in converting: ../data/midi_img/piano\Life_Stream_Right Hand_22.png
# Error in converting: ../data/midi_img/piano\lurk_in_dark_Right Hand_8.png
# Error in converting: ../data/midi_img/piano\mining_Right Hand_4.png
# Error in converting: ../data/midi_img/piano\Oppressed_Right Hand_7.png
# Error in converting: ../data/midi_img/piano\OTD5YA_Right Hand_13.png
# Error in converting: ../data/midi_img/piano\path_of_repentance_Right_6.png
# Error in converting: ../data/midi_img/piano\pkelite4_Right Hand_4.png
# Error in converting: ../data/midi_img/piano\Rachel_Piano_tempofix_Staff_10.png
# Error in converting: ../data/midi_img/piano\redwings_Piano_24.png
# Error in converting: ../data/midi_img/piano\relmstheme-piano_Right Hand_7.png
# Error in converting: ../data/midi_img/piano\roseofmay-piano_Piano_10.png
# Error in converting: ../data/midi_img/piano\rufus_Right Hand_10.png
# Error in converting: ../data/midi_img/piano\Rydia_pc_Right Hand_12.png
# Error in converting: ../data/midi_img/piano\sandy_Right Hand_9.png
# Error in converting: ../data/midi_img/piano\sera__Piano_8.png
# Error in converting: ../data/midi_img/piano\sobf_Right Hand_12.png
# Error in converting: ../data/midi_img/piano\Still_Alive-1_Piano_10.png
# Error in converting: ../data/midi_img/piano\Suteki_Da_Ne_(Piano_Version)_Track 1_16.png
# Error in converting: ../data/midi_img/piano\thenightmarebegins_Piano_10.png
# Error in converting: ../data/midi_img/piano\thoughts_Piano_6.png
# Error in converting: ../data/midi_img/piano\tifap_Piano_8.png
# Error in converting: ../data/midi_img/piano\tpirtsd-piano_The Place I'll Return to Some Day_6.png
# Error in converting: ../data/midi_img/piano\traitor_Right Hand_8.png
# Error in converting: ../data/midi_img/piano\ultimafro_Piano_11.png
# Error in converting: ../data/midi_img/piano\ultros_Piano_11.png
# Error in converting: ../data/midi_img/piano\VincentPiano_Right Hand_8.png
# Error in converting: ../data/midi_img/piano\ViviinAlexandria_Staff_28.png
# Error in converting: ../data/midi_img/piano\waltz_de_choco_Right Hand_4.png
# Error in converting: ../data/midi_img/piano\Zelda_Overworld_Right Hand_8.png
# Error in converting: ../data/midi_img/piano\z_aeristhemepiano_Staff_7.png

# %%
# Dataset Construction
def access_images(path, num_images=float("inf")):
    """
        Fetch a defined number of images from a directory
        and return their normalized pixels arrays
        Inputs:
            path: path to the directory containing the images
            img_list: list of image names
            num_images: number of images to fetch
        Output:
            image_arr: pixel array of images
            img: the original image
    """
    pixels = []
    imgs = []

    # fetch all images from the directory
    i = 0
    for file in (glob.glob(f"{path}/*.png")):
        if i >= num_images:
            break
        try:
            img = Image.open(file, 'r')
            img = img.convert('1')
            pix = np.array(img.getdata())
            pix = pix.astype('float32')
            pix /= 255.0
            pixels.append(pix.reshape(106,106,1))
            imgs.append(img)
        except:
            pass
        i+=1
    return np.array(pixels), imgs


img_dir = "../data/midi_img/piano"

pixels_arr, imgs = access_images(img_dir)
np.unique(pixels_arr)
# Out:
# array([0., 1.], dtype=float32)

# %% [markdown]
# # GAN Definition
#
# GAN model consists of two part:
# 1. Generator
# 2. Discriminator

# %%
# check to see if tensorflow mount to GPU properly
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
def define_generator(latent_dim):
    """Define the generator model
        Inputs:
            latent_dim: dimension of the latent space
        Output:
            model: the generator model
    """
    model = keras.Sequential()
    n_nodes = 128 * 53 * 53
    model.add(keras.layers.Dense(n_nodes, input_dim=latent_dim))
    model.add(keras.layers.LeakyReLU(alpha=0.2))
    model.add(keras.layers.Reshape((53, 53, 128)))
    model.add(keras.layers.Dense(1024))
    model.add(keras.layers.Conv2DTranspose(1024, (4,4), strides=(2,2), padding='same'))
    model.add(keras.layers.Dense(1024))
    model.add(keras.layers.LeakyReLU(alpha=0.2))
    model.add(keras.layers.Dense(1024))
    model.add(keras.layers.Conv2D(1, (7,7) , padding='same',activation = 'sigmoid'))
    return model

# %%
def define_discriminator(in_shape = (106,106,1)):
    """
        GAN discriminator model
        Inputs:
            in_shape: shape of the input image
        Output:
            model: discriminator model with binary crossentropy loss to denotes if the image is real or fake
    """
    model = keras.Sequential()
    model.add(keras.layers.Conv2D(64, (3,3), strides=(2, 2), padding='same', input_shape=in_shape))
    model.add(keras.layers.LeakyReLU(alpha=0.2))
    model.add(keras.layers.Dropout(0.5))
    model.add(keras.layers.Conv2D(64, (3,3), strides=(2, 2), padding='same'))
    model.add(keras.layers.LeakyReLU(alpha=0.2))
    model.add(keras.layers.Dropout(0.5))
    model.add(keras.layers.Flatten())
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Dense(1, activation='sigmoid'))
    opt = keras.optimizers.Adam(lr=0.0002, beta_1=0.5)
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
    return model

# %%
def define_gan(g_model, d_model):
    d_model.trainable = False
    model = keras.Sequential()
    model.add(g_model)
    model.add(d_model)
    opt = keras.optimizers.Adam(lr=0.0002, beta_1=0.5)
    model.compile(loss='binary_crossentropy', optimizer=opt)
    return model

# %%
latent_dim = 100
g_model = define_generator(latent_dim)
d_model = define_discriminator()
gan_model = define_gan(g_model, d_model)
g_model.summary(), d_model.summary(), gan_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 359552)            36314752
#
#  leaky_re_lu (LeakyReLU)     (None, 359552)            0
#
#  reshape (Reshape)           (None, 53, 53, 128)       0
#
#  dense_1 (Dense)             (None, 53, 53, 1024)      132096
#
#  conv2d_transpose (Conv2DTra  (None, 106, 106, 1024)   16778240
#  nspose)
#
#  dense_2 (Dense)             (None, 106, 106, 1024)    1049600
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 106, 106, 1024)    0
#
#  dense_3 (Dense)             (None, 106, 106, 1024)    1049600
#
#  conv2d (Conv2D)             (None, 106, 106, 1)       50177
#
# =================================================================
# Total params: 55,374,465
# Trainable params: 55,374,465
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 53, 53, 64)        640
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 53, 53, 64)        0
#
#  dropout (Dropout)           (None, 53, 53, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 27, 27, 64)        36928
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 27, 27, 64)        0
#
#  dropout_1 (Dropout)         (None, 27, 27, 64)        0
#
#  flatten (Flatten)           (None, 46656)             0
#
#  batch_normalization (BatchN  (None, 46656)            186624
#  ormalization)
#
#  dense_4 (Dense)             (None, 1)                 46657
#
# =================================================================
# Total params: 270,849
# Trainable params: 0
# Non-trainable params: 270,849
# _________________________________________________________________
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 106, 106, 1)       55374465
#
#  sequential_1 (Sequential)   (None, 1)                 270849
#
# =================================================================
# Total params: 55,645,314
# Trainable params: 55,374,465
# Non-trainable params: 270,849
# _________________________________________________________________
# c:\Users\ktrin\miniconda3\envs\W266\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# (None, None, None)

# %%
def generate_real_samples(dataset, n_samples):
    ix = np.random.randint(0, dataset.shape[0], n_samples)
    X = dataset[ix]
    y = np.ones((n_samples, 1))
    return X, y
 
def generate_latent_points(latent_dim, n_samples):
    x_input = np.random.randn(latent_dim * n_samples)
    x_input = x_input.reshape(n_samples, latent_dim)
    return x_input

def generate_fake_samples(g_model, latent_dim, n_samples):
    x_input = generate_latent_points(latent_dim, n_samples)
    X = g_model.predict(x_input)
    y = np.zeros((n_samples, 1))
    return X, y

# %%
# # generate samples and save as a plot and save the model
# def summarize_performance(step, g_model, gan_model, latent_dim, n_cat, n_samples=100):
# 	# prepare fake examples
# 	X, _ = generate_fake_samples(g_model, latent_dim, n_cat, n_samples)
# 	# scale from [-1,1] to [0,1]
# 	X = (X + 1) / 2.0
# 	# plot images
# 	for i in range(100):
# 		# define subplot
# 		plt.subplot(10, 10, 1 + i)
# 		# turn off axis
# 		plt.axis('off')
# 		# plot raw pixel data
# 		plt.imshow(X[i, :, :, 0], cmap='gray_r')
# 	# save plot to file
# 	filename1 = 'generated_plot_%04d.png' % (step+1)
# 	plt.savefig(filename1)
# 	plt.close()
# 	# save the generator model
# 	filename2 = 'model_%04d.h5' % (step+1)
# 	g_model.save(filename2)
# 	# save the gan model
# 	filename3 = 'gan_model_%04d.h5' % (step+1)
# 	gan_model.save(filename3)
# 	print('>Saved: %s, %s, and %s' % (filename1, filename2, filename3))

# %%
def train(g_model, d_model, gan_model, dataset, latent_dim, n_epochs=51, n_batch=10):
    bat_per_epo = int(dataset.shape[0] / n_batch)
    half_batch = int(n_batch / 2)
    for i in range(n_epochs):
        for j in range(bat_per_epo):
            X_real, y_real = generate_real_samples(dataset, half_batch)
            X_fake, y_fake = generate_fake_samples(g_model, latent_dim, half_batch)
            X, y = np.vstack((X_real, X_fake)), np.vstack((y_real, y_fake))
            d_loss, _ = d_model.train_on_batch(X, y)
            X_gan = generate_latent_points(latent_dim, n_batch)
            y_gan = np.ones((n_batch, 1))
            g_loss = gan_model.train_on_batch(X_gan, y_gan)
            print('>%d, %d/%d, d=%.3f, g=%.3f' % (i+1, j+1, bat_per_epo, d_loss, g_loss))

        if (i+1) % 10 == 0:
            # summarize_performance(i, g_model, d_model, dataset, latent_dim)
            clear_output()

# %%
import joblib
import random

random.seed(5634)

training_set = joblib.load('../data/piano-labelled/training_set.joblib')
training_set = random.sample(training_set, 2048) #5 is the lenth of the sample
pixels_arr, captions = zip(*training_set)
pixels_arr = np.array(pixels_arr)

# %%
train(g_model, d_model, gan_model, np.array(pixels_arr), latent_dim, n_epochs=3)
# Out:
# >1, 1/204, d=0.579, g=0.858
# >1, 2/204, d=0.167, g=0.964
# >1, 3/204, d=0.068, g=0.986
# >1, 4/204, d=0.035, g=0.987
# >1, 5/204, d=0.073, g=0.936
# >1, 6/204, d=0.228, g=0.804
# >1, 7/204, d=0.701, g=0.699
# >1, 8/204, d=0.878, g=0.681
# >1, 9/204, d=0.881, g=0.683
# >1, 10/204, d=0.631, g=0.688
# >1, 11/204, d=0.601, g=0.689
# >1, 12/204, d=0.607, g=0.685
# >1, 13/204, d=0.448, g=0.684
# >1, 14/204, d=0.462, g=0.687
# >1, 15/204, d=0.350, g=0.682
# >1, 16/204, d=0.251, g=0.665
# >1, 17/204, d=0.401, g=0.674
# >1, 18/204, d=0.243, g=0.663
# >1, 19/204, d=0.219, g=0.647
# >1, 20/204, d=0.235, g=0.635
# >1, 21/204, d=0.438, g=0.588
# >1, 22/204, d=0.277, g=0.585
# >1, 23/204, d=0.176, g=0.597
# >1, 24/204, d=0.254, g=0.609
# >1, 25/204, d=0.278, g=0.627
# >1, 26/204, d=0.255, g=0.594
# >1, 27/204, d=0.222, g=0.598
# >1, 28/204, d=0.140, g=0.613
# >1, 29/204, d=0.146, g=0.618
# >1, 30/204, d=0.157, g=0.610
# >1, 31/204, d=0.188, g=0.591
# >1, 32/204, d=0.103, g=0.586
# >1, 33/204, d=0.266, g=0.563
# >1, 34/204, d=0.084, g=0.562
# >1, 35/204, d=0.214, g=0.541
# >1, 36/204, d=0.149, g=0.538
# >1, 37/204, d=0.074, g=0.535
# >1, 38/204, d=0.347, g=0.522
# >1, 39/204, d=0.284, g=0.531
# >1, 40/204, d=0.123, g=0.547
# >1, 41/204, d=0.045, g=0.557
# >1, 42/204, d=0.085, g=0.566
# >1, 43/204, d=0.033, g=0.570
# >1, 44/204, d=0.110, g=0.550
# >1, 45/204, d=0.068, g=0.534
# >1, 46/204, d=0.062, g=0.524
# >1, 47/204, d=0.173, g=0.488
# >1, 48/204, d=0.050, g=0.469
# >1, 49/204, d=0.217, g=0.450
# >1, 50/204, d=0.068, g=0.434
# >1, 51/204, d=0.064, g=0.437
# >1, 52/204, d=0.034, g=0.442
# >1, 53/204, d=0.052, g=0.457
# >1, 54/204, d=0.159, g=0.436
# >1, 55/204, d=0.163, g=0.415
# >1, 56/204, d=0.025, g=0.410
# >1, 57/204, d=0.107, g=0.392
# >1, 58/204, d=0.215, g=0.359
# >1, 59/204, d=0.283, g=0.331
# >1, 60/204, d=0.290, g=0.323
# >1, 61/204, d=0.142, g=0.314
# >1, 62/204, d=0.215, g=0.300
# >1, 63/204, d=0.137, g=0.295
# >1, 64/204, d=0.119, g=0.315
# >1, 65/204, d=0.022, g=0.327
# >1, 66/204, d=0.036, g=0.338
# >1, 67/204, d=0.072, g=0.338
# >1, 68/204, d=0.036, g=0.345
# >1, 69/204, d=0.064, g=0.350
# >1, 70/204, d=0.037, g=0.360
# >1, 71/204, d=0.215, g=0.361
# >1, 72/204, d=0.056, g=0.373
# >1, 73/204, d=0.058, g=0.381
# >1, 74/204, d=0.082, g=0.390
# >1, 75/204, d=0.215, g=0.367
# >1, 76/204, d=0.301, g=0.335
# >1, 77/204, d=0.140, g=0.307
# >1, 78/204, d=0.015, g=0.297
# >1, 79/204, d=0.017, g=0.284
# >1, 80/204, d=0.057, g=0.298
# >1, 81/204, d=0.096, g=0.294
# >1, 82/204, d=0.206, g=0.295
# >1, 83/204, d=0.078, g=0.284
# >1, 84/204, d=0.225, g=0.275
# >1, 85/204, d=0.567, g=0.309
# >1, 86/204, d=2.166, g=0.145
# >1, 87/204, d=3.424, g=0.486
# >1, 88/204, d=0.284, g=0.313
# >1, 89/204, d=0.797, g=0.339
# >1, 90/204, d=0.504, g=0.534
# >1, 91/204, d=0.309, g=0.770
# >1, 92/204, d=0.313, g=0.750
# >1, 93/204, d=0.254, g=0.802
# >1, 94/204, d=0.092, g=0.770
# >1, 95/204, d=0.249, g=0.752
# >1, 96/204, d=0.318, g=0.727
# >1, 97/204, d=0.226, g=0.736
# >1, 98/204, d=0.295, g=0.724
# >1, 99/204, d=0.247, g=0.718
# >1, 100/204, d=0.243, g=0.723
# >1, 101/204, d=0.304, g=0.709
# >1, 102/204, d=0.304, g=0.693
# >1, 103/204, d=0.371, g=0.685
# >1, 104/204, d=0.225, g=0.721
# >1, 105/204, d=0.325, g=0.734
# >1, 106/204, d=0.157, g=0.680
# >1, 107/204, d=0.182, g=0.675
# >1, 108/204, d=0.494, g=0.649
# >1, 109/204, d=0.508, g=0.659
# >1, 110/204, d=0.251, g=0.678
# >1, 111/204, d=0.137, g=0.633
# >1, 112/204, d=0.197, g=0.659
# >1, 113/204, d=0.287, g=0.656
# >1, 114/204, d=0.232, g=0.640
# >1, 115/204, d=0.302, g=0.619
# >1, 116/204, d=0.205, g=0.623
# >1, 117/204, d=0.127, g=0.646
# >1, 118/204, d=0.221, g=0.635
# >1, 119/204, d=0.159, g=0.626
# >1, 120/204, d=0.163, g=0.676
# >1, 121/204, d=0.219, g=0.657
# >1, 122/204, d=0.154, g=0.676
# >1, 123/204, d=0.167, g=0.706
# >1, 124/204, d=0.297, g=0.710
# >1, 125/204, d=0.288, g=0.665
# >1, 126/204, d=0.378, g=0.654
# >1, 127/204, d=0.409, g=0.687
# >1, 128/204, d=0.146, g=0.653
# >1, 129/204, d=0.306, g=0.644
# >1, 130/204, d=0.236, g=0.608
# >1, 131/204, d=0.264, g=0.595
# >1, 132/204, d=0.142, g=0.611
# >1, 133/204, d=0.445, g=0.643
# >1, 134/204, d=0.171, g=0.624
# >1, 135/204, d=0.349, g=0.621
# >1, 136/204, d=0.444, g=0.607
# >1, 137/204, d=0.482, g=0.583
# >1, 138/204, d=0.285, g=0.616
# >1, 139/204, d=0.148, g=0.584
# >1, 140/204, d=0.220, g=0.583
# >1, 141/204, d=0.291, g=0.590
# >1, 142/204, d=0.450, g=0.587
# >1, 143/204, d=0.195, g=0.593
# >1, 144/204, d=0.309, g=0.572
# >1, 145/204, d=0.250, g=0.605
# >1, 146/204, d=0.422, g=0.537
# >1, 147/204, d=0.201, g=0.531
# >1, 148/204, d=0.305, g=0.497
# >1, 149/204, d=0.257, g=0.495
# >1, 150/204, d=0.301, g=0.494
# >1, 151/204, d=0.262, g=0.498
# >1, 152/204, d=0.101, g=0.514
# >1, 153/204, d=0.291, g=0.523
# >1, 154/204, d=0.218, g=0.530
# >1, 155/204, d=0.119, g=0.539
# >1, 156/204, d=0.259, g=0.511
# >1, 157/204, d=0.244, g=0.509
# >1, 158/204, d=0.283, g=0.486
# >1, 159/204, d=0.271, g=0.488
# >1, 160/204, d=0.295, g=0.482
# >1, 161/204, d=0.130, g=0.449
# >1, 162/204, d=0.088, g=0.420
# >1, 163/204, d=0.197, g=0.453
# >1, 164/204, d=0.560, g=0.441
# >1, 165/204, d=0.134, g=0.412
# >1, 166/204, d=0.147, g=0.440
# >1, 167/204, d=0.307, g=0.394
# >1, 168/204, d=0.160, g=0.383
# >1, 169/204, d=0.321, g=0.346
# >1, 170/204, d=0.191, g=0.348
# >1, 171/204, d=0.131, g=0.353
# >1, 172/204, d=0.182, g=0.378
# >1, 173/204, d=0.223, g=0.410
# >1, 174/204, d=0.106, g=0.417
# >1, 175/204, d=0.328, g=0.397
# >1, 176/204, d=0.097, g=0.371
# >1, 177/204, d=0.322, g=0.365
# >1, 178/204, d=0.060, g=0.338
# >1, 179/204, d=0.143, g=0.344
# >1, 180/204, d=0.073, g=0.313
# >1, 181/204, d=0.351, g=0.313
# >1, 182/204, d=0.268, g=0.296
# >1, 183/204, d=0.363, g=0.280
# >1, 184/204, d=0.190, g=0.285
# >1, 185/204, d=0.138, g=0.271
# >1, 186/204, d=0.050, g=0.260
# >1, 187/204, d=0.035, g=0.281
# >1, 188/204, d=0.041, g=0.279
# >1, 189/204, d=0.204, g=0.280
# >1, 190/204, d=0.257, g=0.287
# >1, 191/204, d=0.148, g=0.290
# >1, 192/204, d=0.138, g=0.308
# >1, 193/204, d=0.210, g=0.286
# >1, 194/204, d=0.213, g=0.297
# >1, 195/204, d=0.341, g=0.310
# >1, 196/204, d=0.056, g=0.315
# >1, 197/204, d=0.101, g=0.313
# >1, 198/204, d=0.170, g=0.308
# >1, 199/204, d=0.189, g=0.294
# >1, 200/204, d=0.116, g=0.277
# >1, 201/204, d=0.148, g=0.294
# >1, 202/204, d=0.125, g=0.283
# >1, 203/204, d=0.042, g=0.298
# >1, 204/204, d=0.315, g=0.257
# >2, 1/204, d=0.364, g=0.242
# >2, 2/204, d=0.587, g=0.264
# >2, 3/204, d=0.054, g=0.271
# >2, 4/204, d=0.274, g=0.258
# >2, 5/204, d=0.155, g=0.249
# >2, 6/204, d=0.079, g=0.272
# >2, 7/204, d=0.126, g=0.257
# >2, 8/204, d=0.114, g=0.242
# >2, 9/204, d=0.229, g=0.261
# >2, 10/204, d=0.165, g=0.215
# >2, 11/204, d=0.025, g=0.223
# >2, 12/204, d=0.101, g=0.226
# >2, 13/204, d=0.078, g=0.241
# >2, 14/204, d=0.331, g=0.229
# >2, 15/204, d=0.057, g=0.233
# >2, 16/204, d=0.417, g=0.214
# >2, 17/204, d=0.238, g=0.206
# >2, 18/204, d=0.054, g=0.211
# >2, 19/204, d=0.208, g=0.232
# >2, 20/204, d=0.419, g=0.216
# >2, 21/204, d=0.035, g=0.196
# >2, 22/204, d=0.170, g=0.200
# >2, 23/204, d=0.379, g=0.191
# >2, 24/204, d=0.342, g=0.196
# >2, 25/204, d=0.176, g=0.215
# >2, 26/204, d=0.149, g=0.225
# >2, 27/204, d=0.054, g=0.221
# >2, 28/204, d=0.079, g=0.234
# >2, 29/204, d=0.068, g=0.244
# >2, 30/204, d=0.126, g=0.236
# >2, 31/204, d=0.159, g=0.243
# >2, 32/204, d=0.078, g=0.238
# >2, 33/204, d=0.040, g=0.245
# >2, 34/204, d=0.072, g=0.250
# >2, 35/204, d=0.116, g=0.247
# >2, 36/204, d=0.099, g=0.272
# >2, 37/204, d=0.394, g=0.223
# >2, 38/204, d=0.131, g=0.221
# >2, 39/204, d=0.100, g=0.229
# >2, 40/204, d=0.355, g=0.271
# >2, 41/204, d=0.171, g=0.304
# >2, 42/204, d=0.130, g=0.331
# >2, 43/204, d=0.176, g=0.299
# >2, 44/204, d=0.184, g=0.285
# >2, 45/204, d=0.233, g=0.264
# >2, 46/204, d=0.184, g=0.247
# >2, 47/204, d=0.108, g=0.231
# >2, 48/204, d=0.086, g=0.251
# >2, 49/204, d=0.101, g=0.253
# >2, 50/204, d=0.130, g=0.269
# >2, 51/204, d=0.144, g=0.278
# >2, 52/204, d=0.023, g=0.283
# >2, 53/204, d=0.179, g=0.280
# >2, 54/204, d=0.011, g=0.305
# >2, 55/204, d=0.085, g=0.266
# >2, 56/204, d=0.087, g=0.283
# >2, 57/204, d=0.353, g=0.293
# >2, 58/204, d=0.031, g=0.294
# >2, 59/204, d=0.010, g=0.313
# >2, 60/204, d=0.025, g=0.290
# >2, 61/204, d=0.042, g=0.300
# >2, 62/204, d=0.071, g=0.351
# >2, 63/204, d=0.015, g=0.367
# >2, 64/204, d=0.079, g=0.351
# >2, 65/204, d=0.308, g=0.351
# >2, 66/204, d=0.033, g=0.312
# >2, 67/204, d=0.099, g=0.296
# >2, 68/204, d=0.087, g=0.336
# >2, 69/204, d=0.011, g=0.271
# >2, 70/204, d=0.005, g=0.276
# >2, 71/204, d=0.256, g=0.219
# >2, 72/204, d=0.199, g=0.167
# >2, 73/204, d=0.170, g=0.187
# >2, 74/204, d=0.153, g=0.227
# >2, 75/204, d=0.047, g=0.235
# >2, 76/204, d=0.057, g=0.282
# >2, 77/204, d=0.220, g=0.326
# >2, 78/204, d=0.039, g=0.301
# >2, 79/204, d=0.029, g=0.351
# >2, 80/204, d=0.102, g=0.385
# >2, 81/204, d=0.013, g=0.394
# >2, 82/204, d=0.086, g=0.414
# >2, 83/204, d=0.013, g=0.412
# >2, 84/204, d=0.004, g=0.428
# >2, 85/204, d=0.067, g=0.451
# >2, 86/204, d=0.050, g=0.461
# >2, 87/204, d=0.113, g=0.413
# >2, 88/204, d=0.249, g=0.500
# >2, 89/204, d=0.218, g=0.491
# >2, 90/204, d=0.136, g=0.462
# >2, 91/204, d=0.088, g=0.421
# >2, 92/204, d=0.023, g=0.339
# >2, 93/204, d=0.218, g=0.325
# >2, 94/204, d=0.015, g=0.253
# >2, 95/204, d=0.018, g=0.247
# >2, 96/204, d=0.012, g=0.241
# >2, 97/204, d=0.013, g=0.251
# >2, 98/204, d=0.288, g=0.267
# >2, 99/204, d=0.174, g=0.281
# >2, 100/204, d=0.027, g=0.277
# >2, 101/204, d=0.085, g=0.327
# >2, 102/204, d=0.098, g=0.348
# >2, 103/204, d=0.081, g=0.350
# >2, 104/204, d=0.225, g=0.413
# >2, 105/204, d=0.165, g=0.527
# >2, 106/204, d=0.160, g=0.607
# >2, 107/204, d=0.122, g=0.577
# >2, 108/204, d=0.426, g=0.582
# >2, 109/204, d=0.318, g=0.456
# >2, 110/204, d=0.006, g=0.451
# >2, 111/204, d=0.024, g=0.413
# >2, 112/204, d=0.042, g=0.455
# >2, 113/204, d=0.016, g=0.369
# >2, 114/204, d=0.008, g=0.400
# >2, 115/204, d=0.014, g=0.385
# >2, 116/204, d=0.028, g=0.430
# >2, 117/204, d=0.003, g=0.430
# >2, 118/204, d=0.188, g=0.514
# >2, 119/204, d=0.153, g=0.587
# >2, 120/204, d=0.094, g=0.713
# >2, 121/204, d=0.008, g=0.689
# >2, 122/204, d=0.436, g=0.626
# >2, 123/204, d=0.028, g=0.527
# >2, 124/204, d=0.017, g=0.546
# >2, 125/204, d=0.017, g=0.502
# >2, 126/204, d=0.041, g=0.561
# >2, 127/204, d=0.077, g=0.577
# >2, 128/204, d=0.206, g=0.597
# >2, 129/204, d=0.338, g=0.561
# >2, 130/204, d=0.021, g=0.474
# >2, 131/204, d=0.054, g=0.413
# >2, 132/204, d=0.012, g=0.524
# >2, 133/204, d=0.015, g=0.479
# >2, 134/204, d=0.170, g=0.396
# >2, 135/204, d=0.090, g=0.402
# >2, 136/204, d=0.025, g=0.319
# >2, 137/204, d=0.019, g=0.215
# >2, 138/204, d=0.013, g=0.200
# >2, 139/204, d=0.217, g=0.194
# >2, 140/204, d=0.117, g=0.215
# >2, 141/204, d=0.059, g=0.267
# >2, 142/204, d=0.286, g=0.259
# >2, 143/204, d=0.071, g=0.463
# >2, 144/204, d=0.034, g=0.195
# >2, 145/204, d=0.046, g=0.106
# >2, 146/204, d=0.206, g=0.141
# >2, 147/204, d=0.860, g=0.132
# >2, 148/204, d=1.145, g=0.020
# >2, 149/204, d=1.294, g=0.019
# >2, 150/204, d=1.918, g=0.067
# >2, 151/204, d=1.691, g=0.068
# >2, 152/204, d=1.261, g=0.271
# >2, 153/204, d=0.862, g=2.657
# >2, 154/204, d=1.383, g=0.508
# >2, 155/204, d=0.942, g=1.011
# >2, 156/204, d=1.078, g=1.298
# >2, 157/204, d=0.355, g=1.633
# >2, 158/204, d=0.398, g=1.843
# >2, 159/204, d=0.109, g=2.253
# >2, 160/204, d=0.170, g=2.209
# >2, 161/204, d=0.081, g=1.910
# >2, 162/204, d=0.285, g=2.026
# >2, 163/204, d=0.632, g=2.138
# >2, 164/204, d=0.183, g=1.904
# >2, 165/204, d=0.396, g=1.792
# >2, 166/204, d=0.120, g=1.691
# >2, 167/204, d=0.698, g=1.416
# >2, 168/204, d=0.364, g=1.552
# >2, 169/204, d=0.756, g=1.418
# >2, 170/204, d=0.827, g=1.678
# >2, 171/204, d=0.576, g=1.352
# >2, 172/204, d=0.577, g=1.573
# >2, 173/204, d=0.149, g=1.742
# >2, 174/204, d=0.341, g=2.251
# >2, 175/204, d=0.175, g=2.557
# >2, 176/204, d=0.296, g=2.600
# >2, 177/204, d=0.327, g=2.428
# >2, 178/204, d=0.143, g=2.468
# >2, 179/204, d=0.193, g=2.208
# >2, 180/204, d=0.284, g=2.382
# >2, 181/204, d=0.050, g=2.637
# >2, 182/204, d=0.026, g=2.611
# >2, 183/204, d=0.151, g=2.158
# >2, 184/204, d=0.075, g=2.442
# >2, 185/204, d=0.261, g=2.390
# >2, 186/204, d=0.247, g=2.583
# >2, 187/204, d=0.297, g=2.928
# >2, 188/204, d=0.031, g=2.939
# >2, 189/204, d=0.289, g=2.943
# >2, 190/204, d=0.045, g=2.892
# >2, 191/204, d=0.054, g=2.767
# >2, 192/204, d=0.298, g=2.742
# >2, 193/204, d=0.017, g=2.359
# >2, 194/204, d=0.066, g=3.550
# >2, 195/204, d=0.069, g=3.476
# >2, 196/204, d=0.494, g=2.938
# >2, 197/204, d=0.066, g=2.903
# >2, 198/204, d=0.151, g=2.883
# >2, 199/204, d=0.237, g=2.782
# >2, 200/204, d=0.261, g=2.633
# >2, 201/204, d=0.103, g=2.520
# >2, 202/204, d=0.088, g=2.671
# >2, 203/204, d=0.425, g=2.589
# >2, 204/204, d=0.103, g=2.514
# >3, 1/204, d=0.079, g=2.215
# >3, 2/204, d=0.196, g=2.537
# >3, 3/204, d=0.054, g=2.535
# >3, 4/204, d=0.129, g=2.693
# >3, 5/204, d=0.318, g=2.843
# >3, 6/204, d=0.047, g=2.952
# >3, 7/204, d=0.222, g=2.652
# >3, 8/204, d=0.020, g=2.890
# >3, 9/204, d=0.042, g=2.763
# >3, 10/204, d=0.109, g=2.539
# >3, 11/204, d=0.114, g=2.671
# >3, 12/204, d=0.162, g=2.912
# >3, 13/204, d=0.052, g=2.727
# >3, 14/204, d=0.173, g=2.635
# >3, 15/204, d=0.297, g=2.803
# >3, 16/204, d=0.259, g=2.553
# >3, 17/204, d=0.040, g=2.759
# >3, 18/204, d=0.154, g=3.079
# >3, 19/204, d=0.054, g=3.256
# >3, 20/204, d=0.044, g=2.888
# >3, 21/204, d=0.041, g=2.824
# >3, 22/204, d=0.028, g=2.650
# >3, 23/204, d=0.046, g=2.712
# >3, 24/204, d=0.034, g=2.769
# >3, 25/204, d=0.340, g=2.649
# >3, 26/204, d=0.040, g=2.639
# >3, 27/204, d=0.100, g=2.669
# >3, 28/204, d=0.180, g=2.517
# >3, 29/204, d=0.024, g=2.655
# >3, 30/204, d=0.090, g=2.461
# >3, 31/204, d=0.117, g=2.320
# >3, 32/204, d=0.052, g=2.396
# >3, 33/204, d=0.286, g=2.653
# >3, 34/204, d=0.205, g=2.672
# >3, 35/204, d=0.080, g=2.905
# >3, 36/204, d=0.036, g=2.687
# >3, 37/204, d=0.055, g=2.732
# >3, 38/204, d=0.070, g=2.842
# >3, 39/204, d=0.024, g=2.907
# >3, 40/204, d=0.071, g=2.905
# >3, 41/204, d=0.147, g=2.889
# >3, 42/204, d=0.023, g=2.874
# >3, 43/204, d=0.026, g=2.912
# >3, 44/204, d=0.023, g=2.930
# >3, 45/204, d=0.030, g=3.073
# >3, 46/204, d=0.134, g=2.989
# >3, 47/204, d=0.032, g=2.983
# >3, 48/204, d=0.529, g=2.798
# >3, 49/204, d=0.092, g=2.758
# >3, 50/204, d=0.013, g=2.620
# >3, 51/204, d=0.045, g=2.644
# >3, 52/204, d=0.100, g=2.699
# >3, 53/204, d=0.105, g=2.683
# >3, 54/204, d=0.131, g=2.785
# >3, 55/204, d=0.016, g=2.709
# >3, 56/204, d=0.008, g=2.876
# >3, 57/204, d=0.256, g=2.842
# >3, 58/204, d=0.024, g=2.954
# >3, 59/204, d=0.126, g=2.998
# >3, 60/204, d=0.014, g=2.950
# >3, 61/204, d=0.238, g=2.946
# >3, 62/204, d=0.132, g=2.963
# >3, 63/204, d=0.054, g=2.862
# >3, 64/204, d=0.107, g=2.849
# >3, 65/204, d=0.074, g=2.858
# >3, 66/204, d=0.052, g=2.803
# >3, 67/204, d=0.252, g=2.971
# >3, 68/204, d=0.062, g=3.019
# >3, 69/204, d=0.021, g=2.991
# >3, 70/204, d=0.012, g=3.073
# >3, 71/204, d=0.144, g=3.086
# >3, 72/204, d=0.094, g=3.093
# >3, 73/204, d=0.015, g=3.122
# >3, 74/204, d=0.145, g=3.091
# >3, 75/204, d=0.019, g=3.147
# >3, 76/204, d=0.068, g=3.123
# >3, 77/204, d=0.008, g=3.179
# >3, 78/204, d=0.288, g=3.099
# >3, 79/204, d=0.019, g=3.085
# >3, 80/204, d=0.026, g=3.093
# >3, 81/204, d=0.020, g=3.181
# >3, 82/204, d=0.004, g=3.219
# >3, 83/204, d=0.154, g=3.068
# >3, 84/204, d=0.125, g=3.128
# >3, 85/204, d=0.122, g=3.108
# >3, 86/204, d=0.031, g=3.044
# >3, 87/204, d=0.010, g=3.057
# >3, 88/204, d=0.296, g=3.044
# >3, 89/204, d=0.323, g=3.078
# >3, 90/204, d=0.018, g=3.125
# >3, 91/204, d=0.014, g=3.174
# >3, 92/204, d=0.014, g=3.313
# >3, 93/204, d=0.024, g=3.262
# >3, 94/204, d=0.019, g=3.372
# >3, 95/204, d=0.102, g=3.435
# >3, 96/204, d=0.056, g=3.426
# >3, 97/204, d=0.005, g=3.569
# >3, 98/204, d=0.005, g=3.557
# >3, 99/204, d=0.026, g=3.576
# >3, 100/204, d=0.284, g=3.544
# >3, 101/204, d=0.004, g=3.576
# >3, 102/204, d=0.007, g=3.567
# >3, 103/204, d=0.124, g=3.560
# >3, 104/204, d=0.295, g=3.377
# >3, 105/204, d=0.147, g=3.410
# >3, 106/204, d=0.194, g=3.308
# >3, 107/204, d=0.250, g=3.258
# >3, 108/204, d=0.004, g=3.218
# >3, 109/204, d=0.042, g=3.283
# >3, 110/204, d=0.069, g=3.216
# >3, 111/204, d=0.053, g=3.364
# >3, 112/204, d=0.022, g=3.357
# >3, 113/204, d=0.014, g=3.437
# >3, 114/204, d=0.005, g=3.418
# >3, 115/204, d=0.014, g=3.407
# >3, 116/204, d=0.013, g=3.437
# >3, 117/204, d=0.009, g=3.539
# >3, 118/204, d=0.004, g=3.517
# >3, 119/204, d=0.130, g=3.694
# >3, 120/204, d=0.171, g=3.684
# >3, 121/204, d=0.006, g=3.614
# >3, 122/204, d=0.009, g=3.602
# >3, 123/204, d=0.121, g=3.686
# >3, 124/204, d=0.327, g=3.535
# >3, 125/204, d=0.009, g=3.520
# >3, 126/204, d=0.005, g=3.530
# >3, 127/204, d=0.027, g=3.563
# >3, 128/204, d=0.001, g=3.570
# >3, 129/204, d=0.026, g=3.624
# >3, 130/204, d=0.056, g=3.580
# >3, 131/204, d=0.008, g=3.634
# >3, 132/204, d=0.030, g=3.558
# >3, 133/204, d=0.377, g=3.409
# >3, 134/204, d=0.025, g=3.362
# >3, 135/204, d=0.143, g=3.252
# >3, 136/204, d=0.028, g=3.183
# >3, 137/204, d=0.011, g=3.236
# >3, 138/204, d=0.002, g=3.314
# >3, 139/204, d=0.056, g=3.383
# >3, 140/204, d=0.160, g=3.324
# >3, 141/204, d=0.026, g=3.364
# >3, 142/204, d=0.017, g=3.376
# >3, 143/204, d=0.076, g=3.481
# >3, 144/204, d=0.006, g=3.565
# >3, 145/204, d=0.002, g=3.601
# >3, 146/204, d=0.093, g=3.696
# >3, 147/204, d=0.005, g=3.680
# >3, 148/204, d=0.003, g=3.666
# >3, 149/204, d=0.018, g=3.680
# >3, 150/204, d=0.003, g=3.784
# >3, 151/204, d=0.016, g=3.861
# >3, 152/204, d=0.009, g=3.925
# >3, 153/204, d=0.002, g=3.866
# >3, 154/204, d=0.104, g=3.901
# >3, 155/204, d=0.010, g=3.897
# >3, 156/204, d=0.047, g=3.865
# >3, 157/204, d=0.048, g=3.873
# >3, 158/204, d=0.003, g=3.934
# >3, 159/204, d=0.006, g=3.867
# >3, 160/204, d=0.001, g=3.994
# >3, 161/204, d=0.085, g=3.848
# >3, 162/204, d=0.003, g=3.985
# >3, 163/204, d=0.088, g=4.037
# >3, 164/204, d=0.009, g=3.907
# >3, 165/204, d=0.014, g=3.921
# >3, 166/204, d=0.003, g=4.042
# >3, 167/204, d=0.161, g=3.976
# >3, 168/204, d=0.005, g=3.941
# >3, 169/204, d=0.005, g=3.890
# >3, 170/204, d=0.002, g=3.951
# >3, 171/204, d=0.025, g=3.926
# >3, 172/204, d=0.007, g=3.908
# >3, 173/204, d=0.008, g=3.938
# >3, 174/204, d=0.001, g=3.990
# >3, 175/204, d=0.007, g=3.936
# >3, 176/204, d=0.026, g=4.007
# >3, 177/204, d=0.005, g=3.937
# >3, 178/204, d=0.343, g=3.830
# >3, 179/204, d=0.005, g=3.803
# >3, 180/204, d=0.021, g=3.713
# >3, 181/204, d=0.004, g=3.813
# >3, 182/204, d=0.016, g=3.821
# >3, 183/204, d=0.030, g=3.973
# >3, 184/204, d=0.010, g=3.957
# >3, 185/204, d=0.199, g=3.731
# >3, 186/204, d=0.002, g=3.639
# >3, 187/204, d=0.004, g=3.681
# >3, 188/204, d=0.035, g=3.688
# >3, 189/204, d=0.003, g=3.670
# >3, 190/204, d=0.005, g=3.759
# >3, 191/204, d=0.017, g=3.860
# >3, 192/204, d=0.044, g=3.824
# >3, 193/204, d=0.390, g=3.631
# >3, 194/204, d=0.037, g=3.556
# >3, 195/204, d=0.011, g=3.603
# >3, 196/204, d=0.011, g=3.616
# >3, 197/204, d=0.310, g=3.579
# >3, 198/204, d=0.019, g=3.539
# >3, 199/204, d=0.064, g=3.491
# >3, 200/204, d=0.143, g=3.584
# >3, 201/204, d=0.012, g=3.275
# >3, 202/204, d=0.022, g=2.742
# >3, 203/204, d=0.255, g=2.559
# >3, 204/204, d=0.024, g=1.406

# %%
def generate_latent_points(latent_dim, n_samples):
    x_input = np.random.randn(latent_dim * n_samples)
    x_input = x_input.reshape(n_samples, latent_dim)
    return x_input


latent_dim = 100
model = g_model
latent_points = generate_latent_points(latent_dim, 1)
X = g_model.predict(latent_points)
array = np.array(X.reshape(106,106),dtype = np.uint8)
array*= 255
new_image = Image.fromarray(array,'L')
new_image = new_image.save('../data/midi_reconstruction/images/composition.png')

# %%
# reconvert MIDI images to MIDI files
image_path = "../data/midi_reconstruction/images/composition.png"
output_path = "../data/midi_reconstruction"

img2midi_obj = img2midi(image_path, output_path, resolution=0.25)
img2midi_obj.convert_to_midi()

# %%
# save the model
g_model.save('../models/mini-gan/piano_generator_model.h5')
d_model.save('../models/mini-gan/piano_discriminator_model.h5')
gan_model.save('../models/mini-gan/piano_gan_model.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# run to cell to play
# stop the cell and run sp.stop to stop the music
from music21 import midi, converter, instrument, note, chord

mf = midi.MidiFile()
mf.open(f"{output_path}/music.mid")
mf.read()
mf.close()
s = midi.translate.midiFileToStream(mf)
sp = midi.realtime.StreamPlayer(s)
sp.play()
# Out:
# pygame 2.5.1 (SDL 2.28.2, Python 3.9.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
sp.stop
# Out:
# <bound method StreamPlayer.stop of <music21.midi.realtime.StreamPlayer object at 0x0000018D8FCEAF10>>
